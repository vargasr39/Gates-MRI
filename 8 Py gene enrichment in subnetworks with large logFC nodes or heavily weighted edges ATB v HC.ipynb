# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>

# %%
project_dir_path = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers'

# %% [markdown]
# #### Load Packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import MaxNLocator
from matplotlib.gridspec import GridSpec
import matplotlib.pylab as pl
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import fastcluster
from scipy.cluster.hierarchy import dendrogram
import scipy.cluster.hierarchy as hier
import networkx as nx
import networkx.algorithms.community as nxcom
import community
from collections import Counter
import pickle
from collections import defaultdict
import gseapy as gp
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Create directory for figures

# %%
figures_dir_path = f'{project_dir_path}/Figures/Notebook 8'
if not os.path.exists(figures_dir_path):
    os.makedirs(figures_dir_path)

# %% [markdown]
# Specify directory paths

# %%
#directory for Pickled Objects
pickled_objects_dir = f'{project_dir_path}/Data/Pickled Files/'

#directory for Data
Data_files_dir = f'{project_dir_path}/Data/'

#directory for Gene Set Files
Gene_Set_dir = f'{project_dir_path}/Data/Gene Set Files/CSV files/'

# %% [markdown]
# Set parameters for plotting

# %%
plt.style.use('ggplot')
plt.rcParams['lines.linewidth']=1.0
plt.rcParams['axes.facecolor']='1.0'
plt.rcParams['xtick.color']='black'
plt.rcParams['axes.grid']=False
plt.rcParams['axes.edgecolor']='black'
plt.rcParams['grid.color']= '1.0'
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# Choose a comparison group

# %%
comparison_X = 'ATB_v_HC'

# %% [markdown]
# ## [1] Load Data

# %% [markdown]
# #### Network

# %%
G = nx.read_gpickle(pickled_objects_dir + f'Network Files/networks/{comparison_X}.pkl')

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 3005
# Number of edges: 672127
# Average degree: 447.3391

# %%
num_nodes_overall_network = int(len(G.nodes()))

# %% [markdown]
# #### Weighted Degrees for Nodes (genes)

# %%
weighted_deg_series = pd.read_pickle(pickled_objects_dir + f'Network Files/weighted degree series/{comparison_X}.pkl')

# %%
np.shape(weighted_deg_series)
# Out:
# (3005,)

# %% [markdown]
# #### Mean $log_2(Fold Change)$ for Nodes (genes)

# %%
mean_logFC_series = pd.read_pickle(pickled_objects_dir + f'Network Files/mean logFC network nodes series/{comparison_X}.pkl')

# %%
np.shape(mean_logFC_series)
# Out:
# (3005,)

# %% [markdown]
# Compile into DataFrame

# %%
G_deg_logFC_df = pd.DataFrame(index = mean_logFC_series.index)
G_deg_logFC_df['mean_log2FC'] = mean_logFC_series.values
G_deg_logFC_df['weighted_degree'] = weighted_deg_series[mean_logFC_series.index].values

# %%
G_deg_logFC_df.head()
# Out:
#           mean_log2FC  weighted_degree
# SERPING1     2.805312       572.733333
# ANKRD22      2.713292       604.800000
# BATF2        2.319556       583.066667
# P2RY14       2.241647       511.666667
# FCGR1B       2.127004       572.733333

# %% [markdown]
# ## [2] Get sub-network constructed from retaining only nodes with $mean(logFC) \ge 0.5$ & detect communities

# %% [markdown]
# ### *Functions* to retrieve node colors based of node values (i.e. weighted degree, logFC for gene)

# %%
def get_node_colors_continuous(node_values):
    
    '''
    This function takes a list of values for each node and color map, 
    normalizes the colormap and assigns each node a color from a 
    color map based on normalized map. Returns a list of colors for nodes.
    '''
    
    #load mpl colormap and normalize to data
    color_scheme = plt.get_cmap('RdYlBu_r')
    norm = mpl.colors.Normalize(vmin = min(node_values), vmax = max(node_values)) #get the normalization
    color_scheme_norm = mpl.cm.ScalarMappable(norm = norm, cmap = color_scheme) #normalize the color map to the min/max values of the node values
    
    #get color for each node from color map
    color_map = []
    for node_value in node_values:
        color_map.append(color_scheme_norm.to_rgba(node_value))
        
    return [color_map, norm, color_scheme]

# %%
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
def get_node_colors_discrete(node_values):
    
    '''
    This function takes a list of values for each node and color map, 
    normalizes the colormap and assigns each node a color from a 
    color map based on normalized map. Returns a list of colors for nodes.
    '''
    
    #load mpl colormap and normalize to data
    color_scheme = discrete_cmap(5, 'RdYlBu_r')
    norm = mpl.colors.Normalize(vmin = -1*max(abs(min(node_values)),max(node_values)), vmax = max(abs(min(node_values)),max(node_values))) #get the normalization
    color_scheme_norm = mpl.cm.ScalarMappable(norm = norm, cmap = color_scheme) #normalize the color map to the min/max values of the node values

    #get color for each node from color map
    color_map = []
    for node_value in node_values:
        color_map.append(color_scheme_norm.to_rgba(node_value))
        
    return [color_map, norm, color_scheme]

# %% [markdown]
# ### *Function* to visualize network by weighted degree & logFC based on gene values

# %%
def visualize_network_color_by_weighted_deg_and_logFC(G, pos, fig_name = None):
    
    #weighted degree for nodes in this network
    node_list = [node_deg[0] for node_deg in list(G.degree(weight = 'weight'))]
    degree_list = [node_deg[1] for node_deg in list(G.degree(weight = 'weight'))]
    node_weighted_deg_values = pd.Series(degree_list , index = node_list) / float(len(node_list)) #normalize by # of nodes
    
    #logFC for nodes in this network
    node_logFC_values = G_deg_logFC_df.mean_log2FC[list(G.nodes)] 
    
    fig = plt.figure(constrained_layout=True)

    gs = GridSpec(2, 3, figure=fig, height_ratios = [13,1])

    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    ax3 = fig.add_subplot(gs[0, 2])
    ax5 = fig.add_subplot(gs[1, 1])
    ax6 = fig.add_subplot(gs[1, 2])
    
    #color nodes with edges
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax1,
        node_size = 45, 
        node_color = 'xkcd:black',
        linewidths = 0.0,
        edge_color = "0.8",
        width=0.2,
        alpha = 1.0, 
        with_labels = False)
    ax1.collections[0].set_edgecolor("black") #color of the node outlines
    
    #color nodes by weighted deg 
    node_colors , color_bar_norm , color_scheme = get_node_colors_continuous(node_weighted_deg_values)
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax2,
        node_size = 45, 
        node_color = node_colors,
        linewidths = 0.2, #width of the node outlines
        edge_color = "0.83",
        width=0.0,
        alpha = 1.0, 
        with_labels = False)
    ax2.collections[0].set_edgecolor("black") #color of the node outlines
    cb1 = mpl.colorbar.ColorbarBase(ax5, cmap = color_scheme, norm = color_bar_norm, orientation='horizontal')
    cb1.set_label('Weighted Degree', fontsize = 14, color = 'k', weight = 'bold')
    
    #color nodes by logFC
    node_colors , color_bar_norm , color_scheme = get_node_colors_discrete(node_logFC_values)
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax3,
        node_size = 45, 
        node_color = node_colors,
        linewidths = 0.2,
        edge_color = "0.83",
        width=0.0,
        alpha = 1.0, 
        with_labels = False)
    ax3.collections[0].set_edgecolor("black") #color of the node outlines
    cb2 = mpl.colorbar.ColorbarBase(ax6, cmap = color_scheme, norm = color_bar_norm, orientation='horizontal')
    cb2.set_label('Mean logFC', fontsize = 14, color = 'k', weight = 'bold')

    ################### Plot
    fig = plt.gcf()
    fig.set_size_inches(24.5, 9.0)
    fig.tight_layout()
    
    if fig_name != None:
        file_name = f'{figures_dir_path}/{comparison_X} {fig_name}.pdf'
        plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

    plt.show()

# %% [markdown]
# ### [2.1] Get most heavily weighted edges that pass optimal threshold & construct sub-graph

# %%
len(G_deg_logFC_df.mean_log2FC[abs(G_deg_logFC_df.mean_log2FC) >= 0.5].index)
# Out:
# 372

# %%
#get the nodes in the network that pass the logFC threshold
nodes_high_abs_logFC_subset = list(G_deg_logFC_df.mean_log2FC[abs(G_deg_logFC_df.mean_log2FC) >= 0.5].index)

#get the SUBGRAPH induced by the most these nodes (correspond to genes with >> |logFC|)
S = G.subgraph(nodes_high_abs_logFC_subset)

# %%
print(nx.info(S))
# Out:
# Name:
# Type: Graph
# Number of nodes: 372
# Number of edges: 62697
# Average degree: 337.0806

# %% [markdown]
# Use **Spring Layout** to set the positions of the nodes

# %%
pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 3.75)

# %%
visualize_network_color_by_weighted_deg_and_logFC(S, pos, 'network colored by weighted deg and mean logFC nodes with high logFC')

# %% [markdown]
# ### [2.2] Run gene-enrichment analysis on genes within subnetwork

# %% [markdown]
# #### Load and prepare gene sets

# %% [markdown]
# DataFrame for the Gene Sets (excel files from Wen-Han)

# %%
GeneSets_df = pd.read_csv(f'{Gene_Set_dir}GeneModule.csv')

#subset to the IMMUNE modules
GeneSets_IMMUNE_df = GeneSets_df.loc[0:258, :] # 'LI' Immune Gene Sets
#GeneSets_IMMUNE_df = GeneSets_df.loc[259:297, :] # 'DC' Immune Gene Sets

#subset to the REACTOME modules
GeneSets_REACTOME_df = GeneSets_df.loc[993:1666, :]

# %%
GeneSets_IMMUNE_df.head()
# Out:
#         ID                                    Title            Category   B
# 0    LI.M0                       targets of FOSL1/2          TF targets  12
# 1  LI.M1.0   integrin cell surface interactions (I)  molecular function  29
# 2  LI.M1.1  integrin cell surface interactions (II)  molecular function  12
# 3  LI.M2.0                 extracellular matrix (I)            location  30
# 4  LI.M2.1                extracellular matrix (II)            location  45

# %%
np.shape(GeneSets_IMMUNE_df)
# Out:
# (259, 4)

# %%
GeneSets_REACTOME_df.head()
# Out:
#          ID                                              Title  \
# 993  M19193         Reactome glycogen breakdown glycogenolysis
# 994   M8229                               Reactome translation
# 995  M10654                     Reactome pyrimidine catabolism
# 996    M486  Reactome rna pol iii transcription initiation ...
# 997    M489  Reactome inhibition of the proteolytic activit...
#
#            Category    B
# 993  C2:CP:REACTOME   18
# 994  C2:CP:REACTOME  222
# 995  C2:CP:REACTOME   12
# 996  C2:CP:REACTOME   23
# 997  C2:CP:REACTOME   24

# %%
np.shape(GeneSets_REACTOME_df)
# Out:
# (674, 4)

# %% [markdown]
# DataFrame for the genes that belong to each Gene Set

# %%
GeneSet_GeneLists_df = pd.read_csv(f'{Gene_Set_dir}GeneModule_Genelist.csv')
GeneSet_GeneLists_df.set_index('ID', drop = True, inplace = True)

# %%
GeneSet_GeneLists_df.head()
# Out:
#        Gene
# ID
# LI.M0  CCL2
# LI.M0   DCN
# LI.M0   LIF
# LI.M0  PLAU
# LI.M0   IL6

# %%
np.shape(GeneSet_GeneLists_df)
# Out:
# (84042, 1)

# %% [markdown]
# #### Convert gene sets to a dictionary
# - keys: gene sets
# - values: list of genes belonging to each set

# %%
#Immune-specific gene sets
gene_set_IMMUNE_dict = {}
for gene_set_i in GeneSets_IMMUNE_df.ID:
    
    gene_list_for_set_i = list(GeneSet_GeneLists_df[GeneSet_GeneLists_df.index == gene_set_i].Gene)
    gene_set_IMMUNE_dict[gene_set_i] = gene_list_for_set_i

#Reactome gene sets
gene_set_REACTOME_dict = {}
for gene_set_i in GeneSets_REACTOME_df.ID:
    
    gene_list_for_set_i = list(GeneSet_GeneLists_df[GeneSet_GeneLists_df.index == gene_set_i].Gene)
    gene_set_REACTOME_dict[gene_set_i] = gene_list_for_set_i

# %%
len(gene_set_IMMUNE_dict.keys()) #number of gene sets
# Out:
# 259

# %%
len(gene_set_REACTOME_dict.keys()) #number of gene sets
# Out:
# 674

# %% [markdown]
# ### *Function* to run gene set enrichment

# %%
def run_enrichr_on_list_of_genes(gene_list, gene_set_category):
    
    #specify which gene sets we'll probe for enrichment
    if gene_set_category == 'IMMUNE':
        gene_set_dict = gene_set_IMMUNE_dict
    elif gene_set_category == 'REACTOME':
        gene_set_dict = gene_set_REACTOME_dict
    
    #run enrichr
    enr = gp.enrichr(gene_list = gene_list,  
        gene_sets = gene_set_dict,
        background = 'hsapiens_gene_ensembl',
        organism = 'Human',
        description = f'community pathway enrichment',
        outdir = f'{Data_files_dir}/enrichr gene set analyses bucket',
        no_plot = True)

    #filter & sort enrichr results df
    enrichr_results_df = enr.results
    enrichr_results_df = enrichr_results_df.loc[: , ['Term', 'P-value', 'Adjusted P-value', 'Overlap', 'Genes']] #subset to necessary columns
    enrichr_results_df.rename(columns = {'Term':'ID'}, inplace = True) #rename column for merging with Gene Set df
    enrichr_results_df = enrichr_results_df[enrichr_results_df.loc[: , 'Adjusted P-value'] <= 0.001] #keep hits with lowest adj. p-vals
    enrichr_results_df.sort_values(by = 'Adjusted P-value', ascending = True , inplace = True) #sort by lowest p-val
    enrichr_results_df.reset_index(inplace = True, drop = True) #reset index
    enrichr_results_df = enrichr_results_df.merge(GeneSets_df.loc[: , ['ID','Title','Category']], how = 'left', on = 'ID') #get details for gene sets
    
    #average the (mean logFC) for each gene detected as part of the gene set and append as another column
    avg_meanlogFC = [mean_logFC_series[enrichr_results_df.Genes[pathway_i].split(';')].mean() for pathway_i in enrichr_results_df.index]
    enrichr_results_df.loc[: , 'logFC'] = avg_meanlogFC
    
    return enrichr_results_df

# %% [markdown]
# Run **gene set enrichment** on genes in subnetwork

# %% [markdown]
# Pathway enrichment with **Immune** modules

# %%
run_enrichr_on_list_of_genes(list(S.nodes), 'IMMUNE')
# Out:
#            ID       P-value  Adjusted P-value Overlap  \
# 0    LI.M37.0  5.317418e-26      6.487249e-24  47/347
# 1      LI.M75  2.623444e-21      1.600301e-19   15/22
# 2    LI.M11.0  6.121860e-20      2.489557e-18  31/189
# 3     LI.M127  1.612054e-18      4.916764e-17   11/12
# 4     LI.M165  1.480548e-15      3.612537e-14   14/35
# 5     LI.M150  7.870711e-14      1.371752e-12    9/12
# 6      LI.M67  7.870711e-14      1.371752e-12    9/12
# 7   LI.M111.1  3.088177e-12      4.709470e-11    8/11
# 8      LI.M16  5.547178e-11      7.519508e-10   12/46
# 9     LI.M7.0  2.324823e-09      2.836284e-08   12/62
# 10     LI.M68  1.050089e-08      1.164644e-07    6/10
# 11     LI.M40  8.164055e-08      8.300123e-07    6/13
# 12    LI.M4.0  2.053512e-07      1.927142e-06  23/335
# 13    LI.M7.1  4.651178e-07      4.053169e-06    9/50
# 14  LI.M111.0  5.510313e-07      4.481721e-06    6/17
# 15     LI.M13  1.162130e-06      8.861244e-06    5/11
# 16  LI.M118.0  1.480610e-06      1.062555e-05    9/57
# 17      LI.S4  2.212097e-06      1.451971e-05   11/94
# 18    LI.M117  2.261266e-06      1.451971e-05    6/21
# 19    LI.M5.0  3.931296e-06      2.398090e-05   10/81
# 20    LI.M7.4  7.081460e-06      3.926992e-05    5/15
# 21    LI.M109  7.081460e-06      3.926992e-05    5/15
# 22  LI.M112.0  1.412907e-05      7.494551e-05    5/17
# 23     LI.M44  2.742792e-05      1.287002e-04    4/10
# 24    LI.M113  2.742792e-05      1.287002e-04    4/10
# 25    LI.M4.3  2.601104e-05      1.287002e-04    6/31
# 26     LI.M14  6.267526e-05      2.831993e-04    4/12
# 27     LI.S11  7.440063e-05      3.241742e-04    6/37
# 28   LI.M61.0  8.671164e-05      3.647869e-04    5/24
#
#                                                 Genes  \
# 0   LY96;CD177;MMP8;CEACAM6;CLEC4D;MCTP1;KCNJ15;LR...
# 1   ELANE;RSAD2;OAS3;OAS1;DDX58;CXCL10;C1QB;HERC5;...
# 2   SORT1;CD36;LILRA6;CYBB;IFI30;ALDH1A1;LMO2;EPB4...
# 3   RSAD2;PARP9;HERC5;TAP1;PLSCR1;IRF7;IFIT1;DDX60...
# 4   IFIT2;RSAD2;IFI27;ATF3;IFIT3;PARP9;PRRG4;TNFAI...
# 5   RSAD2;EIF2AK2;OASL;TAP1;PLSCR1;IRF7;OAS1;OAS3;...
# 6   C2;RSAD2;C1QC;DDX58;SERPING1;PLSCR1;IRF7;DDX60...
# 7    IFIT2;DDX58;CXCL10;ZBP1;CASP1;TAP1;TNFSF13B;BST2
# 8   LY96;P2RY13;LILRA6;BST1;KCNJ2;TLR8;FCGR1A;DYSF...
# 9   CD247;ITK;IL7R;CD27;CD96;ETS1;CD6;KLRB1;NELL2;...
# 10               DDX58;CXCL10;ISG15;IRF7;TRIM25;IFIH1
# 11                      LY96;C1QC;OLR1;TLR8;C1QB;C1QA
# 12  SORT1;CD36;LILRA6;CYBB;IFI30;LMO2;EPB41L3;FCGR...
# 13          TXK;CD247;CD5;ITK;IL7R;CD27;CCR7;CD7;LEF1
# 14                 ZBP1;IFI35;TAP1;TNFSF13B;BST2;TLR7
# 15                        DDX58;CXCL10;ZBP1;IRF7;AIM2
# 16  LY96;VNN1;DPYD;DYSF;TNFSF13B;MARC1;LRRK2;SMARC...
# 17  P2RY13;CD36;CLEC12A;MCTP1;DYSF;CCR2;AGTRAP;ASG...
# 18                   CXCR3;CD96;CD6;SPOCK2;NELL2;LEF1
# 19  LY96;MAPK14;CD247;ITK;MNDA;CD19;CCR7;TLR5;TLR7...
# 20                         ETS1;CD96;KLF12;NELL2;LEF1
# 21                         S1PR1;CCR7;CCR2;LRRK2;LEF1
# 22                         C2;C1QC;C1QB;SERPING1;C1QA
# 23                            MAPK14;IL23A;IFI30;IL7R
# 24                          SORT1;TLR8;FAM198B;LPCAT2
# 25                  GPBAR1;TLR8;MYOF;ASGR1;TLR5;MARCO
# 26                               SPOCK2;TXK;ITK;LRRN3
# 27            IFI27;PRRG4;CD274;TNFSF13B;IFI6;TMEM140
# 28                         CD247;PVRIG;CD96;KLRB1;CD7
#
#                                                 Title            Category  \
# 0                 immune activation - generic cluster              immune
# 1                             antiviral IFN signature              immune
# 2                          enriched in monocytes (II)              immune
# 3                          type I interferon response              immune
# 4          enriched in activated dendritic cells (II)              immune
# 5                           innate antiviral response              immune
# 6                           activated dendritic cells              immune
# 7   viral sensing & immunity; IRF2 targets network...              immune
# 8                      TLR and inflammatory signaling              immune
# 9                             enriched in T cells (I)              immune
# 10                      RIG-1 like receptor signaling              immune
# 11              complement and other receptors in DCs              immune
# 12                       cell cycle and transcription  biological process
# 13                              T cell activation (I)              immune
# 14  viral sensing & immunity; IRF2 targets network...              immune
# 15         innate activation by cytosolic DNA sensing              immune
# 16                         enriched in monocytes (IV)              immune
# 17                         Monocyte surface signature              immune
# 18                                 cell adhesion (GO)  molecular function
# 19  regulation of antigen presentation and immune ...              immune
# 20                            T cell activation (III)              immune
# 21                          receptors, cell migration  molecular function
# 22                          complement activation (I)              immune
# 23                 T cell signaling and costimulation              immune
# 24                                 golgi membrane (I)            location
# 25   myeloid cell enriched receptors and transporters              immune
# 26                             T cell differentiation              immune
# 27   Activated (LPS) dendritic cell surface signature              immune
# 28                          enriched in NK cells (II)              immune
#
#        logFC
# 0   0.634590
# 1   1.087366
# 2   0.713188
# 3   0.910252
# 4   1.077035
# 5   0.863285
# 6   1.166409
# 7   0.775062
# 8   0.990161
# 9  -0.692751
# 10  0.792091
# 11  0.804881
# 12  0.792591
# 13 -0.716859
# 14  0.748877
# 15  0.941108
# 16  0.764113
# 17  0.818665
# 18 -0.806442
# 19  0.332200
# 20 -0.749914
# 21 -0.240964
# 22  1.534473
# 23 -0.031499
# 24  0.696940
# 25  0.758664
# 26 -0.803379
# 27  0.804111
# 28 -0.614369

# %% [markdown]
# Pathway enrichment with **Reactome** modules

# %%
run_enrichr_on_list_of_genes(list(S.nodes), 'REACTOME')
# Out:
#        ID       P-value  Adjusted P-value Overlap  \
# 0   M1045  5.746342e-27      1.723903e-24  76/933
# 1    M983  1.488919e-24      2.233379e-22  33/159
# 2   M1060  8.153435e-21      8.153435e-19  37/270
# 3    M973  1.813580e-16      1.360185e-14   18/64
# 4   M1036  5.248722e-15      3.149233e-13  31/279
# 5    M965  5.196278e-14      2.598139e-12   16/63
# 6  M19752  2.268174e-06      9.720745e-05    7/32
# 7    M550  5.218711e-06      1.957017e-04    9/66
# 8    M985  2.601104e-05      8.670346e-04    6/31
#
#                                                Genes  \
# 0  LY96;GBP5;CD247;ITK;OAS1;CD36;PROS1;C1QB;UBE2L...
# 1  GBP5;UBE2L6;GBP1;IFITM3;ISG15;STAT1;IFI27;FLNB...
# 2  GBP5;UBE2L6;GBP1;IFITM3;ISG15;STAT1;IFI27;FLNB...
# 3  IFIT2;IFI27;XAF1;OAS1;IFIT3;IFI35;OASL;OAS2;IF...
# 4  LY96;PROS1;C1QB;UBE2L6;DEFA1B;ISG15;CCR2;AIM2;...
# 5  GBP5;OAS1;JAK2;GBP4;GBP6;OASL;FCGR1A;OAS2;GBP1...
# 6                   C2;C1QC;C4BPA;PROS1;C1QB;C5;C1QA
# 7  FLNB;DDX58;EIF2AK2;HERC5;UBE2L6;ISG15;IFIT1;ST...
# 8              DDX58;HERC5;UBE2L6;ISG15;TRIM25;IFIH1
#
#                                                Title        Category     logFC
# 0                             Reactome immune system  C2:CP:REACTOME  0.729931
# 1                      Reactome interferon signaling  C2:CP:REACTOME  0.940852
# 2       Reactome cytokine signaling in immune system  C2:CP:REACTOME  0.831985
# 3           Reactome interferon alpha beta signaling  C2:CP:REACTOME  0.893786
# 4                      Reactome innate immune system  C2:CP:REACTOME  0.822585
# 5                Reactome interferon gamma signaling  C2:CP:REACTOME  1.113092
# 6                        Reactome complement cascade  C2:CP:REACTOME  1.008820
# 7  Reactome antiviral mechanism by ifn stimulated...  C2:CP:REACTOME  0.597439
# 8  Reactome negative regulators of rig i mda5 sig...  C2:CP:REACTOME  0.797765

# %% [markdown]
# ## [3] Calculate *num edges*, *mean edge weight*, *num nodes* & *mean weighted degree*  for subgraphs induced by highest weighted edges

# %% [markdown]
# #### Edges Weights for Node Pairs (gene pairs)

# %%
edge_weight_dict = nx.get_edge_attributes(G, 'weight') #keys: node pairs; values: edge weights
edge_weight_array = np.array(list(edge_weight_dict.values())) #array of edge weights in graph

# %%
len(edge_weight_array)
# Out:
# 672127

# %%
edge_weight_array.mean()
# Out:
# 0.2537207006017215

# %% [markdown]
# #### Distribution of Edge Weights in original Network

# %%
def prettify_plot(ax):
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.grid(False)
    ax.tick_params(labelcolor = 'k')
    ax.tick_params(axis='y', which='major', labelsize=12 , labelcolor = 'k')
    ax.tick_params(axis='x', which='major', labelsize=12 , labelcolor = 'k')

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(1, 1, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])

#EDGE WEIGHTS
ax1.hist(edge_weight_array , bins = len(set(edge_weight_array)), color = 'black' , rwidth = 0.95 , edgecolor='white', linewidth=0.0, align='left')

ax1.set_ylabel('Number of Edges', fontsize = 12, color = 'k')
ax1.set_xlabel('Edge Weight' , fontsize = 12, color = 'k')

prettify_plot(ax1)
#ax1.set_yscale('log')
    
################### Plot ###################
fig = plt.gcf()
fig.set_size_inches(9, 5.5)
fig.tight_layout()

file_name = f'{figures_dir_path}/{comparison_X} distribution of edge weights in entire network.pdf'
plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()

# %%
edge_weight_thresholds = np.sort(np.array(list(set(edge_weight_array))))
edge_weight_thresholds
# Out:
# array([0.2       , 0.26666667, 0.33333333, 0.4       , 0.46666667,
#        0.53333333, 0.6       , 0.66666667, 0.73333333, 0.8       ,
#        0.86666667])

# %% [markdown]
# ### *Function* that returns attributes of a subgraph induced by setting a threshold on edge weights

# %%
def get_characteristics_of_subgraph(edge_weight_thresh):
    
    '''
    (1) This function returns the mean (edge weight) & (weighted degree) of the subgraph induced by the edges 
    that pass the edge weight threshold in the larger network.
    
    (2) Function returns the (# Edges) and (# Nodes) for these different subgraphs.
    '''
    
    #get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
    edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
    edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

    #get the SUBGRAPH induced by the most heavily weighted edges
    S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))

    #Get a series of the WEIGHTED DEGREE for each node in the subgraph 
    node_list = [node_deg[0] for node_deg in list(S.degree(weight = 'weight'))]
    degree_list = [node_deg[1] for node_deg in list(S.degree(weight = 'weight'))]
    subgraph_weighted_degree_series = pd.Series(degree_list , index = node_list).sort_values(ascending = False)
    
    return [float(len(edge_weight_array_subset)), edge_weight_array_subset.mean(), float(len(node_list)), subgraph_weighted_degree_series.mean()]

# %% [markdown]
# #### Iterate through subnetworks of various sizes for different *edge weight thresholds* in original network

# %%
num_edges_for_subnetworks_list = []
mean_edge_weight_for_subnetworks_list = []
num_nodes_for_subnetworks_list = []
mean_weighted_deg_for_subnetworks_list = []

for edge_weight_thresh in edge_weight_thresholds:
    
    subgraph_num_edges , subgraph_mean_edge_weight , subgraph_num_nodes , subgraph_mean_weighted_deg = get_characteristics_of_subgraph(edge_weight_thresh)
    
    num_edges_for_subnetworks_list.append(subgraph_num_edges)
    mean_edge_weight_for_subnetworks_list.append(subgraph_mean_edge_weight)
    num_nodes_for_subnetworks_list.append(subgraph_num_nodes)
    mean_weighted_deg_for_subnetworks_list.append(subgraph_mean_weighted_deg)
    
    print(edge_weight_thresh)
    
#convert to arrays
num_edges_for_subnetworks = np.array(num_edges_for_subnetworks_list)
mean_edge_weight_for_subnetworks = np.array(mean_edge_weight_for_subnetworks_list)
num_nodes_for_subnetworks = np.array(num_nodes_for_subnetworks_list)
mean_weighted_deg_for_subnetworks = np.array(mean_weighted_deg_for_subnetworks_list)
# Out:
# 0.2
# 0.26666666666666666
# 0.3333333333333333
# 0.4
# 0.4666666666666667
# 0.5333333333333333
# 0.6
# 0.6666666666666666
# 0.7333333333333333
# 0.8
# 0.8666666666666667

# %% [markdown]
# #### Plot various characteristics of subgraphs induced by highest weighted edges

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(2, 2, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])

#NUMBER OF EDGES
ax1.scatter(edge_weight_thresholds, num_edges_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax1.plot(edge_weight_thresholds, num_edges_for_subnetworks , color = 'black' , linewidth=1.0)

ax1.set_ylabel('Number of Edges in Subgraph', fontsize = 12, color = 'k')
ax1.set_title('# of Edges', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax1)

#EDGE WEIGHT
ax2.scatter(edge_weight_thresholds, mean_edge_weight_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax2.plot(edge_weight_thresholds, mean_edge_weight_for_subnetworks , color = 'black' , linewidth=1.0)

ax2.set_ylabel('Mean Edge Weight in Subgraph', fontsize = 12, color = 'k')
ax2.set_title('Mean Edge Weight', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax2)

#NUMBER OF NODES

#targeting sub-networks with around ~50-500 nodes
ax3.axhline(y = 500, linewidth = 1.0, color = 'green', linestyle = '--')
#ax3.axhline(y = 50, linewidth = 1.0, color = 'green', linestyle = '--')

ax3.scatter(edge_weight_thresholds, num_nodes_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax3.plot(edge_weight_thresholds, num_nodes_for_subnetworks , color = 'black' , linewidth=1.0)

ax3.set_ylabel('Number of Nodes in Subgraph', fontsize = 12, color = 'k')
ax3.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')
ax3.set_title('# of Nodes', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax3)
    
#WEIGHTED DEGREE
ax4.scatter(edge_weight_thresholds, mean_weighted_deg_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax4.plot(edge_weight_thresholds, mean_weighted_deg_for_subnetworks , color = 'black' , linewidth=1.0)

ax4.set_ylabel('Mean Weighted Degree in Subgraph', fontsize = 12, color = 'k')
ax4.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')
ax4.set_title('Mean Weighted Degree', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax4)
    
################### Plot ###################
fig = plt.gcf()
fig.set_size_inches(12, 10)
fig.tight_layout()

file_name = f'{figures_dir_path}/{comparison_X} characteristics of subgraphs from increasing edge weight threshold.pdf'
plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()

# %% [markdown]
# How does the **edge weight threshold** affect the **number of nodes** in the subnetwork?

# %%
for edge_weight_thresh_i, num_nodes_subnetwork_i in zip(edge_weight_thresholds, num_nodes_for_subnetworks):
    print(f'Edge Weight Threshold = {edge_weight_thresh_i} , Number of Nodes in Subnetwork = {num_nodes_subnetwork_i}')
# Out:
# Edge Weight Threshold = 0.2 , Number of Nodes in Subnetwork = 3005.0
# Edge Weight Threshold = 0.26666666666666666 , Number of Nodes in Subnetwork = 1580.0
# Edge Weight Threshold = 0.3333333333333333 , Number of Nodes in Subnetwork = 1038.0
# Edge Weight Threshold = 0.4 , Number of Nodes in Subnetwork = 726.0
# Edge Weight Threshold = 0.4666666666666667 , Number of Nodes in Subnetwork = 502.0
# Edge Weight Threshold = 0.5333333333333333 , Number of Nodes in Subnetwork = 342.0
# Edge Weight Threshold = 0.6 , Number of Nodes in Subnetwork = 227.0
# Edge Weight Threshold = 0.6666666666666666 , Number of Nodes in Subnetwork = 141.0
# Edge Weight Threshold = 0.7333333333333333 , Number of Nodes in Subnetwork = 81.0
# Edge Weight Threshold = 0.8 , Number of Nodes in Subnetwork = 38.0
# Edge Weight Threshold = 0.8666666666666667 , Number of Nodes in Subnetwork = 9.0

# %% [markdown]
# We're aiming to run enrichment analysis on **~50-500 nodes** so we have to adjust the edge-weight thresholds for this.

# %%
print(edge_weight_thresholds[4:-1])
# Out:
# [0.46666667 0.53333333 0.6        0.66666667 0.73333333 0.8       ]

# %%
edge_weight_thresholds = edge_weight_thresholds[4:-1]

# %% [markdown]
# ## [4] Iterate through subnetworks constructed from most heavily weighted edges and preform gene enrichment analysis

# %% [markdown]
# ### *Function* to plot subnetworks (after thresholding edge weights) & perform gene enrichment on nodes

# %%
def subgraph_visualize_and_gene_enrichment(edge_weight_thresh, gene_set_category):
    
    '''
    (1) This function returns visualizes the sub-network generated by 
    retaining only the edge weights above the input edge weight threshold.
        (1.1) colors nodes by weighted degree
        (1.2) colors nodes by mean logFC
        
    (2) This function also returns a dataframe from the gene enrichment 
    analysis run on the nodes of the subnetwork.
    '''
    
    #get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
    edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
    edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

    #get the SUBGRAPH induced by the most heavily weighted edges
    S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))
    
    #print some stats
    print('')
    print('')
    print('')
    print('')
    print(f'Edge Weight Threshold = {edge_weight_thresh}')
    print(f'Number of Nodes = {len(S.nodes)}')
    print('---------------------------------------------')
    
    #visualize subgraph
    pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 3.0)
    visualize_network_color_by_weighted_deg_and_logFC(S, pos)
    
    #gene set enrichment
    gene_enrichr_df = run_enrichr_on_list_of_genes(list(S.nodes), gene_set_category)
    print(f'gene enrichment for nodes in this network: ')
    display(gene_enrichr_df.head(n=40)) #return the top 40 hits if there are > 40
    print('---------------------------------------------')
    
    ## return gene_enrichr_df #uncomment to return dataframe

# %% [markdown]
# #### Iterate through subnetworks of various sizes for different *edge weight thresholds* in original network

# %% [markdown]
# We're going to start with the largest **edge weight threshold** and iterate up from there (decrease edge weight threshold but decrease # of nodes) to preform gene enrichment

# %% [markdown]
# ### [4.1] Using *Immune* Gene Sets for gene enrichment

# %%
for edge_weight_thresh in reversed(edge_weight_thresholds):
    
    subgraph_visualize_and_gene_enrichment(edge_weight_thresh, 'IMMUNE')
# Out:
# Edge Weight Threshold = 0.8
# Number of Nodes = 38
# ---------------------------------------------
# gene enrichment for nodes in this network:
#         ID       P-value  Adjusted P-value Overlap  \
# 0   LI.M16  3.110499e-08          0.000002    5/46
# 1  LI.M5.0  2.009256e-05          0.000542    4/81
#
#                            Genes  \
# 0  KCNJ2;KCNJ15;TLR5;TLR7;FCGR1B
# 1          TLR7;TLR5;FCGR1B;CCR7
#
#                                                Title Category     logFC
# 0                     TLR and inflammatory signaling   immune  1.135627
# 1  regulation of antigen presentation and immune ...   immune  0.721589
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.7333333333333333
# Number of Nodes = 81
# ---------------------------------------------
# gene enrichment for nodes in this network:
#          ID       P-value  Adjusted P-value Overlap  \
# 0    LI.M16  4.014745e-08          0.000003    6/46
# 1   LI.M165  1.439131e-05          0.000373    4/35
# 2  LI.M37.0  1.644607e-05          0.000373   9/347
#
#                                                Genes  \
# 0                 BST1;KCNJ2;KCNJ15;TLR5;TLR7;FCGR1B
# 1                         IFIT3;PARP9;SERPING1;IFIT2
# 2  SMCO4;STX11;CEACAM1;BST1;HCAR3;KCNJ15;LRRK2;TL...
#
#                                         Title Category     logFC
# 0              TLR and inflammatory signaling   immune  1.064768
# 1  enriched in activated dendritic cells (II)   immune  1.510122
# 2         immune activation - generic cluster   immune  0.839493
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6666666666666666
# Number of Nodes = 141
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     LI.M127  8.068521e-13      6.616187e-11    7/12
# 1      LI.M75  2.167810e-12      8.888020e-11    8/22
# 2    LI.M37.0  1.151906e-11      3.148543e-10  19/347
# 3      LI.M16  4.517370e-11      9.260609e-10    9/46
# 4     LI.M165  1.471489e-10      2.011036e-09    8/35
# 5      LI.M67  1.319746e-10      2.011036e-09    6/12
# 6   LI.M111.1  9.243314e-09      1.082788e-07    5/11
# 7    LI.M11.0  1.651042e-07      1.692318e-06  11/189
# 8   LI.M118.0  2.040438e-07      1.859066e-06    7/57
# 9     LI.M7.0  3.680367e-07      3.017901e-06    7/62
# 10  LI.M111.0  6.362630e-06      4.743052e-05    4/17
# 11    LI.M5.0  3.047852e-05      2.082699e-04    6/81
# 12     LI.M13  6.279524e-05      3.678007e-04    3/11
# 13     LI.M18  6.279524e-05      3.678007e-04    3/11
# 14    LI.M150  8.327298e-05      4.552256e-04    3/12
# 15   LI.M86.1  1.362895e-04      6.573966e-04    3/14
# 16     LI.M65  1.362895e-04      6.573966e-04    3/14
# 17    LI.M7.4  1.694391e-04      7.312633e-04    3/15
# 18    LI.M109  1.694391e-04      7.312633e-04    3/15
# 19    LI.M4.0  2.003700e-04      8.215168e-04  10/335
#
#                                                 Genes  \
# 0           RSAD2;PARP9;TAP1;PLSCR1;DDX60;STAT1;IFIH1
# 1    RSAD2;DDX58;C1QB;ANXA3;SERPING1;IFIH1;DDX60;IL1B
# 2   LY96;HP;SMCO4;STX11;CEACAM1;SLC26A8;OSCAR;PRRG...
# 3   LY96;BST1;KCNJ2;FCGR1A;DYSF;KCNJ15;TLR5;TLR7;F...
# 4   IFIT2;RSAD2;IFIT3;PARP9;PRRG4;TNFAIP6;SERPING1...
# 5             RSAD2;DDX58;SERPING1;PLSCR1;DDX60;IFIH1
# 6                     IFIT2;DDX58;CASP1;TNFSF13B;TAP1
# 7   PLAUR;HPSE;SORT1;BST1;EPB41L3;FCGR1A;TYMP;MYOF...
# 8         LY96;HCAR3;DYSF;TNFSF13B;LRRK2;SMARCD3;LTBR
# 9                  ETS1;ITK;IL7R;CD6;KLRB1;NELL2;GZMK
# 10                           TLR7;IFI35;TAP1;TNFSF13B
# 11                     LY96;ITK;CCR7;TLR5;TLR7;FCGR1B
# 12                                    DDX58;AIM2;IL1B
# 13                                    SPOCK2;ETS1;ITK
# 14                                  RSAD2;TAP1;PLSCR1
# 15                                  GCH1;TNFAIP6;IL1B
# 16                                      CCR7;ITK;IL7R
# 17                                   NELL2;KLF12;ETS1
# 18                                   LRRK2;CCR7;S1PR1
# 19  PLAUR;HPSE;SORT1;EPB41L3;FCGR1A;TYMP;MYOF;NOD2...
#
#                                                 Title            Category  \
# 0                          type I interferon response              immune
# 1                             antiviral IFN signature              immune
# 2                 immune activation - generic cluster              immune
# 3                      TLR and inflammatory signaling              immune
# 4          enriched in activated dendritic cells (II)              immune
# 5                           activated dendritic cells              immune
# 6   viral sensing & immunity; IRF2 targets network...              immune
# 7                          enriched in monocytes (II)              immune
# 8                          enriched in monocytes (IV)              immune
# 9                             enriched in T cells (I)              immune
# 10  viral sensing & immunity; IRF2 targets network...              immune
# 11  regulation of antigen presentation and immune ...              immune
# 12         innate activation by cytosolic DNA sensing              immune
# 13             T cell differentiation via ITK and PKC              immune
# 14                          innate antiviral response              immune
# 15  proinflammatory dendritic cell, myeloid cell r...              immune
# 16                              IL2, IL7, TCR network              immune
# 17                            T cell activation (III)              immune
# 18                          receptors, cell migration  molecular function
# 19                       cell cycle and transcription  biological process
#
#        logFC
# 0   1.048049
# 1   1.289749
# 2   0.855092
# 3   1.104388
# 4   1.274367
# 5   1.345405
# 6   0.800885
# 7   1.011940
# 8   0.717179
# 9  -0.768613
# 10  0.851131
# 11  0.528822
# 12  0.951834
# 13 -0.669851
# 14  1.162391
# 15  0.667335
# 16 -0.853888
# 17 -0.835898
# 18 -0.362592
# 19  1.027817
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6
# Number of Nodes = 227
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0      LI.M75  3.582759e-18      3.726069e-16   12/22
# 1     LI.M127  8.851514e-16      4.602787e-14    9/12
# 2    LI.M37.0  1.110735e-14      2.887911e-13  27/347
# 3    LI.M11.0  1.070957e-14      2.887911e-13  21/189
# 4   LI.M111.1  5.770973e-14      1.200362e-12    8/11
# 5      LI.M67  1.713589e-13      2.970221e-12    8/12
# 6     LI.M7.0  7.870285e-12      1.039243e-10   12/62
# 7   LI.M111.0  7.994175e-12      1.039243e-10    8/17
# 8     LI.M150  2.339094e-09      2.702953e-08    6/12
# 9      LI.M16  3.117680e-09      3.242387e-08    9/46
# 10    LI.M165  6.433853e-09      6.082916e-08    8/35
# 11     LI.M13  1.004288e-07      8.703830e-07    5/11
# 12    LI.M7.1  1.258472e-07      1.006777e-06    8/50
# 13    LI.M5.0  5.143277e-07      3.820720e-06    9/81
# 14    LI.M4.0  6.014413e-07      4.080846e-06  17/335
# 15    LI.M7.4  6.278224e-07      4.080846e-06    5/15
# 16    LI.M117  4.012852e-06      2.454921e-05    5/21
# 17  LI.M118.0  4.970853e-06      2.872048e-05    7/57
# 18      LI.S4  1.664185e-05      9.109224e-05    8/94
# 19    LI.M109  2.422007e-05      1.259444e-04    4/15
# 20   LI.M61.0  1.733042e-04      8.529071e-04    4/24
# 21     LI.M44  1.886237e-04      8.529071e-04    3/10
# 22     LI.M68  1.886237e-04      8.529071e-04    3/10
#
#                                                 Genes  \
# 0   RSAD2;OAS1;DDX58;C1QB;ANXA3;SERPING1;PML;IRF7;...
# 1   RSAD2;PARP9;TAP1;PLSCR1;IRF7;DDX60;STAT1;IFITM...
# 2   LY96;OSCAR;CLEC4D;MCTP1;KCNJ15;LRRK2;PRRG4;HCA...
# 3   PLAUR;SORT1;CYBB;IFI30;LMO2;EPB41L3;FCGR1A;TYM...
# 4     IFIT2;DDX58;ZBP1;CASP1;TAP1;TNFSF13B;BST2;PSMB8
# 5   RSAD2;C1QC;DDX58;SERPING1;PLSCR1;IRF7;DDX60;IFIH1
# 6   CD247;ITK;IL7R;CD27;CD96;ETS1;GZMK;CD6;KLRB1;N...
# 7       ZBP1;IFI35;KYNU;TAP1;TNFSF13B;BST2;TLR7;PSMB8
# 8                    RSAD2;OASL;TAP1;PLSCR1;IRF7;OAS1
# 9   LY96;BST1;KCNJ2;FCGR1A;DYSF;KCNJ15;TLR5;TLR7;F...
# 10  IFIT2;RSAD2;IFIT3;PARP9;PRRG4;TNFAIP6;SERPING1...
# 11                          DDX58;ZBP1;IRF7;AIM2;IL1B
# 12             CD247;CD5;ITK;IL7R;CD27;CCR7;LEF1;CD28
# 13   LY96;MAPK14;CD247;ITK;CD19;CCR7;TLR5;TLR7;FCGR1B
# 14  PLAUR;DMXL2;HPSE;LMO2;STAB1;SORT1;EPB41L3;FCGR...
# 15                         ETS1;CD96;KLF12;NELL2;LEF1
# 16                         CD96;CD6;SPOCK2;NELL2;LEF1
# 17        LY96;HCAR3;DYSF;TNFSF13B;LRRK2;SMARCD3;LTBR
# 18     HCAR3;MCTP1;DYSF;TLR5;LTBR;MARCO;FCGR1B;FCER1A
# 19                              LRRK2;LEF1;CCR7;S1PR1
# 20                             PVRIG;CD247;KLRB1;CD96
# 21                                  MAPK14;IFI30;IL7R
# 22                                   DDX58;IFIH1;IRF7
#
#                                                 Title            Category  \
# 0                             antiviral IFN signature              immune
# 1                          type I interferon response              immune
# 2                 immune activation - generic cluster              immune
# 3                          enriched in monocytes (II)              immune
# 4   viral sensing & immunity; IRF2 targets network...              immune
# 5                           activated dendritic cells              immune
# 6                             enriched in T cells (I)              immune
# 7   viral sensing & immunity; IRF2 targets network...              immune
# 8                           innate antiviral response              immune
# 9                      TLR and inflammatory signaling              immune
# 10         enriched in activated dendritic cells (II)              immune
# 11         innate activation by cytosolic DNA sensing              immune
# 12                              T cell activation (I)              immune
# 13  regulation of antigen presentation and immune ...              immune
# 14                       cell cycle and transcription  biological process
# 15                            T cell activation (III)              immune
# 16                                 cell adhesion (GO)  molecular function
# 17                         enriched in monocytes (IV)              immune
# 18                         Monocyte surface signature              immune
# 19                          receptors, cell migration  molecular function
# 20                          enriched in NK cells (II)              immune
# 21                 T cell signaling and costimulation              immune
# 22                      RIG-1 like receptor signaling              immune
#
#        logFC
# 0   1.025110
# 1   0.954381
# 2   0.713972
# 3   0.778576
# 4   0.692782
# 5   1.231202
# 6  -0.685099
# 7   0.659994
# 8   0.959007
# 9   1.104388
# 10  1.274367
# 11  0.798322
# 12 -0.693410
# 13  0.310037
# 14  0.811681
# 15 -0.749914
# 16 -0.803369
# 17  0.717179
# 18  0.733394
# 19 -0.452267
# 20 -0.620593
# 21  0.131616
# 22  0.729172
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.5333333333333333
# Number of Nodes = 342
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0      LI.M75  5.595363e-24      7.218018e-22   16/22
# 1    LI.M37.0  3.410349e-19      2.199675e-17  38/347
# 2    LI.M11.0  6.668830e-19      2.867597e-17  29/189
# 3     LI.M127  1.960507e-16      6.322636e-15   10/12
# 4   LI.M111.1  9.339562e-15      2.300270e-13    9/11
# 5     LI.M7.0  1.069893e-14      2.300270e-13   16/62
# 6     LI.M150  4.643129e-12      7.487045e-11    8/12
# 7      LI.M67  4.643129e-12      7.487045e-11    8/12
# 8     LI.M165  1.518313e-11      2.176248e-10   11/35
# 9     LI.M7.1  6.122445e-11      7.897955e-10   12/50
# 10  LI.M111.0  2.108060e-10      2.472180e-09    8/17
# 11    LI.M4.0  2.129574e-09      2.289293e-08  25/335
# 12     LI.M68  6.352654e-09      6.303788e-08    6/10
# 13     LI.M16  7.037802e-09      6.484832e-08   10/46
# 14      LI.S4  1.313079e-08      1.109772e-07   13/94
# 15     LI.M13  1.376462e-08      1.109772e-07    6/11
# 16    LI.M5.0  2.165927e-08      1.643556e-07   12/81
# 17     LI.M14  2.711329e-08      1.943119e-07    6/12
# 18    LI.M117  1.388672e-06      9.428353e-06    6/21
# 19    LI.M7.2  2.369294e-06      1.528194e-05    8/49
# 20   LI.M61.0  3.291145e-06      2.021703e-05    6/24
# 21    LI.M109  4.701927e-06      2.637168e-05    5/15
# 22    LI.M7.4  4.701927e-06      2.637168e-05    5/15
# 23  LI.M118.0  7.662303e-06      4.118488e-05    8/57
# 24    LI.M4.3  1.619159e-05      8.354861e-05    6/31
# 25      LI.M3  1.923526e-05      9.543647e-05    7/47
# 26     LI.M18  3.054458e-05      1.459352e-04    4/11
# 27   LI.M37.1  3.788966e-05      1.745631e-04    7/52
# 28     LI.M56  4.516865e-05      2.009226e-04    4/12
# 29      LI.S0  1.058703e-04      4.552425e-04    5/27
# 30     LI.M19  2.022653e-04      8.153819e-04    4/17
# 31     LI.M64  2.022653e-04      8.153819e-04    4/17
#
#                                                 Genes  \
# 0   ELANE;RSAD2;OAS3;OAS1;DDX58;CXCL10;C1QB;HERC5;...
# 1   LY96;OSCAR;CLEC4D;MCTP1;KCNJ15;LRRK2;CREB5;PRR...
# 2   PLAUR;MAFB;SORT1;CYBB;IFI30;CD14;LMO2;TLR2;FCE...
# 3   RSAD2;PARP9;HERC5;TAP1;PLSCR1;IRF7;DDX60;STAT1...
# 4   IFIT2;DDX58;CXCL10;ZBP1;CASP1;TAP1;TNFSF13B;BS...
# 5   PRKCH;CD247;ITK;IL7R;CD27;CD96;ETS1;GZMK;CD3G;...
# 6       RSAD2;EIF2AK2;OASL;TAP1;PLSCR1;IRF7;OAS1;OAS3
# 7   RSAD2;C1QC;DDX58;SERPING1;PLSCR1;IRF7;DDX60;IFIH1
# 8   IFIT2;RSAD2;ATF3;IFIT3;PARP9;PRRG4;TNFAIP6;HER...
# 9   PRKCH;TXK;CD247;CD5;ITK;IL7R;CD27;CD3G;CCR7;CD...
# 10      ZBP1;IFI35;KYNU;TAP1;TNFSF13B;BST2;TLR7;PSMB8
# 11  PLAUR;MAFB;SORT1;CYBB;IFI30;CD14;LMO2;FCER1G;T...
# 12               DDX58;CXCL10;ISG15;IRF7;TRIM25;IFIH1
# 13  LY96;TLR2;KCNJ2;BST1;FCGR1A;DYSF;KCNJ15;TLR5;T...
# 14  TLR2;ABCA1;HCAR3;MCTP1;DYSF;CCR2;AGTRAP;ASGR1;...
# 15                   DDX58;CXCL10;ZBP1;IRF7;AIM2;IL1B
# 16  LY96;MAPK14;CD247;ITK;FCER1G;TLR2;CD3G;CD19;CC...
# 17                      TXK;ITK;LRRN3;SPOCK2;MAL;CD28
# 18                   CXCR3;CD96;CD6;SPOCK2;NELL2;LEF1
# 19       KLRF1;PRKCH;CLIC3;CD247;ITK;CD96;KLRB1;ARL4C
# 20                   KLRF1;CD247;PVRIG;CD96;KLRB1;CD7
# 21                         S1PR1;CCR7;CCR2;LRRK2;LEF1
# 22                         ETS1;CD96;KLF12;NELL2;LEF1
# 23   LY96;HCAR3;DYSF;TNFSF13B;LRRK2;SMARCD3;NAIP;LTBR
# 24                  GPBAR1;MYOF;ASGR1;TLR5;MARCO;CD14
# 25            HPSE;TLR2;S100A12;TLR5;IL1RN;ADAP2;NOD2
# 26                              PRKCH;ETS1;ITK;SPOCK2
# 27        FFAR2;CREB5;HCAR3;SLC22A4;LRG1;KCNJ15;MSRB1
# 28                           DUSP3;IL1B;CACNA2D3;CD14
# 29                            CD3G;CD6;LRRN3;MAL;CD28
# 30                                 CD28;GZMK;MAL;CD3G
# 31                              SOD2;DRAM1;IL1B;IL1RN
#
#                                                 Title            Category  \
# 0                             antiviral IFN signature              immune
# 1                 immune activation - generic cluster              immune
# 2                          enriched in monocytes (II)              immune
# 3                          type I interferon response              immune
# 4   viral sensing & immunity; IRF2 targets network...              immune
# 5                             enriched in T cells (I)              immune
# 6                           innate antiviral response              immune
# 7                           activated dendritic cells              immune
# 8          enriched in activated dendritic cells (II)              immune
# 9                               T cell activation (I)              immune
# 10  viral sensing & immunity; IRF2 targets network...              immune
# 11                       cell cycle and transcription  biological process
# 12                      RIG-1 like receptor signaling              immune
# 13                     TLR and inflammatory signaling              immune
# 14                         Monocyte surface signature              immune
# 15         innate activation by cytosolic DNA sensing              immune
# 16  regulation of antigen presentation and immune ...              immune
# 17                             T cell differentiation              immune
# 18                                 cell adhesion (GO)  molecular function
# 19                           enriched in NK cells (I)              immune
# 20                          enriched in NK cells (II)              immune
# 21                          receptors, cell migration  molecular function
# 22                            T cell activation (III)              immune
# 23                         enriched in monocytes (IV)              immune
# 24   myeloid cell enriched receptors and transporters              immune
# 25                  regulation of signal transduction           signaling
# 26             T cell differentiation via ITK and PKC              immune
# 27                        enriched in neutrophils (I)              immune
# 28                      suppression of MAPK signaling           signaling
# 29                           T cell surface signature              immune
# 30                       T cell differentiation (Th2)              immune
# 31    enriched in activated dendritic cells/monocytes              immune
#
#        logFC
# 0   0.982280
# 1   0.548095
# 2   0.666786
# 3   0.935580
# 4   0.738843
# 5  -0.628138
# 6   0.889074
# 7   1.231202
# 8   1.155651
# 9  -0.642611
# 10  0.659994
# 11  0.699864
# 12  0.792091
# 13  1.038182
# 14  0.639690
# 15  0.849823
# 16  0.279970
# 17 -0.698128
# 18 -0.806442
# 19 -0.517426
# 20 -0.548087
# 21 -0.240964
# 22 -0.749914
# 23  0.715704
# 24  0.730406
# 25  0.602329
# 26 -0.608646
# 27  0.530562
# 28  0.296205
# 29 -0.602450
# 30 -0.485112
# 31  0.355115
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.4666666666666667
# Number of Nodes = 502
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0    LI.M11.0  1.276332e-33      1.825155e-31  48/189
# 1    LI.M37.0  5.242041e-29      3.748059e-27  57/347
# 2      LI.M75  1.860553e-25      8.868636e-24   18/22
# 3     LI.M7.0  3.104006e-18      1.109682e-16   21/62
# 4     LI.M127  4.500670e-17      1.287192e-15   11/12
# 5     LI.M165  9.151150e-14      1.894385e-12   14/35
# 6     LI.M7.1  9.273213e-14      1.894385e-12   16/50
# 7     LI.M4.0  1.810018e-13      3.235407e-12  37/335
# 8   LI.M111.1  3.009540e-13      4.781825e-12    9/11
# 9     LI.M150  1.175762e-12      1.528491e-11    9/12
# 10     LI.M67  1.175762e-12      1.528491e-11    9/12
# 11     LI.M16  7.251589e-12      8.641477e-11   14/46
# 12      LI.S4  3.960994e-11      4.357093e-10   18/94
# 13     LI.M14  9.965010e-11      1.017855e-09    8/12
# 14  LI.M111.0  1.154805e-10      1.100914e-09    9/17
# 15    LI.M5.0  2.765137e-09      2.471341e-08   15/81
# 16    LI.M4.3  4.002605e-09      3.366897e-08   10/31
# 17     LI.M81  1.506911e-08      1.197157e-07   10/35
# 18    LI.M7.2  4.517064e-08      3.098235e-07   11/49
# 19    LI.M7.4  4.549855e-08      3.098235e-07    7/15
# 20    LI.M109  4.549855e-08      3.098235e-07    7/15
# 21     LI.M68  6.257588e-08      4.067432e-07    6/10
# 22     LI.M13  1.345975e-07      8.019768e-07    6/11
# 23     LI.M18  1.345975e-07      8.019768e-07    6/11
# 24  LI.M118.0  2.364564e-07      1.352531e-06   11/57
# 25      LI.S0  3.152220e-07      1.733721e-06    8/27
# 26   LI.M61.0  1.990894e-06      1.054437e-05    7/24
# 27      LI.M3  3.200374e-06      1.578116e-05    9/47
# 28  LI.M112.0  3.150008e-06      1.578116e-05    6/17
# 29   LI.M37.1  7.687261e-06      3.664261e-05    9/52
# 30     LI.M56  8.483867e-06      3.913526e-05    5/12
# 31    LI.M7.3  1.288930e-05      5.585365e-05    7/31
# 32    LI.M117  1.262477e-05      5.585365e-05    6/21
# 33   LI.M43.1  2.052642e-05      8.633170e-05    5/14
# 34     LI.M87  2.927701e-05      1.164228e-04    6/24
# 35   LI.M43.0  3.012337e-05      1.164228e-04    5/15
# 36     LI.M24  3.012337e-05      1.164228e-04    5/15
# 37     LI.M44  8.835203e-05      3.158585e-04    4/10
# 38    LI.M113  8.835203e-05      3.158585e-04    4/10
# 39    LI.M209  8.835203e-05      3.158585e-04    4/10
#
#                                                 Genes  \
# 0   PLAUR;MAFB;SORT1;SIRPB1;PLXDC2;MS4A7;CD36;IGSF...
# 1   LY96;SH2D1A;SIRPB1;PLXDC2;MS4A7;OSCAR;CLEC4D;M...
# 2   ELANE;RSAD2;OAS3;OAS1;DDX58;CXCL10;C1QB;IL1B;H...
# 3   SH2D1A;CD247;ITK;CD6;PTPRCAP;KLRB1;MAL;NELL2;L...
# 4   RSAD2;PARP9;HERC5;TAP1;PLSCR1;IRF7;IFIT1;DDX60...
# 5   IFIT2;RSAD2;IFI27;ATF3;IFIT3;PARP9;PRRG4;RBM47...
# 6   PRKCH;TXK;CD247;ITK;CD5;IL7R;CD27;ITPR3;CD3G;C...
# 7   PLAUR;MAFB;SORT1;CD36;IGSF6;CYBB;IFI30;TLR4;CD...
# 8   IFIT2;DDX58;CXCL10;ZBP1;CASP1;TAP1;TNFSF13B;BS...
# 9   RSAD2;EIF2AK2;OASL;TAP1;PLSCR1;IRF7;OAS1;OAS3;...
# 10  C2;RSAD2;C1QC;DDX58;SERPING1;PLSCR1;IRF7;DDX60...
# 11  LY96;HSPA6;TLR2;KCNJ2;BST1;TLR8;FCGR1A;DYSF;KC...
# 12  CCR1;SIRPB1;CD36;MARCO;TLR2;ABCA1;HCAR3;MCTP1;...
# 13       SH2D1A;TXK;CD28;ITK;LRRN3;SPOCK2;MAL;RASGRP1
# 14  CXCL16;ZBP1;IFI35;KYNU;TAP1;TNFSF13B;BST2;TLR7...
# 15  LY96;MAPK14;CD247;ITK;TLR2;FCER1G;CD3G;CD19;CC...
# 16  CCR1;GPBAR1;TLR8;IGSF6;MYOF;SECTM1;TLR5;ASGR1;...
# 17  ITGA2B;LIN7A;PROS1;FCER1G;ITGB3;CCR2;SELP;TLR7...
# 18  KLRF1;PRKCH;CLIC3;CD247;ITK;PTGDR;CD96;KLRB1;A...
# 19          ETS1;CD96;KLF12;THEMIS;NELL2;LEF1;RASGRP1
# 20              CCR1;S1PR1;CCR7;C3AR1;CCR2;LRRK2;LEF1
# 21               DDX58;CXCL10;ISG15;IRF7;TRIM25;IFIH1
# 22                   DDX58;CXCL10;ZBP1;IRF7;AIM2;IL1B
# 23                PRKCH;SH2D1A;ETS1;ITK;ABLIM1;SPOCK2
# 24  LY96;VNN1;HCAR3;DYSF;LRRK2;TNFSF13B;SMARCD3;NA...
# 25       CD3G;CD6;LRRN3;MAL;SLC38A1;PTPRCAP;CD28;CD3E
# 26             KLRF1;CD247;PVRIG;CD96;KLRB1;CD7;IL2RB
# 27  CCR1;HPSE;TLR2;S100A12;TLR5;IL1RN;ADAP2;NOD2;CD3E
# 28                    C2;C1QC;CR1;C1QB;SERPING1;C3AR1
# 29  FFAR2;CREB5;LIN7A;HCAR3;SLC22A4;LRG1;KCNJ15;ST...
# 30                     HSPA6;DUSP3;CACNA2D3;IL1B;CD14
# 31            CXCR3;CD247;ITK;CD3G;PTPRCAP;CD3E;SP140
# 32                   CXCR3;CD96;CD6;SPOCK2;NELL2;LEF1
# 33                        ICAM1;IL23A;RELB;BCL3;IL1RN
# 34                    HK3;CD36;TLR2;SLC22A4;AQP9;TLR4
# 35                       SAMSN1;ICAM1;IL23A;RELB;BCL3
# 36                     IL15;SERPING1;IL23A;BCL3;SBNO2
# 37                            MAPK14;IL23A;IFI30;IL7R
# 38                           STEAP4;SORT1;TLR8;LPCAT2
# 39                               GM2A;CTSZ;SORT1;CTSL
#
#                                                 Title            Category  \
# 0                          enriched in monocytes (II)              immune
# 1                 immune activation - generic cluster              immune
# 2                             antiviral IFN signature              immune
# 3                             enriched in T cells (I)              immune
# 4                          type I interferon response              immune
# 5          enriched in activated dendritic cells (II)              immune
# 6                               T cell activation (I)              immune
# 7                        cell cycle and transcription  biological process
# 8   viral sensing & immunity; IRF2 targets network...              immune
# 9                           innate antiviral response              immune
# 10                          activated dendritic cells              immune
# 11                     TLR and inflammatory signaling              immune
# 12                         Monocyte surface signature              immune
# 13                             T cell differentiation              immune
# 14  viral sensing & immunity; IRF2 targets network...              immune
# 15  regulation of antigen presentation and immune ...              immune
# 16   myeloid cell enriched receptors and transporters              immune
# 17            enriched in myeloid cells and monocytes              immune
# 18                           enriched in NK cells (I)              immune
# 19                            T cell activation (III)              immune
# 20                          receptors, cell migration  molecular function
# 21                      RIG-1 like receptor signaling              immune
# 22         innate activation by cytosolic DNA sensing              immune
# 23             T cell differentiation via ITK and PKC              immune
# 24                         enriched in monocytes (IV)              immune
# 25                           T cell surface signature              immune
# 26                          enriched in NK cells (II)              immune
# 27                  regulation of signal transduction           signaling
# 28                          complement activation (I)              immune
# 29                        enriched in neutrophils (I)              immune
# 30                      suppression of MAPK signaling           signaling
# 31                             T cell activation (II)              immune
# 32                                 cell adhesion (GO)  molecular function
# 33   myeloid, dendritic cell activation via NFkB (II)              immune
# 34                        transmembrane transport (I)  molecular function
# 35    myeloid, dendritic cell activation via NFkB (I)              immune
# 36                  cell activation (IL15, IL23, TNF)              immune
# 37                 T cell signaling and costimulation              immune
# 38                                 golgi membrane (I)            location
# 39                                           lysosome            location
#
#        logFC
# 0   0.586283
# 1   0.490869
# 2   0.910279
# 3  -0.557615
# 4   0.910252
# 5   1.057776
# 6  -0.585209
# 7   0.633442
# 8   0.738843
# 9   0.863285
# 10  1.166409
# 11  0.864099
# 12  0.592457
# 13 -0.611144
# 14  0.589455
# 15  0.205356
# 16  0.622513
# 17  0.555729
# 18 -0.459323
# 19 -0.639535
# 20 -0.080953
# 21  0.792091
# 22  0.849823
# 23 -0.526720
# 24  0.635492
# 25 -0.532680
# 26 -0.537299
# 27  0.467285
# 28  1.218878
# 29  0.502206
# 30  0.320892
# 31 -0.374338
# 32 -0.806442
# 33  0.047959
# 34  0.434722
# 35  0.026458
# 36  0.679904
# 37 -0.031499
# 38  0.662626
# 39  0.462182
# ---------------------------------------------

# %% [markdown]
# ## [5] Construct subnetwork from thresholding weighted edges that yields ~500 nodes; preform gene enrichment analysis & color pathways in network

# %% [markdown]
# Pick the edge weight threshold that yields ~500 nodes in the subgraph

# %%
edge_weight_thresh = 0.4666666666666667

# %% [markdown]
# Visualize sub-network induced by setting edge weight cut-off above

# %%
#get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

#get the SUBGRAPH induced by the most heavily weighted edges
S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))

#print some stats
print(f'Number of Nodes = {len(S.nodes)}')

#visualize subgraph
pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 3.0) #positions of nodes will be used for this visualization and downstream
visualize_network_color_by_weighted_deg_and_logFC(S, pos, 'network colored by weighted deg and mean logFC nodes with edgweight thresh 0.46')
# Out:
# Number of Nodes = 502

# %% [markdown]
# Run **gene set enrichment** on the nodes in this network

# %%
#gene set enrichment
gene_enrichr_df = run_enrichr_on_list_of_genes(list(S.nodes), 'IMMUNE')

#average the (weighted degree) for each gene detected as part of the gene set and append as another column
#weighted degree for nodes in this network
node_list = [node_deg[0] for node_deg in list(S.degree(weight = 'weight'))]
degree_list = [node_deg[1] for node_deg in list(S.degree(weight = 'weight'))]
node_weighted_deg_values = pd.Series(degree_list , index = node_list) / float(len(node_list)) #normalize by # of nodes
avg_weighted_deg = [node_weighted_deg_values[gene_enrichr_df.Genes[pathway_i].split(';')].mean() for pathway_i in gene_enrichr_df.index]
gene_enrichr_df.loc[: , 'weighted_deg'] = avg_weighted_deg

# %%
gene_enrichr_df
# Out:
#            ID       P-value  Adjusted P-value Overlap  \
# 0    LI.M11.0  1.276332e-33      1.825155e-31  48/189
# 1    LI.M37.0  5.242041e-29      3.748059e-27  57/347
# 2      LI.M75  1.860553e-25      8.868636e-24   18/22
# 3     LI.M7.0  3.104006e-18      1.109682e-16   21/62
# 4     LI.M127  4.500670e-17      1.287192e-15   11/12
# 5     LI.M165  9.151150e-14      1.894385e-12   14/35
# 6     LI.M7.1  9.273213e-14      1.894385e-12   16/50
# 7     LI.M4.0  1.810018e-13      3.235407e-12  37/335
# 8   LI.M111.1  3.009540e-13      4.781825e-12    9/11
# 9     LI.M150  1.175762e-12      1.528491e-11    9/12
# 10     LI.M67  1.175762e-12      1.528491e-11    9/12
# 11     LI.M16  7.251589e-12      8.641477e-11   14/46
# 12      LI.S4  3.960994e-11      4.357093e-10   18/94
# 13     LI.M14  9.965010e-11      1.017855e-09    8/12
# 14  LI.M111.0  1.154805e-10      1.100914e-09    9/17
# 15    LI.M5.0  2.765137e-09      2.471341e-08   15/81
# 16    LI.M4.3  4.002605e-09      3.366897e-08   10/31
# 17     LI.M81  1.506911e-08      1.197157e-07   10/35
# 18    LI.M7.2  4.517064e-08      3.098235e-07   11/49
# 19    LI.M7.4  4.549855e-08      3.098235e-07    7/15
# 20    LI.M109  4.549855e-08      3.098235e-07    7/15
# 21     LI.M68  6.257588e-08      4.067432e-07    6/10
# 22     LI.M13  1.345975e-07      8.019768e-07    6/11
# 23     LI.M18  1.345975e-07      8.019768e-07    6/11
# 24  LI.M118.0  2.364564e-07      1.352531e-06   11/57
# 25      LI.S0  3.152220e-07      1.733721e-06    8/27
# 26   LI.M61.0  1.990894e-06      1.054437e-05    7/24
# 27      LI.M3  3.200374e-06      1.578116e-05    9/47
# 28  LI.M112.0  3.150008e-06      1.578116e-05    6/17
# 29   LI.M37.1  7.687261e-06      3.664261e-05    9/52
# 30     LI.M56  8.483867e-06      3.913526e-05    5/12
# 31    LI.M7.3  1.288930e-05      5.585365e-05    7/31
# 32    LI.M117  1.262477e-05      5.585365e-05    6/21
# 33   LI.M43.1  2.052642e-05      8.633170e-05    5/14
# 34     LI.M87  2.927701e-05      1.164228e-04    6/24
# 35   LI.M43.0  3.012337e-05      1.164228e-04    5/15
# 36     LI.M24  3.012337e-05      1.164228e-04    5/15
# 37     LI.M44  8.835203e-05      3.158585e-04    4/10
# 38    LI.M113  8.835203e-05      3.158585e-04    4/10
# 39    LI.M209  8.835203e-05      3.158585e-04    4/10
# 40   LI.M37.2  1.068833e-04      3.727879e-04    5/19
# 41     LI.S10  1.535356e-04      5.227523e-04    9/75
# 42     LI.M40  2.824329e-04      9.179069e-04    4/13
# 43    LI.M223  2.824329e-04      9.179069e-04    4/13
#
#                                                 Genes  \
# 0   PLAUR;MAFB;SORT1;SIRPB1;PLXDC2;MS4A7;CD36;IGSF...
# 1   LY96;SH2D1A;SIRPB1;PLXDC2;MS4A7;OSCAR;CLEC4D;M...
# 2   ELANE;RSAD2;OAS3;OAS1;DDX58;CXCL10;C1QB;IL1B;H...
# 3   SH2D1A;CD247;ITK;CD6;PTPRCAP;KLRB1;MAL;NELL2;L...
# 4   RSAD2;PARP9;HERC5;TAP1;PLSCR1;IRF7;IFIT1;DDX60...
# 5   IFIT2;RSAD2;IFI27;ATF3;IFIT3;PARP9;PRRG4;RBM47...
# 6   PRKCH;TXK;CD247;ITK;CD5;IL7R;CD27;ITPR3;CD3G;C...
# 7   PLAUR;MAFB;SORT1;CD36;IGSF6;CYBB;IFI30;TLR4;CD...
# 8   IFIT2;DDX58;CXCL10;ZBP1;CASP1;TAP1;TNFSF13B;BS...
# 9   RSAD2;EIF2AK2;OASL;TAP1;PLSCR1;IRF7;OAS1;OAS3;...
# 10  C2;RSAD2;C1QC;DDX58;SERPING1;PLSCR1;IRF7;DDX60...
# 11  LY96;HSPA6;TLR2;KCNJ2;BST1;TLR8;FCGR1A;DYSF;KC...
# 12  CCR1;SIRPB1;CD36;MARCO;TLR2;ABCA1;HCAR3;MCTP1;...
# 13       SH2D1A;TXK;CD28;ITK;LRRN3;SPOCK2;MAL;RASGRP1
# 14  CXCL16;ZBP1;IFI35;KYNU;TAP1;TNFSF13B;BST2;TLR7...
# 15  LY96;MAPK14;CD247;ITK;TLR2;FCER1G;CD3G;CD19;CC...
# 16  CCR1;GPBAR1;TLR8;IGSF6;MYOF;SECTM1;TLR5;ASGR1;...
# 17  ITGA2B;LIN7A;PROS1;FCER1G;ITGB3;CCR2;SELP;TLR7...
# 18  KLRF1;PRKCH;CLIC3;CD247;ITK;PTGDR;CD96;KLRB1;A...
# 19          ETS1;CD96;KLF12;THEMIS;NELL2;LEF1;RASGRP1
# 20              CCR1;S1PR1;CCR7;C3AR1;CCR2;LRRK2;LEF1
# 21               DDX58;CXCL10;ISG15;IRF7;TRIM25;IFIH1
# 22                   DDX58;CXCL10;ZBP1;IRF7;AIM2;IL1B
# 23                PRKCH;SH2D1A;ETS1;ITK;ABLIM1;SPOCK2
# 24  LY96;VNN1;HCAR3;DYSF;LRRK2;TNFSF13B;SMARCD3;NA...
# 25       CD3G;CD6;LRRN3;MAL;SLC38A1;PTPRCAP;CD28;CD3E
# 26             KLRF1;CD247;PVRIG;CD96;KLRB1;CD7;IL2RB
# 27  CCR1;HPSE;TLR2;S100A12;TLR5;IL1RN;ADAP2;NOD2;CD3E
# 28                    C2;C1QC;CR1;C1QB;SERPING1;C3AR1
# 29  FFAR2;CREB5;LIN7A;HCAR3;SLC22A4;LRG1;KCNJ15;ST...
# 30                     HSPA6;DUSP3;CACNA2D3;IL1B;CD14
# 31            CXCR3;CD247;ITK;CD3G;PTPRCAP;CD3E;SP140
# 32                   CXCR3;CD96;CD6;SPOCK2;NELL2;LEF1
# 33                        ICAM1;IL23A;RELB;BCL3;IL1RN
# 34                    HK3;CD36;TLR2;SLC22A4;AQP9;TLR4
# 35                       SAMSN1;ICAM1;IL23A;RELB;BCL3
# 36                     IL15;SERPING1;IL23A;BCL3;SBNO2
# 37                            MAPK14;IL23A;IFI30;IL7R
# 38                           STEAP4;SORT1;TLR8;LPCAT2
# 39                               GM2A;CTSZ;SORT1;CTSL
# 40                       SORT1;TLR8;LPCAT2;TLR7;ACSL1
# 41  STAB1;LHFPL2;PLXDC2;IGSF6;LPCAT2;SLAMF8;CCRL2;...
# 42                                LY96;TLR8;C1QC;C1QB
# 43                         SLC38A1;TC2N;DENND2D;LRRN3
#
#                                                 Title            Category  \
# 0                          enriched in monocytes (II)              immune
# 1                 immune activation - generic cluster              immune
# 2                             antiviral IFN signature              immune
# 3                             enriched in T cells (I)              immune
# 4                          type I interferon response              immune
# 5          enriched in activated dendritic cells (II)              immune
# 6                               T cell activation (I)              immune
# 7                        cell cycle and transcription  biological process
# 8   viral sensing & immunity; IRF2 targets network...              immune
# 9                           innate antiviral response              immune
# 10                          activated dendritic cells              immune
# 11                     TLR and inflammatory signaling              immune
# 12                         Monocyte surface signature              immune
# 13                             T cell differentiation              immune
# 14  viral sensing & immunity; IRF2 targets network...              immune
# 15  regulation of antigen presentation and immune ...              immune
# 16   myeloid cell enriched receptors and transporters              immune
# 17            enriched in myeloid cells and monocytes              immune
# 18                           enriched in NK cells (I)              immune
# 19                            T cell activation (III)              immune
# 20                          receptors, cell migration  molecular function
# 21                      RIG-1 like receptor signaling              immune
# 22         innate activation by cytosolic DNA sensing              immune
# 23             T cell differentiation via ITK and PKC              immune
# 24                         enriched in monocytes (IV)              immune
# 25                           T cell surface signature              immune
# 26                          enriched in NK cells (II)              immune
# 27                  regulation of signal transduction           signaling
# 28                          complement activation (I)              immune
# 29                        enriched in neutrophils (I)              immune
# 30                      suppression of MAPK signaling           signaling
# 31                             T cell activation (II)              immune
# 32                                 cell adhesion (GO)  molecular function
# 33   myeloid, dendritic cell activation via NFkB (II)              immune
# 34                        transmembrane transport (I)  molecular function
# 35    myeloid, dendritic cell activation via NFkB (I)              immune
# 36                  cell activation (IL15, IL23, TNF)              immune
# 37                 T cell signaling and costimulation              immune
# 38                                 golgi membrane (I)            location
# 39                                           lysosome            location
# 40                              endoplasmic reticulum            location
# 41           Resting dendritic cell surface signature              immune
# 42              complement and other receptors in DCs              immune
# 43                           enriched in T cells (II)              immune
#
#        logFC  weighted_deg
# 0   0.586283      0.135309
# 1   0.490869      0.134806
# 2   0.910279      0.192268
# 3  -0.557615      0.168418
# 4   0.910252      0.247917
# 5   1.057776      0.199981
# 6  -0.585209      0.160267
# 7   0.633442      0.145160
# 8   0.738843      0.219581
# 9   0.863285      0.189346
# 10  1.166409      0.232448
# 11  0.864099      0.231901
# 12  0.592457      0.125291
# 13 -0.611144      0.155777
# 14  0.589455      0.197167
# 15  0.205356      0.208066
# 16  0.622513      0.113652
# 17  0.555729      0.110837
# 18 -0.459323      0.144754
# 19 -0.639535      0.163878
# 20 -0.080953      0.175507
# 21  0.792091      0.185525
# 22  0.849823      0.235790
# 23 -0.526720      0.153342
# 24  0.635492      0.163262
# 25 -0.532680      0.104283
# 26 -0.537299      0.163252
# 27  0.467285      0.175933
# 28  1.218878      0.157193
# 29  0.502206      0.123093
# 30  0.320892      0.206162
# 31 -0.374338      0.116885
# 32 -0.806442      0.258012
# 33  0.047959      0.027676
# 34  0.434722      0.089022
# 35  0.026458      0.019203
# 36  0.679904      0.099548
# 37 -0.031499      0.192364
# 38  0.662626      0.159628
# 39  0.462182      0.122809
# 40  0.674686      0.203054
# 41  0.442758      0.100812
# 42  1.149030      0.206042
# 43 -0.548027      0.078851

# %%
np.shape(gene_enrichr_df)
# Out:
# (44, 9)

# %% [markdown]
# #### Organize gene sets into bigger buckets

# %% [markdown]
# We're going to manually organize the gene sets above into broader gene set classifications
#
# - **Interferon Type I**: LI.M127
#
# - **Interferon Type II**: LI.M68 - LI.M150 - LI.M111.1 - LI.M111.0 - LI.M75
#
# - **T-cell Response**: LI.M7.0 - LI.M7.1 - LI.M14 - LI.M7.4 - LI.M18 - LI.S0 - LI.M7.3 - LI.M44 - LI.M223
#
# - **Toll-like Receptor**: LI.M16
#
# - **Antigen Presentation**: LI.M5.0
#
# - **Dendritic Cells**: LI.M165 - LI.M67 - LI.M43.0 - LI.S10 - LI.M43.1
#
# - **Monoctyes**: LI.M11.0 - LI.S4 - LI.M81 - LI.M118.0
#
# - **Myeloid Cells**: LI.M4.3 - LI.M81 - LI.M43.0 - LI.M43.1
#
# - **B Cells**:
#
# - **Complement**: LI.M112.0 - LI.M40
#
# - **Natural Killer Cells**: LI.M7.2 - LI.M61.0
#
# - **Neutrophils**: LI.M37.1

# %%
gene_set_group_dict = {
    'Interferon Type I': ['LI.M127'],
    'Interferon Type II': ['LI.M68', 'LI.M150', 'LI.M111.1', 'LI.M111.0','LI.M75'],
    'T-cell Response': ['LI.M7.0', 'LI.M7.1', 'LI.M14', 'LI.M7.4', 'LI.M18', 'LI.S0', 'LI.M7.3', 'LI.M44', 'LI.M223'],
    'Toll-like Receptor': ['LI.M16'],
    'Antigen Presentation': ['LI.M5.0'],
    'Dendritic Cells': ['LI.M165', 'LI.M67', 'LI.M43.0', 'LI.S10', 'LI.M43.1'],
    'Monoctyes': ['LI.M11.0', 'LI.S4', 'LI.M81', 'LI.M118.0'],
    'Myeloid Cells': ['LI.M4.3', 'LI.M81', 'LI.M43.0', 'LI.M43.1'],
    'Complement': ['LI.M112.0', 'LI.M40'],
    'Natural Killer Cells': ['LI.M7.2', 'LI.M61.0'],
    'Neutrophils': ['LI.M37.1']
    }

# %% [markdown]
# Add **column** to gene enriched df to indicate gene group assignment

# %%
gene_set_list_for_df = []
#iterate through each enriched pathway and find corresponding gene group assignment
for gene_pathway_id in gene_enrichr_df.ID:
    gene_group_assignment = ''
    for gene_group in gene_set_group_dict.keys():
        if gene_pathway_id in gene_set_group_dict[gene_group]:
            if gene_group_assignment == '':
                gene_group_assignment = gene_group
            else:
                gene_group_assignment = gene_group_assignment + '/' + gene_group
    gene_set_list_for_df.append(gene_group_assignment)
    
gene_enrichr_df.loc[:  , 'Gene Group'] = gene_set_list_for_df

# %%
gene_enrichr_df
# Out:
#            ID       P-value  Adjusted P-value Overlap  \
# 0    LI.M11.0  1.276332e-33      1.825155e-31  48/189
# 1    LI.M37.0  5.242041e-29      3.748059e-27  57/347
# 2      LI.M75  1.860553e-25      8.868636e-24   18/22
# 3     LI.M7.0  3.104006e-18      1.109682e-16   21/62
# 4     LI.M127  4.500670e-17      1.287192e-15   11/12
# 5     LI.M165  9.151150e-14      1.894385e-12   14/35
# 6     LI.M7.1  9.273213e-14      1.894385e-12   16/50
# 7     LI.M4.0  1.810018e-13      3.235407e-12  37/335
# 8   LI.M111.1  3.009540e-13      4.781825e-12    9/11
# 9     LI.M150  1.175762e-12      1.528491e-11    9/12
# 10     LI.M67  1.175762e-12      1.528491e-11    9/12
# 11     LI.M16  7.251589e-12      8.641477e-11   14/46
# 12      LI.S4  3.960994e-11      4.357093e-10   18/94
# 13     LI.M14  9.965010e-11      1.017855e-09    8/12
# 14  LI.M111.0  1.154805e-10      1.100914e-09    9/17
# 15    LI.M5.0  2.765137e-09      2.471341e-08   15/81
# 16    LI.M4.3  4.002605e-09      3.366897e-08   10/31
# 17     LI.M81  1.506911e-08      1.197157e-07   10/35
# 18    LI.M7.2  4.517064e-08      3.098235e-07   11/49
# 19    LI.M7.4  4.549855e-08      3.098235e-07    7/15
# 20    LI.M109  4.549855e-08      3.098235e-07    7/15
# 21     LI.M68  6.257588e-08      4.067432e-07    6/10
# 22     LI.M13  1.345975e-07      8.019768e-07    6/11
# 23     LI.M18  1.345975e-07      8.019768e-07    6/11
# 24  LI.M118.0  2.364564e-07      1.352531e-06   11/57
# 25      LI.S0  3.152220e-07      1.733721e-06    8/27
# 26   LI.M61.0  1.990894e-06      1.054437e-05    7/24
# 27      LI.M3  3.200374e-06      1.578116e-05    9/47
# 28  LI.M112.0  3.150008e-06      1.578116e-05    6/17
# 29   LI.M37.1  7.687261e-06      3.664261e-05    9/52
# 30     LI.M56  8.483867e-06      3.913526e-05    5/12
# 31    LI.M7.3  1.288930e-05      5.585365e-05    7/31
# 32    LI.M117  1.262477e-05      5.585365e-05    6/21
# 33   LI.M43.1  2.052642e-05      8.633170e-05    5/14
# 34     LI.M87  2.927701e-05      1.164228e-04    6/24
# 35   LI.M43.0  3.012337e-05      1.164228e-04    5/15
# 36     LI.M24  3.012337e-05      1.164228e-04    5/15
# 37     LI.M44  8.835203e-05      3.158585e-04    4/10
# 38    LI.M113  8.835203e-05      3.158585e-04    4/10
# 39    LI.M209  8.835203e-05      3.158585e-04    4/10
# 40   LI.M37.2  1.068833e-04      3.727879e-04    5/19
# 41     LI.S10  1.535356e-04      5.227523e-04    9/75
# 42     LI.M40  2.824329e-04      9.179069e-04    4/13
# 43    LI.M223  2.824329e-04      9.179069e-04    4/13
#
#                                                 Genes  \
# 0   PLAUR;MAFB;SORT1;SIRPB1;PLXDC2;MS4A7;CD36;IGSF...
# 1   LY96;SH2D1A;SIRPB1;PLXDC2;MS4A7;OSCAR;CLEC4D;M...
# 2   ELANE;RSAD2;OAS3;OAS1;DDX58;CXCL10;C1QB;IL1B;H...
# 3   SH2D1A;CD247;ITK;CD6;PTPRCAP;KLRB1;MAL;NELL2;L...
# 4   RSAD2;PARP9;HERC5;TAP1;PLSCR1;IRF7;IFIT1;DDX60...
# 5   IFIT2;RSAD2;IFI27;ATF3;IFIT3;PARP9;PRRG4;RBM47...
# 6   PRKCH;TXK;CD247;ITK;CD5;IL7R;CD27;ITPR3;CD3G;C...
# 7   PLAUR;MAFB;SORT1;CD36;IGSF6;CYBB;IFI30;TLR4;CD...
# 8   IFIT2;DDX58;CXCL10;ZBP1;CASP1;TAP1;TNFSF13B;BS...
# 9   RSAD2;EIF2AK2;OASL;TAP1;PLSCR1;IRF7;OAS1;OAS3;...
# 10  C2;RSAD2;C1QC;DDX58;SERPING1;PLSCR1;IRF7;DDX60...
# 11  LY96;HSPA6;TLR2;KCNJ2;BST1;TLR8;FCGR1A;DYSF;KC...
# 12  CCR1;SIRPB1;CD36;MARCO;TLR2;ABCA1;HCAR3;MCTP1;...
# 13       SH2D1A;TXK;CD28;ITK;LRRN3;SPOCK2;MAL;RASGRP1
# 14  CXCL16;ZBP1;IFI35;KYNU;TAP1;TNFSF13B;BST2;TLR7...
# 15  LY96;MAPK14;CD247;ITK;TLR2;FCER1G;CD3G;CD19;CC...
# 16  CCR1;GPBAR1;TLR8;IGSF6;MYOF;SECTM1;TLR5;ASGR1;...
# 17  ITGA2B;LIN7A;PROS1;FCER1G;ITGB3;CCR2;SELP;TLR7...
# 18  KLRF1;PRKCH;CLIC3;CD247;ITK;PTGDR;CD96;KLRB1;A...
# 19          ETS1;CD96;KLF12;THEMIS;NELL2;LEF1;RASGRP1
# 20              CCR1;S1PR1;CCR7;C3AR1;CCR2;LRRK2;LEF1
# 21               DDX58;CXCL10;ISG15;IRF7;TRIM25;IFIH1
# 22                   DDX58;CXCL10;ZBP1;IRF7;AIM2;IL1B
# 23                PRKCH;SH2D1A;ETS1;ITK;ABLIM1;SPOCK2
# 24  LY96;VNN1;HCAR3;DYSF;LRRK2;TNFSF13B;SMARCD3;NA...
# 25       CD3G;CD6;LRRN3;MAL;SLC38A1;PTPRCAP;CD28;CD3E
# 26             KLRF1;CD247;PVRIG;CD96;KLRB1;CD7;IL2RB
# 27  CCR1;HPSE;TLR2;S100A12;TLR5;IL1RN;ADAP2;NOD2;CD3E
# 28                    C2;C1QC;CR1;C1QB;SERPING1;C3AR1
# 29  FFAR2;CREB5;LIN7A;HCAR3;SLC22A4;LRG1;KCNJ15;ST...
# 30                     HSPA6;DUSP3;CACNA2D3;IL1B;CD14
# 31            CXCR3;CD247;ITK;CD3G;PTPRCAP;CD3E;SP140
# 32                   CXCR3;CD96;CD6;SPOCK2;NELL2;LEF1
# 33                        ICAM1;IL23A;RELB;BCL3;IL1RN
# 34                    HK3;CD36;TLR2;SLC22A4;AQP9;TLR4
# 35                       SAMSN1;ICAM1;IL23A;RELB;BCL3
# 36                     IL15;SERPING1;IL23A;BCL3;SBNO2
# 37                            MAPK14;IL23A;IFI30;IL7R
# 38                           STEAP4;SORT1;TLR8;LPCAT2
# 39                               GM2A;CTSZ;SORT1;CTSL
# 40                       SORT1;TLR8;LPCAT2;TLR7;ACSL1
# 41  STAB1;LHFPL2;PLXDC2;IGSF6;LPCAT2;SLAMF8;CCRL2;...
# 42                                LY96;TLR8;C1QC;C1QB
# 43                         SLC38A1;TC2N;DENND2D;LRRN3
#
#                                                 Title            Category  \
# 0                          enriched in monocytes (II)              immune
# 1                 immune activation - generic cluster              immune
# 2                             antiviral IFN signature              immune
# 3                             enriched in T cells (I)              immune
# 4                          type I interferon response              immune
# 5          enriched in activated dendritic cells (II)              immune
# 6                               T cell activation (I)              immune
# 7                        cell cycle and transcription  biological process
# 8   viral sensing & immunity; IRF2 targets network...              immune
# 9                           innate antiviral response              immune
# 10                          activated dendritic cells              immune
# 11                     TLR and inflammatory signaling              immune
# 12                         Monocyte surface signature              immune
# 13                             T cell differentiation              immune
# 14  viral sensing & immunity; IRF2 targets network...              immune
# 15  regulation of antigen presentation and immune ...              immune
# 16   myeloid cell enriched receptors and transporters              immune
# 17            enriched in myeloid cells and monocytes              immune
# 18                           enriched in NK cells (I)              immune
# 19                            T cell activation (III)              immune
# 20                          receptors, cell migration  molecular function
# 21                      RIG-1 like receptor signaling              immune
# 22         innate activation by cytosolic DNA sensing              immune
# 23             T cell differentiation via ITK and PKC              immune
# 24                         enriched in monocytes (IV)              immune
# 25                           T cell surface signature              immune
# 26                          enriched in NK cells (II)              immune
# 27                  regulation of signal transduction           signaling
# 28                          complement activation (I)              immune
# 29                        enriched in neutrophils (I)              immune
# 30                      suppression of MAPK signaling           signaling
# 31                             T cell activation (II)              immune
# 32                                 cell adhesion (GO)  molecular function
# 33   myeloid, dendritic cell activation via NFkB (II)              immune
# 34                        transmembrane transport (I)  molecular function
# 35    myeloid, dendritic cell activation via NFkB (I)              immune
# 36                  cell activation (IL15, IL23, TNF)              immune
# 37                 T cell signaling and costimulation              immune
# 38                                 golgi membrane (I)            location
# 39                                           lysosome            location
# 40                              endoplasmic reticulum            location
# 41           Resting dendritic cell surface signature              immune
# 42              complement and other receptors in DCs              immune
# 43                           enriched in T cells (II)              immune
#
#        logFC  weighted_deg                     Gene Group
# 0   0.586283      0.135309                      Monoctyes
# 1   0.490869      0.134806
# 2   0.910279      0.192268             Interferon Type II
# 3  -0.557615      0.168418                T-cell Response
# 4   0.910252      0.247917              Interferon Type I
# 5   1.057776      0.199981                Dendritic Cells
# 6  -0.585209      0.160267                T-cell Response
# 7   0.633442      0.145160
# 8   0.738843      0.219581             Interferon Type II
# 9   0.863285      0.189346             Interferon Type II
# 10  1.166409      0.232448                Dendritic Cells
# 11  0.864099      0.231901             Toll-like Receptor
# 12  0.592457      0.125291                      Monoctyes
# 13 -0.611144      0.155777                T-cell Response
# 14  0.589455      0.197167             Interferon Type II
# 15  0.205356      0.208066           Antigen Presentation
# 16  0.622513      0.113652                  Myeloid Cells
# 17  0.555729      0.110837        Monoctyes/Myeloid Cells
# 18 -0.459323      0.144754           Natural Killer Cells
# 19 -0.639535      0.163878                T-cell Response
# 20 -0.080953      0.175507
# 21  0.792091      0.185525             Interferon Type II
# 22  0.849823      0.235790
# 23 -0.526720      0.153342                T-cell Response
# 24  0.635492      0.163262                      Monoctyes
# 25 -0.532680      0.104283                T-cell Response
# 26 -0.537299      0.163252           Natural Killer Cells
# 27  0.467285      0.175933
# 28  1.218878      0.157193                     Complement
# 29  0.502206      0.123093                    Neutrophils
# 30  0.320892      0.206162
# 31 -0.374338      0.116885                T-cell Response
# 32 -0.806442      0.258012
# 33  0.047959      0.027676  Dendritic Cells/Myeloid Cells
# 34  0.434722      0.089022
# 35  0.026458      0.019203  Dendritic Cells/Myeloid Cells
# 36  0.679904      0.099548
# 37 -0.031499      0.192364                T-cell Response
# 38  0.662626      0.159628
# 39  0.462182      0.122809
# 40  0.674686      0.203054
# 41  0.442758      0.100812                Dendritic Cells
# 42  1.149030      0.206042                     Complement
# 43 -0.548027      0.078851                T-cell Response

# %% [markdown]
# ### *Function* to visualize a color a specific list of nodes

# %%
def visualize_network_color_by_inclusion_in_node_set(G, ax, pos, node_set, color, pathway_name, num_nodes):
    
    #color nodes by whether they belong in gene set (given color) or not (grey)
    node_color_dict = {True:color, False:'0.85'}
    node_colors = [node_color_dict[node_i in node_set] for node_i in G.nodes]
    
    #nodes in node set
    H = G.subgraph(node_set)
    collection = nx.draw_networkx_nodes(
        H, 
        pos = pos, 
        ax = ax,
        node_size = 25, 
        node_color = color,
        linewidths = 0.25,
        edge_color = "0.83",
        width=0.0,
        alpha = 1.0, 
        with_labels = False)
    collection.set_zorder(2)
    ax.collections[0].set_edgecolor("black") #color of the node outlines
    
    #nodes not in node set
    H = G.subgraph([node_i for node_i in G.nodes if node_i not in node_set])
    collection = nx.draw_networkx_nodes(
        H, 
        pos = pos, 
        ax = ax,
        node_size = 20, 
        node_color = '0.85',
        linewidths = 0.0,
        edge_color = "0.83",
        width=0.0,
        alpha = 0.8, 
        with_labels = False)
    collection.set_zorder(1)
    
    #average the (weighted degree) for each gene detected as part of the gene set
    avg_weighted_deg = round(node_weighted_deg_values[genes_in_category_i].mean(), 2)
    
    #average the (mean logFC) for each gene detected as part of the gene set
    avg_meanlogFC = round(mean_logFC_series[genes_in_category_i].mean(), 2)
    
    ax.set_title(f'{pathway_name}\nN={num_nodes} / avg weight deg={avg_weighted_deg} / avg logFC={avg_meanlogFC}', color = 'k', fontsize = 11)

# %% [markdown]
# Assign a color to each gene category by pulling from a color map

# %%
num_gene_categories = len(gene_set_group_dict.keys()) #number of gene categories (subplots)
color_scheme = discrete_cmap(num_gene_categories, 'jet') #pull a color map and discretize it
norm = mpl.colors.Normalize(vmin = 0, vmax = num_gene_categories) #get the normalization
color_scheme_norm = mpl.cm.ScalarMappable(norm = norm, cmap = color_scheme) #normalize the color map to the min/max values of the node values

#get color for each node from color map
gene_category_color_dict = {}
i = 0
for gene_category_i in gene_set_group_dict.keys(): #iterate through gene categories
    gene_category_color_dict[gene_category_i] = 'k' # color_scheme_norm.to_rgba(i)
    i += 1

# %%
print(f'Number of Gene Groups = {len(gene_category_color_dict.keys())}')
# Out:
# Number of Gene Groups = 11

# %% [markdown]
# #### Visualize nodes that belong to the enriched gene categories

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(4, 3, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[1, 0])
ax5 = fig.add_subplot(gs[1, 1])
ax6 = fig.add_subplot(gs[1, 2])
ax7 = fig.add_subplot(gs[2, 0])
ax8 = fig.add_subplot(gs[2, 1])
ax9 = fig.add_subplot(gs[2, 2])
ax10 = fig.add_subplot(gs[3, 0])
ax11 = fig.add_subplot(gs[3, 1])

#iterate through each gene category & axis
for gene_category_i, ax in zip(gene_set_group_dict.keys(), [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11]):
    
    #get all the genes that belongs to the enriched pathways for this gene category
    genes_in_category_i = []
    
    #iterate through each pathway tied to this gene category
    for enriched_pathway_i in gene_set_group_dict[gene_category_i]:

        genes_in_enriched_pathway_i = gene_enrichr_df[gene_enrichr_df.ID == enriched_pathway_i].Genes.values[0]
        genes_in_enriched_pathway_i = genes_in_enriched_pathway_i.split(';')
        genes_in_category_i = genes_in_category_i + genes_in_enriched_pathway_i

    genes_in_category_i = list(set(genes_in_category_i)) #get rid of repeat genes
    gene_category_color = gene_category_color_dict[gene_category_i] #get the color assigned to this gene category
    num_nodes_category_i = str(len(genes_in_category_i)) #number of nodes

    visualize_network_color_by_inclusion_in_node_set(S, ax, pos, genes_in_category_i, gene_category_color, gene_category_i, num_nodes_category_i)

################### Plot
fig = plt.gcf()
fig.set_size_inches(16.0, 21.5)
fig.tight_layout()

file_name = f'{figures_dir_path}/{comparison_X} network with nodes colored according to functional immune gene groups.pdf'
plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()
