# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #### choose correct comparison groups

# %%
comparison_X = 'ATB_v_HC'

# %% [markdown]
# import packages

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import MaxNLocator
from matplotlib.gridspec import GridSpec
import matplotlib.pylab as pl
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

import fastcluster
from scipy.cluster.hierarchy import dendrogram
import scipy.cluster.hierarchy as hier

import networkx as nx
import networkx.algorithms.community as nxcom
import community
from collections import Counter
import pickle
from collections import defaultdict

import gseapy as gp
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### set parameters for plotting

# %%
plt.style.use('ggplot')
plt.rcParams['lines.linewidth']=1.0
plt.rcParams['axes.facecolor']='1.0'
plt.rcParams['xtick.color']='black'
plt.rcParams['axes.grid']=False
plt.rcParams['axes.edgecolor']='black'
plt.rcParams['grid.color']= '1.0'
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# #### specify directory paths

# %%
# use these paths for O2 computing cluster

#specify directory for Data
Data_files_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/'

#specify directory for pickling objects
pickled_objects_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/Pickled Files/'

#specify directory for CSV files
CSV_files_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/CSV Files/'

#specify directory for Gene Set Files
Gene_Set_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/Gene Set Files/CSV files/'

# %% [markdown]
# # [1] Load Data

# %% [markdown]
# ### Network

# %%
G = nx.read_gpickle(pickled_objects_dir + f'Network Files/networks/{comparison_X}.pkl')

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 3005
# Number of edges: 672127
# Average degree: 447.3391

# %%
num_nodes_overall_network = int(len(G.nodes()))

# %% [markdown]
# ### Weighted Degrees for Nodes (genes)

# %%
weighted_deg_series = pd.read_pickle(pickled_objects_dir + f'Network Files/weighted degree series/{comparison_X}.pkl')

# %%
np.shape(weighted_deg_series)
# Out:
# (3005,)

# %% [markdown]
# ### Mean $log_2(Fold Change)$ for Nodes (genes)

# %%
mean_logFC_series = pd.read_pickle(pickled_objects_dir + f'Network Files/mean logFC network nodes series/{comparison_X}.pkl')

# %%
np.shape(mean_logFC_series)
# Out:
# (3005,)

# %% [markdown]
# ### Compile into DataFrame

# %%
G_deg_logFC_df = pd.DataFrame(index = mean_logFC_series.index)
G_deg_logFC_df['mean_log2FC'] = mean_logFC_series.values
G_deg_logFC_df['weighted_degree'] = weighted_deg_series[mean_logFC_series.index].values

# %%
G_deg_logFC_df.head()
# Out:
#           mean_log2FC  weighted_degree
# SERPING1     2.805312       572.733333
# ANKRD22      2.713292       604.800000
# BATF2        2.319556       583.066667
# P2RY14       2.241647       511.666667
# FCGR1B       2.127004       572.733333

# %% [markdown]
# # [2] *Functions* for community detection

# %% [markdown]
# ### Louvain algorithm

# %%
def run_louvain_alg(G, mod_only):
    
    '''
    name: Louvain
    nature: Modularity Optimization
    complexity: O(L) where N = nodes, L = edges, and L~N for sparse networks
    ref: V. D. Blondel, J.-L. Guillaume, R. Lambiotte, and E. Lefebvre. Fast unfolding of communities in large networks. J. Stat. Mech., 2008.
    '''

    # Starting with an initial partition of the graph and running the Louvain algorithm for Community Detection
    partition = community.best_partition(G, weight='weight')
    
    # Grouping dictionary keys by value
    communities = defaultdict(list)
    for key, val in sorted(partition.items()):
        communities[val].append(key)
    communities = list(communities.values())

    # Calculating modularity
    mod = nxcom.modularity(G, communities, weight='weight')

    if mod_only == True:
        
        return mod
        
    else:

        # Creating a dictionary like {community_number:list_of_participants}
        values=[partition.get(node) for node in G.nodes()]
        list_com=partition.values()
        dict_nodes={}

        # Populating the dictionary with items
        for each_item in partition.items():
            community_num=each_item[1]
            community_node=each_item[0]
            if community_num in dict_nodes:
                value=dict_nodes.get(community_num) + ' | ' + str(community_node)
                dict_nodes.update({community_num:value})
            else:
                dict_nodes.update({community_num:community_node})

        # Creating a dataframe from the dict
        community_df=pd.DataFrame.from_dict(dict_nodes, orient='index',columns=['Members'])
        community_df.index.rename('Community_Num' , inplace=True)
        num_comm_members = [len(comm_i_member_list.split(' | ')) for comm_i_member_list in community_df.Members]
        community_df.loc[: , 'Num_Members'] = num_comm_members
        community_df.sort_values(by = 'Num_Members' , ascending = False , inplace = True)
        community_df.reset_index(inplace = True , drop = True)

        # Calculating the total number of communities
        print("Modularity: ", mod)
        print("Total number of Communities =", np.shape(community_df)[0])

        return community_df

# %% [markdown]
# ### Girvan-Newman algorithm

# %%
def run_girvan_alg(G, mod_only):
    
    '''
    name: Girvan-Newman
    nature: Hierarchical Divisive
    complexity: O(N^2) where N = nodes, L = edges, and L~N for sparse networks
    ref: M. Girvan and M.E.J. Newman. Community structure in social and biological networks. PNAS, 99:7821–7826, 2002.
    '''
    
    # Using the Girvan-Newman algorithm to create a Community Structure
    comp=nxcom.girvan_newman(G)

    # Creating a dictionary for the community number assocaited with each node
    com = 0
    thisdict={}

    # Populating the items of the dictionary
    for c in next(comp):
        thislist=sorted(c)
        for i in range(len(thislist)):
            if thislist[i] in thisdict:
                print('already found')
            else:
                thisdict.update({thislist[i]: com})
            i+=1
        com+=1

    # Grouping dictionary keys by value
    communities = defaultdict(list)
    for key, val in sorted(thisdict.items()):
        communities[val].append(key)
    communities = list(communities.values())
    
    # Calculating modularity
    mod = nxcom.modularity(G, communities, weight='weight')

    if mod_only == True:
        
        return mod
        
    else:

        values=[thisdict.get(node) for node in G.nodes()]

        # Creating a dictionary like 'Community num':'List of participants'
        dict_nodes={}
        for each_item in thisdict.items():
            community_num=each_item[1]
            community_node=each_item[0]

            if community_num in dict_nodes:
                value=dict_nodes.get(community_num) + ' | ' + str(community_node)
                dict_nodes.update({community_num: value})
            else:
                dict_nodes.update({community_num: community_node})

        # Creating the output file
        community_df=pd.DataFrame.from_dict(dict_nodes, orient='index',columns=['Members'])
        community_df.index.rename('Community Num', inplace=True)
        num_comm_members = [len(comm_i_member_list.split(' | ')) for comm_i_member_list in community_df.Members]
        community_df.loc[: , 'Num_Members'] = num_comm_members
        community_df.sort_values(by = 'Num_Members' , ascending = False , inplace = True)
        community_df.reset_index(inplace = True , drop = True)

        # Calculating the total number of communities
        print("Modularity:", mod)
        print("Total number of Communities =", np.shape(community_df)[0])
        
        return community_df

# %% [markdown]
# ### Clauset-Newman-Moore algorithm

# %%
def run_clauset_alg(G, mod_only):
    
    '''
    name: Greedy Modularity (optimized)
    nature: Modularity Optimization
    complexity: O(L) where N = nodes, L = edges, and L~N for sparse networks
    ref: A. Clauset, M.E.J. Newman, and C. Moore. Finding community structure in very large networks. Physical Review E, 70:066111, 2004.
    '''

    # Using the Clauset-Newman-Moore algorithm to create a Community Structure
    communities = nxcom.greedy_modularity_communities(G, weight='weight')
    communities = [list(comm_i) for comm_i in communities] #convert from list of frozen sets to list of lists
    
    # Calculate the modularity
    mod = nxcom.modularity(G, communities, weight='weight')

    if mod_only == True:
        
        return mod
        
    else:
        
        # Creating a dictionary for the community number associated with each node
        com = 0
        thisdict = {}

        # Populating the items of the dictionary
        for comm_i in communities: #iterate through communities
            for node_i in comm_i: #iterate through nodes within community
                thisdict[node_i] = com
            #update community ID
            com += 1

        # Creating a dictionary like 'Community num':'List of participants'
        values=[thisdict.get(node) for node in G.nodes()]
        dict_nodes={}
        for each_item in thisdict.items():
            community_num=each_item[1]
            community_node=each_item[0]

            if community_num in dict_nodes:
                value=dict_nodes.get(community_num) + ' | ' + str(community_node)
                dict_nodes.update({community_num: value})
            else:
                dict_nodes.update({community_num: community_node})

        # Creating the output file
        community_df=pd.DataFrame.from_dict(dict_nodes, orient='index',columns=['Members'])
        community_df.index.rename('Community Num', inplace=True)
        num_comm_members = [len(comm_i_member_list.split(' | ')) for comm_i_member_list in community_df.Members]
        community_df.loc[: , 'Num_Members'] = num_comm_members
        community_df.sort_values(by = 'Num_Members' , ascending = False , inplace = True)
        community_df.reset_index(inplace = True , drop = True)

        # Calculation of number of communities
        print("Modularity:", mod)
        print("Total number of Communities =", np.shape(community_df)[0])
        
        return community_df

# %% [markdown]
# # [3] Get sub-network constructed from retaining only nodes with $mean(logFC) \ge 0.5$ & detect communities

# %% [markdown]
# ## [3.1] Get most heavily weighted edges that pass optimal threshold & construct sub-graph

# %%
len(G_deg_logFC_df.mean_log2FC[abs(G_deg_logFC_df.mean_log2FC) >= 0.5].index)
# Out:
# 372

# %%
#get the nodes in the network that pass the logFC threshold
nodes_high_abs_logFC_subset = list(G_deg_logFC_df.mean_log2FC[abs(G_deg_logFC_df.mean_log2FC) >= 0.5].index)

#get the SUBGRAPH induced by the most these nodes (correspond to genes with >> |logFC|)
S = G.subgraph(nodes_high_abs_logFC_subset)

# %%
print(nx.info(S))
# Out:
# Name:
# Type: Graph
# Number of nodes: 372
# Number of edges: 62697
# Average degree: 337.0806

# %% [markdown]
# Use **Spring Layout** to set the positions of the nodes

# %%
pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 4.5)

# %%
fig , ax = plt.subplots()

nx.draw_networkx(
    S, 
    pos = pos, 
    ax = ax,
    node_size = 45, 
    node_color = 'xkcd:black',
    linewidths = 0.0,
    edge_color = "0.9",
    width=0.25,
    alpha = 0.75, 
    with_labels = False)

fig = plt.gcf()
fig.set_size_inches(7.5, 7.5)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### *Function* to retrieve node colors based of node values (i.e. weighted degree, logFC for gene)

# %%
def get_node_colors(node_values):
    
    '''
    This function takes a list of values for each node and color map, 
    normalizes the list of values from 0.0-1.0 and assigns each node 
    a color from a color map based on normalized values. Returns a 
    list of colors for nodes.
    '''
    color_map = []
    color_scheme = plt.get_cmap('bwr')
    node_values_normalized = (node_values-min(node_values))/(max(node_values) - min(node_values)) #normalize data

    for node_value in node_values_normalized:
        color_map.append(color_scheme(node_value))
        
    return color_map

# %% [markdown]
# #### *Function* to visualize network by weighted degree & logFC based on gene values

# %%
def visualize_network_color_by_weighted_deg_and_logFC(G, pos):
    
    #weighted degree for nodes in this network
    node_weighted_deg_values = G_deg_logFC_df.weighted_degree[list(G.nodes)] 
    
    #logFC for nodes in this network
    node_logFC_values = G_deg_logFC_df.mean_log2FC[list(G.nodes)] 
    
    fig = plt.figure(constrained_layout=True)

    gs = GridSpec(1, 2, figure=fig)

    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    
    #color nodes by weighted deg
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax1,
        node_size = 40, 
        node_color = get_node_colors(node_weighted_deg_values),
        linewidths = 0.0,
        edge_color = "0.83",
        width=0.1,
        alpha = 1.0, 
        with_labels = False)
    
    ax1.set_title(f'Nodes colored by Weighted Deg (blue -> red)', fontsize = 14, color = 'k')
    
    #color nodes by logFC
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax2,
        node_size = 40, 
        node_color = get_node_colors(node_logFC_values),
        linewidths = 0.0,
        edge_color = "0.83",
        width=0.1,
        alpha = 1.0, 
        with_labels = False)
    
    ax2.set_title(f'Nodes colored by mean logFC (blue -> red)', fontsize = 14, color = 'k')

    ################### Plot
    fig = plt.gcf()
    fig.set_size_inches(15.0, 7.5)
    fig.tight_layout()

    #file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
    #plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

    plt.show()

# %%
visualize_network_color_by_weighted_deg_and_logFC(S, pos)

# %% [markdown]
# ## [3.2] Run community detection algorithms and check to see which yields the highest modularity

# %%
#run algorithms for COMMUNITY detection and return MODULARITY
mod_louvain = run_louvain_alg(S, True)
mod_girvan = run_girvan_alg(S, True)
mod_clauset = run_clauset_alg(S, True)

# %%
mod_louvain
# Out:
# 0.042433718893594916

# %%
mod_girvan
# Out:
# 4.7925874559941684e-05

# %%
mod_clauset
# Out:
# -2.851161064174396e-16

# %% [markdown]
# ### Run *Louvain* algorithm on sub-network and return communities

# %%
community_df = run_louvain_alg(S, False)
# Out:
# Modularity:  0.04292256591021143
# Total number of Communities = 4

# %%
community_df
# Out:
#                                              Members  Num_Members
# 0  IRF7 | DUSP3 | PASK | ID3 | CD96 | SCO2 | TAP1...          131
# 1  LBH | CETP | WARS | RTP4 | GBP4 | KRT72 | PROS...          121
# 2  CCR7 | TLR8 | HIP1R | CXCR3 | DEFA1 | SORT1 | ...          118
# 3                                        IL1A | CCL7            2

# %% [markdown]
# ## [3.3] Visualize communites within sub-network

# %% [markdown]
# #### *Function* to color a subset of nodes differently

# %%
def draw_graph_and_color_subset_nodes(G, nodes_in_group, ax):

    '''
    This function takes in a graph, list of a subset of nodes and axis object,
    then draws the network with the subset of nodes colored seperately from the 
    rest of the nodes in the network
    '''

    #draw nodes NOT in the (subset) group
    size_map = []
    for node in G:
        if node not in nodes_in_group:
            size_map.append(35)
        elif node in nodes_in_group:
            size_map.append(0)

    nx.draw_networkx(
        G, 
        ax = ax,
        pos=pos, 
        node_size=size_map, 
        node_color = "0.8",
        linewidths = 0.0,
        edge_color="0.7",
        width=0.0,
        alpha=1.0, 
        with_labels=False)

    #draw nodes that ARE in the (subset) group
    size_map = []
    for node in G:
        if node not in nodes_in_group:
            size_map.append(0)
        elif node in nodes_in_group:
            size_map.append(35)

    nx.draw_networkx(
        G, 
        pos=pos, 
        ax = ax,
        node_size=size_map, 
        node_color = 'xkcd:black',
        linewidths = 0.0,
        edge_color="0.7",
        width=0.0,
        alpha=1.0, 
        with_labels=False)

# %% [markdown]
# #### *Function* to plot a set of genes in within community

# %%
def draw_community_subgraph_network(G, comm_i):
    
    fig = plt.figure(constrained_layout=True)

    gs = GridSpec(1, 1, figure=fig)

    ax1 = fig.add_subplot(gs[0, 0])
    
    ################### VISUALIZE COMMUNITY ###################
    #get the set of nodes within the community
    nodes_in_community = set(community_df.loc[comm_i, 'Members'].split(' | '))
    number_of_nodes = len(nodes_in_community)

    #get the subgraph generated by nodes in community
    G_community_subgraph = G.subgraph(list(nodes_in_community)) 

    #draw the network & color the community differently
    draw_graph_and_color_subset_nodes(G, nodes_in_community, ax1)
    
    ax1.set_title(f'Community {comm_i} with {number_of_nodes} members', fontsize = 12, color = 'k')

    ################### Plot ###################
    fig = plt.gcf()
    fig.set_size_inches(7.5, 7.5)
    fig.tight_layout()

    #file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
    #plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

    plt.show()

# %% [markdown]
# ### Visualize different communities

# %%
draw_community_subgraph_network(S, 0)

# %%
draw_community_subgraph_network(S, 1)

# %%
draw_community_subgraph_network(S, 2)

# %%
draw_community_subgraph_network(S, 3)

# %% [markdown]
# ## [3.4] Run gene-enrichment analysis on genes within communities

# %% [markdown]
# ### Load and prepare gene sets

# %% [markdown]
# DataFrame for the Gene Sets (excel files from Wen-Han)

# %%
GeneSets_df = pd.read_csv(f'{Gene_Set_dir}GeneModule.csv')

#subset to the first 298 modules (immune-related modules)
GeneSets_df = GeneSets_df.loc[0:297, :]

# %%
GeneSets_df.head()
# Out:
#         ID                                    Title            Category   B
# 0    LI.M0                       targets of FOSL1/2          TF targets  12
# 1  LI.M1.0   integrin cell surface interactions (I)  molecular function  29
# 2  LI.M1.1  integrin cell surface interactions (II)  molecular function  12
# 3  LI.M2.0                 extracellular matrix (I)            location  30
# 4  LI.M2.1                extracellular matrix (II)            location  45

# %%
np.shape(GeneSets_df)
# Out:
# (298, 4)

# %% [markdown]
# DataFrame for the genes that belong to each Gene Set

# %%
GeneSet_GeneLists_df = pd.read_csv(f'{Gene_Set_dir}GeneModule_Genelist.csv')
GeneSet_GeneLists_df.set_index('ID', drop = True, inplace = True)

# %%
GeneSet_GeneLists_df.head()
# Out:
#        Gene
# ID
# LI.M0  CCL2
# LI.M0   DCN
# LI.M0   LIF
# LI.M0  PLAU
# LI.M0   IL6

# %%
np.shape(GeneSet_GeneLists_df)
# Out:
# (84042, 1)

# %% [markdown]
# #### Convert gene sets to a dictionary
# - keys: gene sets
# - values: list of genes belonging to each set

# %%
gene_set_dict = {}
for gene_set_i in GeneSets_df.ID:
    gene_list_for_set_i = list(GeneSet_GeneLists_df[GeneSet_GeneLists_df.index == gene_set_i].Gene)
    
    if gene_list_for_set_i == []:
        print(gene_set_i)
    
    gene_set_dict[gene_set_i] = gene_list_for_set_i

# %%
len(gene_set_dict.keys()) #number of gene sets
# Out:
# 298

# %% [markdown]
# #### *Function* to run gene set enrichment

# %%
def run_enrichr_on_list_of_genes(gene_list):
    
    #run enrichr
    enr = gp.enrichr(gene_list = gene_list,  
        gene_sets = gene_set_dict,
        background = 'hsapiens_gene_ensembl',
        organism = 'Human',
        description = f'community pathway enrichment',
        outdir = f'{Data_files_dir}/enrichr gene set analyses bucket',
        no_plot = True)

    #filter & sort enrichr results df
    enrichr_results_df = enr.results
    enrichr_results_df = enrichr_results_df.loc[: , ['Term', 'P-value', 'Adjusted P-value', 'Overlap', 'Genes']] #subset to necessary columns
    enrichr_results_df.rename(columns = {'Term':'ID'}, inplace = True) #rename column for merging with Gene Set df
    enrichr_results_df = enrichr_results_df[enrichr_results_df.loc[: , 'Adjusted P-value'] <= 0.001] #keep hits with lowest adj. p-vals
    enrichr_results_df.sort_values(by = 'Adjusted P-value', ascending = True , inplace = True) #sort by lowest p-val
    enrichr_results_df.reset_index(inplace = True, drop = True) #reset index
    enrichr_results_df = enrichr_results_df.merge(GeneSets_df.loc[: , ['ID','Title','Category']], how = 'left', on = 'ID') #get details for gene sets
    
    return enrichr_results_df

# %% [markdown]
# ### Run gene set enrichment on genes detected within different communities

# %% [markdown]
# Community 0

# %%
community_i = 0
community_node_list = community_df.loc[community_i,'Members'].split(' | ') #get list of genes that belong to the community
run_enrichr_on_list_of_genes(community_node_list) #pathway enrichment
# Out:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M4.1  3.722485e-20      2.977988e-18   15/58
# 1    DC.M5.12  5.725217e-15      2.290087e-13   12/59
# 2     DC.M3.4  2.544940e-12      6.786506e-11   10/53
# 3    DC.M4.15  3.922870e-10      7.845739e-09    8/42
# 4     LI.M7.0  1.001585e-08      1.602536e-07    8/62
# 5     LI.M150  1.014885e-06      1.353180e-05    4/12
# 6     LI.M7.4  2.754125e-06      3.147572e-05    4/15
# 7   LI.M111.0  4.751051e-06      4.751051e-05    4/17
# 8     LI.M7.1  2.359721e-05      2.097530e-04    5/50
# 9     DC.M1.2  3.321421e-05      2.657137e-04    4/27
# 10     LI.M68  3.686634e-05      2.681189e-04    3/10
# 11   LI.M11.0  4.965703e-05      3.103762e-04   8/189
# 12  LI.M111.1  5.043614e-05      3.103762e-04    3/11
# 13     LI.M14  6.690989e-05      3.568528e-04    3/12
# 14     LI.M67  6.690989e-05      3.568528e-04    3/12
# 15   LI.M61.2  1.669173e-04      8.345863e-04    3/16
#
#                                                 Genes  \
# 0   ID3;LEF1;TXK;HPCAL4;HOOK1;KLHL3;LRRN3;GAL3ST4;...
# 1   BST2;ACTA2;RNF213;ASPRV1;TYMP;LGALS9;TAP2;TMEM...
# 2   MT2A;MOV10;ZBP1;GBP6;SCO2;IRF7;SEPT4;STAT2;PML...
# 3      ZNF256;TC2N;ITK;S1PR1;CD96;CD247;OCIAD2;ZNF831
# 4           LEF1;ETS1;ITK;KLRB1;CD96;CD247;IL7R;NELL2
# 5                                 OASL;TAP1;OAS3;IRF7
# 6                                LEF1;CD96;NELL2;ETS1
# 7                                BST2;TAP1;IFI35;ZBP1
# 8                             LEF1;TXK;ITK;CD247;IL7R
# 9                                OASL;LY6E;OAS3;ISG15
# 10                                  IRF7;ISG15;TRIM25
# 11  CRISPLD2;ADAP2;FCGR1A;NOD2;ASGR1;TYMP;LILRA6;HPSE
# 12                                     BST2;TAP1;ZBP1
# 13                                      LRRN3;ITK;TXK
# 14                                       C2;IRF7;C1QC
# 15                                     ITK;CD247;CD96
#
#                                                 Title Category
# 0                                              T cell    DC.M4
# 1                                          Interferon    DC.M5
# 2                                          Interferon    DC.M3
# 3                                             T cells    DC.M4
# 4                             enriched in T cells (I)   immune
# 5                           innate antiviral response   immune
# 6                             T cell activation (III)   immune
# 7   viral sensing & immunity; IRF2 targets network...   immune
# 8                               T cell activation (I)   immune
# 9                                          Interferon    DC.M1
# 10                      RIG-1 like receptor signaling   immune
# 11                         enriched in monocytes (II)   immune
# 12  viral sensing & immunity; IRF2 targets network...   immune
# 13                             T cell differentiation   immune
# 14                          activated dendritic cells   immune
# 15         enriched in NK cells (receptor activation)   immune

# %% [markdown]
# Community 1

# %%
community_i = 1
community_node_list = community_df.loc[community_i,'Members'].split(' | ') #get list of genes that belong to the community
run_enrichr_on_list_of_genes(community_node_list) #pathway enrichment
# Out:
#          ID       P-value  Adjusted P-value Overlap  \
# 0   DC.M3.4  3.088377e-23      2.686888e-21   16/53
# 1   DC.M1.2  5.131173e-18      2.232060e-16   11/27
# 2    LI.M75  5.795310e-15      1.680640e-13    9/22
# 3   LI.M165  1.180773e-14      2.568181e-13   10/35
# 4   LI.M127  5.204612e-11      9.056024e-10    6/12
# 5  DC.M5.12  1.202887e-10      1.744187e-09    9/59
# 6  LI.M37.0  6.632322e-10      8.243028e-09  16/347
# 7   LI.M150  7.383525e-07      7.137408e-06    4/12
# 8    LI.M67  7.383525e-07      7.137408e-06    4/12
# 9   DC.M4.2  1.312427e-05      1.141811e-04    5/48
#
#                                                Genes  \
# 0  WARS;GBP1;PLSCR1;GBP4;IFIH1;CARD17;IFIT2;OAS2;...
# 1  IFI44;RTP4;LAMP3;HERC5;OAS2;CXCL10;IFIT1;OAS1;...
# 2  DDX60;IFIH1;HERC5;ANXA3;CXCL10;IFIT1;OAS1;RSAD...
# 3  LAMP3;DOCK4;IFIH1;HERC5;IFIT2;IFIT1;TNFAIP6;RS...
# 4               PLSCR1;DDX60;IFIH1;HERC5;IFIT1;RSAD2
# 5  ETV7;LHFPL2;CHMP5;GBP2;TRAFD1;TCN2;DYNLT1;C1QA...
# 6  TLR5;KCNJ15;DEFA4;NLRC4;CD19;LCN2;LPCAT2;STX11...
# 7                            OAS1;IFIT1;PLSCR1;RSAD2
# 8                           IFIH1;DDX60;PLSCR1;RSAD2
# 9                       TLR5;MAPK14;ANXA3;VNN1;CASP5
#
#                                         Title Category
# 0                                  Interferon    DC.M3
# 1                                  Interferon    DC.M1
# 2                     antiviral IFN signature   immune
# 3  enriched in activated dendritic cells (II)   immune
# 4                  type I interferon response   immune
# 5                                  Interferon    DC.M5
# 6         immune activation - generic cluster   immune
# 7                   innate antiviral response   immune
# 8                   activated dendritic cells   immune
# 9                                Inflammation    DC.M4

# %% [markdown]
# Community 2

# %%
community_i = 2
community_node_list = community_df.loc[community_i,'Members'].split(' | ') #get list of genes that belong to the community
run_enrichr_on_list_of_genes(community_node_list) #pathway enrichment
# Out:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  1.562569e-21      1.453189e-19   15/53
# 1    LI.M37.0  1.741883e-17      8.099755e-16  23/347
# 2    LI.M11.0  1.273082e-16      3.946555e-15  18/189
# 3    DC.M5.15  4.615225e-09      1.073040e-07    6/23
# 4     LI.M4.0  1.624147e-07      3.020913e-06  13/335
# 5      LI.M16  3.813067e-07      5.910253e-06    6/46
# 6     DC.M4.1  1.550951e-06      1.802980e-05    6/58
# 7   LI.M118.0  1.397533e-06      1.802980e-05    6/57
# 8     DC.M3.2  2.323872e-06      2.401335e-05   8/138
# 9     DC.M1.2  2.202899e-05      2.048696e-04    4/27
# 10      LI.S4  2.602854e-05      2.090330e-04    6/94
# 11    LI.M113  2.697200e-05      2.090330e-04    3/10
# 12  LI.M111.1  3.691879e-05      2.641113e-04    3/11
# 13    LI.M127  4.900251e-05      3.255167e-04    3/12
# 14     LI.M40  6.341535e-05      3.931751e-04    3/13
# 15    LI.M109  9.997851e-05      5.811251e-04    3/15
# 16   DC.M4.15  1.307771e-04      7.154275e-04    4/42
# 17    LI.M5.0  1.477262e-04      7.632521e-04    5/81
#
#                                                 Genes  \
# 0   UBE2L6;LGALS3BP;GBP5;FBXO6;LAP3;APOL6;TNFSF10;...
# 1   PRRG4;P2RY13;CLEC4D;CAMP;CYFIP1;BPI;MEGF9;DEFA...
# 2   BST1;CYFIP1;LMO2;CYBB;S100A12;MNDA;FCGR1B;MEGF...
# 3                        MMP8;HP;BPI;CEACAM8;LTF;CAMP
# 4   LMO2;CYBB;S100A12;MNDA;FCGR1B;CEACAM8;FAM198B;...
# 5                   LY96;BST1;FCGR1B;P2RY13;TLR7;TLR8
# 6            CCR7;FAM102A;TNFRSF25;BACH2;DHRS3;SPOCK2
# 7                 LY96;MARC1;NAIP;DPYD;LRRK2;TNFSF13B
# 8     LY96;BST1;PLXNC1;MEGF9;SULT1B1;CREB5;MSRB1;TLR8
# 9                          SERPING1;XAF1;BATF2;IFITM3
# 10              FCGR1B;CCR2;P2RY13;CLEC12A;CD36;MCTP1
# 11                                 FAM198B;SORT1;TLR8
# 12                               DDX58;CASP1;TNFSF13B
# 13                                 PARP9;IFITM1;STAT1
# 14                                     LY96;C1QB;TLR8
# 15                                    CCR7;LRRK2;CCR2
# 16                                  CD6;CD5;ARL4C;CD7
# 17                         CCR7;LY96;MNDA;FCGR1B;TLR7
#
#                                                 Title            Category
# 0                                          Interferon               DC.M3
# 1                 immune activation - generic cluster              immune
# 2                          enriched in monocytes (II)              immune
# 3                                         Neutrophils               DC.M5
# 4                        cell cycle and transcription  biological process
# 5                      TLR and inflammatory signaling              immune
# 6                                              T cell               DC.M4
# 7                          enriched in monocytes (IV)              immune
# 8                                        Inflammation               DC.M3
# 9                                          Interferon               DC.M1
# 10                         Monocyte surface signature              immune
# 11                                 golgi membrane (I)            location
# 12  viral sensing & immunity; IRF2 targets network...              immune
# 13                         type I interferon response              immune
# 14              complement and other receptors in DCs              immune
# 15                          receptors, cell migration  molecular function
# 16                                            T cells               DC.M4
# 17  regulation of antigen presentation and immune ...              immune

# %% [markdown]
# Community 3

# %%
community_i = 3
community_node_list = community_df.loc[community_i,'Members'].split(' | ') #get list of genes that belong to the community
run_enrichr_on_list_of_genes(community_node_list) #pathway enrichment
# Out:
# Empty DataFrame
# Columns: [P-value, Adjusted P-value, Overlap, Genes, ID, Title, Category]
# Index: []

# %% [markdown]
# ## [4] Calculate *mean edge weight*, *mean weighted degree*, *num edges*, *num nodes* & *community modularities* for subgraphs induced by highest weighted edges

# %% [markdown]
# ### Edges Weights for Node Pairs (gene pairs)

# %%
edge_weight_dict = nx.get_edge_attributes(G, 'weight') #keys: node pairs; values: edge weights
edge_weight_array = np.array(list(edge_weight_dict.values())) #array of edge weights in graph

# %%
len(edge_weight_array)
# Out:
# 672127

# %%
edge_weight_array.mean()
# Out:
# 0.2537207006017215

# %% [markdown]
# ### Distribution of Edge Weights in original Network

# %%
def prettify_plot(ax):
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.grid(False)
    ax.tick_params(labelcolor = 'k')
    ax.tick_params(axis='y', which='major', labelsize=12 , labelcolor = 'k')
    ax.tick_params(axis='x', which='major', labelsize=12 , labelcolor = 'k')

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(1, 1, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])

#EDGE WEIGHTS
ax1.hist(edge_weight_array , bins = len(set(edge_weight_array)), color = 'black' , rwidth = 0.95 , edgecolor='white', linewidth=0.0, align='left')

ax1.set_ylabel('Number of Edges', fontsize = 12, color = 'k')
ax1.set_xlabel('Edge Weight' , fontsize = 12, color = 'k')

prettify_plot(ax1)
#ax1.set_yscale('log')
    
################### Plot ###################
fig = plt.gcf()
fig.set_size_inches(9, 5.5)
fig.tight_layout()

#file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
#plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()

# %%
edge_weight_thresholds = np.sort(np.array(list(set(edge_weight_array))))
edge_weight_thresholds
# Out:
# array([0.2       , 0.26666667, 0.33333333, 0.4       , 0.46666667,
#        0.53333333, 0.6       , 0.66666667, 0.73333333, 0.8       ,
#        0.86666667])

# %%
def get_characteristics_of_subgraph(edge_weight_thresh):
    
    '''
    (1) This function returns the mean (edge weight) & (weighted degree) of the subgraph induced by the edges 
    that pass the edge weight threshold in the larger network.
    
    (2) Function returns the (# Edges) and (# Nodes) for these different subgraphs.
    
    (3) Function also returns the modularity after running a community detection
    algorithm on the subgraph
    '''
    
    #get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
    edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
    edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

    #get the SUBGRAPH induced by the most heavily weighted edges
    S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))

    #Get a series of the WEIGHTED DEGREE for each node in the subgraph 
    node_list = [node_deg[0] for node_deg in list(S.degree(weight = 'weight'))]
    degree_list = [node_deg[1] for node_deg in list(S.degree(weight = 'weight'))]
    subgraph_weighted_degree_series = pd.Series(degree_list , index = node_list).sort_values(ascending = False)
    
    #run algorithms for COMMUNITY detection and return MODULARITY
    mod_louvain = run_louvain_alg(S, True)
    mod_girvan = run_girvan_alg(S, True)
    mod_clauset = run_clauset_alg(S, True)
    
    return [edge_weight_array_subset.mean() , subgraph_weighted_degree_series.mean() , float(len(edge_weight_array_subset)) , float(len(node_list)) , mod_louvain, mod_girvan, mod_clauset]

# %% [markdown]
# #### Iterate through subnetworks of various sizes for different *edge weight thresholds* in original network

# %%
mean_edge_weight_for_subnetworks_list = []
mean_weighted_deg_for_subnetworks_list = []
num_edges_for_subnetworks_list = []
num_nodes_for_subnetworks_list = []
louvain_modularity_for_subnetworks_list = []
girvan_modularity_for_subnetworks_list = []
clauset_modularity_for_subnetworks_list = []

for edge_weight_thresh in edge_weight_thresholds:
    
    subgraph_mean_edge_weight , subgraph_mean_weighted_deg , subgraph_num_edges , subgraph_num_nodes , subgraph_comm_mod_louvain , subgraph_comm_mod_girvan , subgraph_comm_mod_clauset = get_characteristics_of_subgraph(edge_weight_thresh)
    
    mean_edge_weight_for_subnetworks_list.append(subgraph_mean_edge_weight)
    mean_weighted_deg_for_subnetworks_list.append(subgraph_mean_weighted_deg)
    num_edges_for_subnetworks_list.append(subgraph_num_edges)
    num_nodes_for_subnetworks_list.append(subgraph_num_nodes)
    louvain_modularity_for_subnetworks_list.append(subgraph_comm_mod_louvain)
    girvan_modularity_for_subnetworks_list.append(subgraph_comm_mod_girvan)
    clauset_modularity_for_subnetworks_list.append(subgraph_comm_mod_clauset)
    
    print(edge_weight_thresh)
    
#convert to arrays
mean_edge_weight_for_subnetworks = np.array(mean_edge_weight_for_subnetworks_list)
mean_weighted_deg_for_subnetworks = np.array(mean_weighted_deg_for_subnetworks_list)
num_edges_for_subnetworks = np.array(num_edges_for_subnetworks_list)
num_nodes_for_subnetworks = np.array(num_nodes_for_subnetworks_list)
louvain_modularity_for_subnetworks = np.array(louvain_modularity_for_subnetworks_list)
girvan_modularity_for_subnetworks = np.array(girvan_modularity_for_subnetworks_list)
clauset_modularity_for_subnetworks = np.array(clauset_modularity_for_subnetworks_list)
# Out:
# 0.2
# 0.26666666666666666
# 0.3333333333333333
# 0.4
# 0.4666666666666667
# 0.5333333333333333
# 0.6
# 0.6666666666666666
# 0.7333333333333333
# 0.8
# 0.8666666666666667

# %% [markdown]
# #### Plot various characteristics of subgraphs induced by highest weighted edges

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(2, 3, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[0, 2])
ax6 = fig.add_subplot(gs[1, 2])

#EDGE WEIGHT
ax1.scatter(edge_weight_thresholds, mean_edge_weight_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax1.plot(edge_weight_thresholds, mean_edge_weight_for_subnetworks , color = 'black' , linewidth=1.0)

ax1.set_ylabel('Mean Edge Weight in Subgraph', fontsize = 12, color = 'k')
ax1.set_title('Edges', fontsize = 12, color = 'k')

prettify_plot(ax1)
    
#WEIGHTED DEGREE
ax2.scatter(edge_weight_thresholds, mean_weighted_deg_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax2.plot(edge_weight_thresholds, mean_weighted_deg_for_subnetworks , color = 'black' , linewidth=1.0)

ax2.set_ylabel('Mean Weighted Degree in Subgraph', fontsize = 12, color = 'k')
ax2.set_title('Nodes', fontsize = 12, color = 'k')

prettify_plot(ax2)

#NUMBER OF EDGES
ax3.scatter(edge_weight_thresholds, num_edges_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax3.plot(edge_weight_thresholds, num_edges_for_subnetworks , color = 'black' , linewidth=1.0)

ax3.set_ylabel('Number of Edges in Subgraph', fontsize = 12, color = 'k')
ax3.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')

prettify_plot(ax3)

#NUMBER OF NODES
ax4.scatter(edge_weight_thresholds, num_nodes_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax4.plot(edge_weight_thresholds, num_nodes_for_subnetworks , color = 'black' , linewidth=1.0)

ax4.set_ylabel('Number of Nodes in Subgraph', fontsize = 12, color = 'k')
ax4.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')

prettify_plot(ax4)

#MODULARITY
#for communities detected in subnetworks using Lovain, Girvan-Newman, Clauset-Newman-Moore Algorithms
ax5.scatter(edge_weight_thresholds, louvain_modularity_for_subnetworks , color = 'green' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0, label = 'Louvain')
ax5.plot(edge_weight_thresholds, louvain_modularity_for_subnetworks , color = 'green' , linewidth=1.0)

ax5.scatter(edge_weight_thresholds, girvan_modularity_for_subnetworks , color = 'blue' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0 , label = 'Girvan-Newman')
ax5.plot(edge_weight_thresholds, girvan_modularity_for_subnetworks , color = 'blue' , linewidth=1.0)

ax5.scatter(edge_weight_thresholds, clauset_modularity_for_subnetworks , color = 'red' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0 , label = 'Clauset-Newman-Moore')
ax5.plot(edge_weight_thresholds, clauset_modularity_for_subnetworks , color = 'red' , linewidth=1.0)

ax5.set_ylabel('Modularity', fontsize = 12, color = 'k')
ax5.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')
#ax5.set_title('Communities detected from Lovain Algorithm', fontsize = 12, color = 'k')
ax5.legend(loc="upper left", fancybox = False)

prettify_plot(ax5)

#MODULARITY v. NUMBER OF NODES
ax6.scatter(num_nodes_for_subnetworks , louvain_modularity_for_subnetworks, color = 'green' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax6.plot(num_nodes_for_subnetworks , louvain_modularity_for_subnetworks, color = 'green' , linewidth=1.0)

ax6.scatter(num_nodes_for_subnetworks , girvan_modularity_for_subnetworks, color = 'blue' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax6.plot(num_nodes_for_subnetworks , girvan_modularity_for_subnetworks, color = 'blue' , linewidth=1.0)

ax6.scatter(num_nodes_for_subnetworks , clauset_modularity_for_subnetworks, color = 'red' , linewidth=0.75 , edgecolor = 'white' , s = 35 , alpha = 1.0)
ax6.plot(num_nodes_for_subnetworks , clauset_modularity_for_subnetworks, color = 'red' , linewidth=1.0)

ax6.set_ylabel('Modularity', fontsize = 12, color = 'k')
ax6.set_xlabel('Number of Nodes in Subgraph' , fontsize = 12, color = 'k')

prettify_plot(ax6)
    
################### Plot ###################
fig = plt.gcf()
fig.set_size_inches(18, 10)
fig.tight_layout()

#file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
#plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()

# %% [markdown]
# ## [5] Iterate through subnetworks constructed from most heavily weighted edges and preform gene enrichment analysis

# %% [markdown]
# ### *Function* to plot subnetworks (after thresholding edge weights) & perform gene enrichment on nodes

# %%
def subgraph_visualize_and_gene_enrichment(edge_weight_thresh):
    
    '''
    (1) This function returns visualizes the sub-network generated by 
    retaining only the edge weights above the input edge weight threshold.
        (1.1) colors nodes by weighted degree
        (1.2) colors nodes by mean logFC
        
    (2) This function also returns a dataframe from the gene enrichment 
    analysis run on the nodes of the subnetwork.
    '''
    
    #get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
    edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
    edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

    #get the SUBGRAPH induced by the most heavily weighted edges
    S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))
    
    #print some stats
    print('')
    print('')
    print('')
    print('')
    print(f'Edge Weight Threshold = {edge_weight_thresh}')
    print(f'Number of Nodes = {len(S.nodes)}')
    print('---------------------------------------------')
    
    #visualize subgraph
    pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 1.75)
    visualize_network_color_by_weighted_deg_and_logFC(S, pos)
    
    #gene set enrichment
    gene_enrichr_df = run_enrichr_on_list_of_genes(list(S.nodes))
    print(f'gene enrichment for nodes in this network: ')
    display(gene_enrichr_df.head(n=40)) #return the top 40 hits if there are > 40
    print('---------------------------------------------')
    
    ## return gene_enrichr_df

# %% [markdown]
# ### Iterate through subnetworks of various sizes for different *edge weight thresholds* in original network

# %%
for edge_weight_thresh_i, num_nodes_subnetwork_i in zip(edge_weight_thresholds, num_nodes_for_subnetworks):
    print(f'Edge Weight Threshold = {edge_weight_thresh_i} , Number of Nodes in Subnetwork = {num_nodes_subnetwork_i}')
# Out:
# Edge Weight Threshold = 0.2 , Number of Nodes in Subnetwork = 3005.0
# Edge Weight Threshold = 0.26666666666666666 , Number of Nodes in Subnetwork = 1580.0
# Edge Weight Threshold = 0.3333333333333333 , Number of Nodes in Subnetwork = 1038.0
# Edge Weight Threshold = 0.4 , Number of Nodes in Subnetwork = 726.0
# Edge Weight Threshold = 0.4666666666666667 , Number of Nodes in Subnetwork = 502.0
# Edge Weight Threshold = 0.5333333333333333 , Number of Nodes in Subnetwork = 342.0
# Edge Weight Threshold = 0.6 , Number of Nodes in Subnetwork = 227.0
# Edge Weight Threshold = 0.6666666666666666 , Number of Nodes in Subnetwork = 141.0
# Edge Weight Threshold = 0.7333333333333333 , Number of Nodes in Subnetwork = 81.0
# Edge Weight Threshold = 0.8 , Number of Nodes in Subnetwork = 38.0
# Edge Weight Threshold = 0.8666666666666667 , Number of Nodes in Subnetwork = 9.0

# %% [markdown]
# We're going to start with the smallest **edge weight threshold** and iterate down from there (increase edge weight threshold but decrease # of nodes) to preform gene enrichment

# %%
for edge_weight_thresh in edge_weight_thresholds:
    
    subgraph_visualize_and_gene_enrichment(edge_weight_thresh)
# Out:
# Edge Weight Threshold = 0.2
# Number of Nodes = 3005
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value  Overlap  \
# 0    LI.M37.0  1.946672e-61      5.275480e-59  187/347
# 1    LI.M11.0  4.325349e-51      5.860848e-49  121/189
# 2     DC.M3.2  2.934565e-37      2.650891e-35   88/138
# 3     DC.M3.4  5.554653e-35      3.763278e-33    49/53
# 4    DC.M5.12  1.621619e-31      8.789173e-30    50/59
# 5     DC.M4.1  8.831237e-31      3.988776e-29    49/58
# 6    DC.M4.15  4.191031e-30      1.622528e-28    40/42
# 7     LI.M7.0  6.775203e-27      2.295100e-25    48/62
# 8     LI.M7.1  2.360145e-26      7.106660e-25    42/50
# 9     LI.M7.2  1.319019e-21      3.574541e-20    38/49
# 10      LI.S4  3.432470e-21      8.456359e-20    55/94
# 11    DC.M4.2  6.555373e-21      1.480422e-19    37/48
# 12    DC.M4.7  2.740303e-20      5.712478e-19   56/100
# 13   LI.M37.1  4.883538e-20      9.453134e-19    38/52
# 14    LI.M5.0  6.690262e-20      1.208707e-18    49/81
# 15     LI.M16  1.588609e-19      2.690707e-18    35/46
# 16    LI.M4.0  1.147845e-18      1.829800e-17  118/335
# 17     LI.M75  2.143926e-18      3.227799e-17    22/22
# 18   DC.M4.10  1.802698e-17      2.571216e-16    27/32
# 19    DC.M3.6  1.019088e-16      1.380865e-15    33/47
# 20  LI.M118.0  7.641125e-16      9.860690e-15    36/57
# 21   LI.M47.0  2.436459e-15      3.001274e-14    34/53
# 22    DC.M4.6  3.128040e-14      3.685647e-13   52/113
# 23    DC.M1.2  7.682449e-14      8.674765e-13    22/27
# 24   DC.M6.13  2.974548e-13      3.100394e-12    30/48
# 25    LI.M165  2.968444e-13      3.100394e-12    25/35
# 26    LI.M7.3  7.219704e-13      7.246443e-12    23/31
# 27      LI.S0  1.529529e-12      1.480365e-11    21/27
# 28     LI.M69  1.584378e-11      1.431222e-10    17/20
# 29   LI.M47.1  1.582496e-11      1.431222e-10    26/42
# 30    LI.M7.4  7.417451e-11      6.484288e-10    14/15
# 31     LI.M19  9.008731e-11      7.629269e-10    15/17
# 32     LI.M14  2.343212e-10      1.924274e-09    12/12
# 33     LI.M18  1.489356e-09      1.187104e-08    11/11
# 34    LI.M4.3  1.132703e-08      8.770360e-08    19/31
# 35     LI.M67  1.529474e-08      1.090756e-07    11/12
# 36    LI.M127  1.529474e-08      1.090756e-07    11/12
# 37    LI.M150  1.529474e-08      1.090756e-07    11/12
# 38   DC.M4.14  5.304975e-08      3.686278e-07    27/59
# 39    LI.M223  8.509431e-08      5.765140e-07    11/13
#
#                                                 Genes  \
# 0   CXCL1;AQP9;SLC19A2;FCGR3A;HNRNPLL;BPI;BASP1;DE...
# 1   FES;TIMP2;CYP1B1;AQP9;TLR2;TLR8;TYMP;MAFB;CEBP...
# 2   NAMPT;TIMP2;AQP9;TLR8;ZNF438;EXOC6;DGAT2;BASP1...
# 3   UBE2L6;LGALS3BP;LAP3;ZNF684;IRF7;CARD17;OAS2;I...
# 4   TDRD7;ETV7;BTN3A1;LHFPL2;ZNFX1;ACTA2;TRAFD1;SP...
# 5   CCR7;LEF1;STMN3;TNFRSF25;THNSL1;BACH2;LRRN3;TR...
# 6   PLEKHA1;MORC4;PRKCH;ZNF256;LBH;SH2D1A;CHMP7;PL...
# 7   LEF1;PRKCH;SH2D1A;SAMD3;GZMM;TRAT1;IL7R;ITM2A;...
# 8   CCR7;PRKCH;LEF1;MS4A1;RHOH;IL7R;CD5;CD3E;CAMK4...
# 9   PRKCH;MYBL1;STAT4;FCGR3B;SAMD3;CLIC3;GZMM;GNLY...
# 10  NFAM1;BRI3;SLC7A7;CCR2;TREM1;ASGR1;P2RY13;MARC...
# 11  LMNB1;PGLYRP1;LRG1;MAPK14;KREMEN1;SERPINA1;MCT...
# 12  SUN1;ZNF721;CCND2;TRAF5;ZMYND11;MTR;ZNF529;TSH...
# 13  RGL4;RNF24;LRG1;FCGR3B;NCF4;TREM1;FFAR2;FCGR3A...
# 14  CCR7;CSK;MAPK14;TRAT1;CARD11;TLR2;JUN;PLCG1;FY...
# 15  FCGR1A;FES;NCF4;P2RY13;AQP9;TLR2;TLR8;HSPA6;LI...
# 16  PGLYRP1;FES;TIMP2;POLA1;CYP1B1;TLR2;TLR8;ASF1B...
# 17  C1QB;IRF7;PTX3;CXCL10;PML;ELANE;OAS3;DDX60;ANX...
# 18  COBLL1;MS4A1;FCRLA;BANK1;OSBPL10;FCRL2;TSPAN13...
# 19  IFNG;KIR3DL2;SAMD3;CLIC3;GZMM;PRSS23;GNLY;MCOL...
# 20  NAIP;PTX3;ACSL1;ARHGEF10L;TNFSF13B;FGD4;HCAR3;...
# 21  ABCB4;PLEKHG1;MS4A1;P2RX5;FCRLA;TCF4;BANK1;FCR...
# 22  SELL;CSRNP1;GNG5;RIT1;AKIRIN2;BRI3;MLKL;ENTPD1...
# 23  OASL;OAS2;CXCL10;OTOF;IFI44;ISG15;TRIM6;LAMP3;...
# 24  RAB20;EIF4E3;NLRC4;NCF1;FES;VASP;RASGRP4;DRAM1...
# 25  PRRG4;FAM20C;CSF2RB;LAMP3;PDGFC;IFIT1;ATF3;PAR...
# 26  IFNG;STAT4;TRAT1;CD3E;CRTAM;CXCR3;GZMA;CD3G;PT...
# 27  LRRN3;ITM2A;LAG3;CD3E;CD6;NDFIP2;SIT1;SLC37A3;...
# 28  ABCB4;TSPAN13;CD22;CD19;BTLA;P2RX5;CD72;MS4A1;...
# 29  PLEKHG1;MS4A1;POU2AF1;FCRLA;TCF4;BANK1;KLF8;PA...
# 30  CAMK4;LCK;LEF1;ZMYND11;ETS1;RASGRP1;THEMIS;KLF...
# 31  HNRNPLL;LCK;LAT;GATA3;GZMK;CD28;DPP4;SIT1;MAL;...
# 32  TXK;RASGRP1;CD28;ITK;NOG;SH2D1A;MAL;LRRN3;TCF7...
# 33  PRKCH;ETS1;ABLIM1;ITK;SIRPG;SH2D1A;PRKCQ;BCL2;...
# 34  IGSF6;TLR5;SLC8A1;CCR1;LRRC25;SLC7A7;SLC24A4;M...
# 35  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;CD...
# 36  PLSCR1;DDX60;IFIH1;IRF7;STAT1;HERC5;IFIT1;RSAD...
# 37  PLSCR1;OAS3;IRF7;SP100;OASL;EIF2AK2;OAS1;IFIT1...
# 38  CPNE8;MS4A7;ENC1;SLC7A7;NAGA;ASGR1;FAM198B;RIN...
# 39  HOPX;SLC38A1;LBH;PLEKHF1;CD40LG;TC2N;FGFBP2;DP...
#
#                                                 Title            Category
# 0                 immune activation - generic cluster              immune
# 1                          enriched in monocytes (II)              immune
# 2                                        Inflammation               DC.M3
# 3                                          Interferon               DC.M3
# 4                                          Interferon               DC.M5
# 5                                              T cell               DC.M4
# 6                                             T cells               DC.M4
# 7                             enriched in T cells (I)              immune
# 8                               T cell activation (I)              immune
# 9                            enriched in NK cells (I)              immune
# 10                         Monocyte surface signature              immune
# 11                                       Inflammation               DC.M4
# 12                                         Cell Cycle               DC.M4
# 13                        enriched in neutrophils (I)              immune
# 14  regulation of antigen presentation and immune ...              immune
# 15                     TLR and inflammatory signaling              immune
# 16                       cell cycle and transcription  biological process
# 17                            antiviral IFN signature              immune
# 18                                             B cell               DC.M4
# 19                                  Cytotoxic/NK Cell               DC.M3
# 20                         enriched in monocytes (IV)              immune
# 21                            enriched in B cells (I)              immune
# 22                                       Inflammation               DC.M4
# 23                                         Interferon               DC.M1
# 24                                         Cell Death               DC.M6
# 25         enriched in activated dendritic cells (II)              immune
# 26                             T cell activation (II)              immune
# 27                           T cell surface signature              immune
# 28                           enriched in B cells (VI)              immune
# 29                           enriched in B cells (II)              immune
# 30                            T cell activation (III)              immune
# 31                       T cell differentiation (Th2)              immune
# 32                             T cell differentiation              immune
# 33             T cell differentiation via ITK and PKC              immune
# 34   myeloid cell enriched receptors and transporters              immune
# 35                          activated dendritic cells              immune
# 36                         type I interferon response              immune
# 37                          innate antiviral response              immune
# 38                                          Monocytes               DC.M4
# 39                           enriched in T cells (II)              immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.26666666666666666
# Number of Nodes = 1580
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value  Overlap  \
# 0    LI.M37.0  5.317578e-67      1.265584e-64  146/347
# 1    LI.M11.0  1.369254e-56      1.629412e-54   99/189
# 2     DC.M3.4  1.130525e-48      8.968833e-47    49/53
# 3     DC.M3.2  5.350264e-38      3.183407e-36   69/138
# 4    DC.M5.12  5.302613e-37      2.524044e-35    45/59
# 5     DC.M4.1  1.669867e-34      6.623807e-33    43/58
# 6    DC.M4.15  2.678966e-33      9.108485e-32    36/42
# 7     DC.M4.2  6.210096e-31      1.847504e-29    37/48
# 8     LI.M7.0  9.613701e-30      2.542290e-28    41/62
# 9     LI.M7.1  1.670385e-25      3.975516e-24    34/50
# 10    LI.M7.2  1.137766e-20      2.461712e-19    30/49
# 11     LI.M16  1.526771e-20      3.028096e-19    29/46
# 12      LI.S4  2.844988e-20      5.208517e-19    41/94
# 13    DC.M1.2  7.738529e-20      1.315550e-18    22/27
# 14     LI.M75  3.154146e-18      5.004579e-17    19/22
# 15    LI.M4.0  2.771355e-17      4.122390e-16   78/335
# 16    LI.M165  3.698053e-17      5.177275e-16    23/35
# 17    LI.M5.0  2.012031e-16      2.660352e-15    34/81
# 18   DC.M4.10  9.265296e-16      1.160600e-14    21/32
# 19    DC.M4.7  1.300875e-15      1.548041e-14   37/100
# 20    DC.M3.6  1.939361e-15      2.197942e-14    25/47
# 21    DC.M4.6  3.344546e-15      3.618191e-14   39/113
# 22   DC.M6.13  3.729717e-15      3.859446e-14    25/48
# 23  LI.M118.0  6.245796e-14      6.193747e-13    26/57
# 24   LI.M37.1  4.184240e-13      3.983396e-12    24/52
# 25    LI.M7.4  7.567684e-13      6.927341e-12    13/15
# 26   LI.M47.0  6.369259e-12      5.614384e-11    23/53
# 27    LI.M127  1.379734e-11      1.094589e-10    11/12
# 28     LI.M67  1.379734e-11      1.094589e-10    11/12
# 29     LI.M14  1.379734e-11      1.094589e-10    11/12
# 30    LI.M7.3  3.320571e-11      2.549341e-10    17/31
# 31     LI.M81  3.652521e-11      2.716563e-10    18/35
# 32  LI.M111.1  1.534057e-10      1.106381e-09    10/11
# 33     LI.M19  4.274173e-10      2.991921e-09    12/17
# 34    LI.M150  8.514477e-10      5.789844e-09    10/12
# 35    LI.M109  1.240138e-09      8.198690e-09    11/15
# 36    LI.M223  3.413246e-09      2.195547e-08    10/13
# 37   DC.M4.14  4.163219e-09      2.607490e-08    21/59
# 38   DC.M5.15  4.369641e-09      2.666601e-08    13/23
# 39      LI.S0  4.948964e-09      2.944633e-08    14/27
#
#                                                 Genes  \
# 0   AQP9;SLC19A2;FCGR3A;HNRNPLL;BPI;BASP1;DEFA1;ST...
# 1   FES;TIMP2;CYP1B1;AQP9;TLR2;TLR8;TYMP;MAFB;CSTA...
# 2   UBE2L6;LGALS3BP;LAP3;ZNF684;IRF7;CARD17;OAS2;I...
# 3   PHTF1;NAMPT;RNF24;QPCT;OSCAR;TIMP2;SULT1B1;AQP...
# 4   TDRD7;ETV7;LHFPL2;ZNFX1;ACTA2;TRAFD1;SP100;ASP...
# 5   CCR7;LEF1;STMN3;TNFRSF25;BACH2;LRRN3;TRAT1;TBC...
# 6   PLEKHA1;PRKCH;ZNF256;LBH;SH2D1A;PLCG1;OCIAD2;C...
# 7   LMNB1;PGLYRP1;LRG1;MAPK14;KREMEN1;SERPINA1;MCT...
# 8   LEF1;PRKCH;SH2D1A;SAMD3;GZMM;TRAT1;IL7R;GNLY;C...
# 9   CCR7;PRKCH;LEF1;RHOH;IL7R;CD5;CD3E;CAMK4;CD8A;...
# 10  PRKCH;MYBL1;STAT4;FCGR3B;SAMD3;CLIC3;GZMM;GNLY...
# 11  FCGR1A;FES;P2RY13;AQP9;TLR2;TLR8;HSPA6;TLR6;SI...
# 12  BRI3;CCR2;ASGR1;MARCO;P2RY13;TLR2;PYCARD;P2RX1...
# 13  OASL;OAS2;CXCL10;OTOF;IFI44;ISG15;TRIM6;LAMP3;...
# 14  C1QB;OAS3;IRF7;DDX60;SERPING1;HERC5;ANXA3;DDX5...
# 15  IGSF6;LMNB1;PGLYRP1;FES;MYOF;NCF1;FCN1;TIMP2;N...
# 16  PRRG4;FAM20C;CSF2RB;LAMP3;IFIT1;ATF3;PARP9;HER...
# 17  CCR7;MAPK14;TRAT1;CARD11;TLR2;JUN;PLCG1;FYN;CD...
# 18  COBLL1;FCRLA;BANK1;OSBPL10;FCRL2;TSPAN13;AFF3;...
# 19  ZNF721;CCND2;TRAF5;MTR;ZNF529;MTAP;GGA2;FYN;AT...
# 20  SAMD3;CLIC3;GZMM;PRSS23;GNLY;MCOLN2;IL2RB;CD8A...
# 21  SELL;CSRNP1;RIT1;AKIRIN2;BRI3;MLKL;ENTPD1;P2RY...
# 22  RAB20;EIF4E3;NLRC4;NCF1;FES;DRAM1;CSTA;HSPA6;S...
# 23  NAIP;ACSL1;TNFSF13B;FGD4;HCAR3;PTGS2;LTBR;SAMH...
# 24  RNF24;LRG1;FCGR3B;FFAR2;FCGR3A;HCAR3;BASP1;CYP...
# 25  CAMK4;LCK;LEF1;ETS1;RASGRP1;THEMIS;KLF12;ATP8B...
# 26  ABCB4;PLEKHG1;P2RX5;FCRLA;BANK1;FCRL2;TSPAN13;...
# 27  PLSCR1;DDX60;IFIH1;IRF7;STAT1;HERC5;IFIT1;RSAD...
# 28  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;CD...
# 29  TXK;RASGRP1;CD28;ITK;SH2D1A;MAL;LRRN3;TCF7;BCL...
# 30  PTPRCAP;LCK;SP140;CXCR3;STAT4;GZMA;ITK;SIRPG;Z...
# 31  CLEC5A;SLC8A1;EGF;PCSK6;F5;BCL6;CD14;ITGB3;CCR...
# 32  ZBP1;TAP1;BST2;PSMB10;PSMB8;DDX58;IFIT2;CXCL10...
# 33  HNRNPLL;LCK;LAT;GATA3;GZMK;CD28;MAL;SIT1;TRAT1...
# 34  PLSCR1;OAS3;IRF7;SP100;OASL;EIF2AK2;OAS1;IFIT1...
# 35  CCR7;LEF1;IL6R;SYNE2;GATA3;CCR2;S1PR1;BCL2;LRR...
# 36  HOPX;SLC38A1;LBH;PLEKHF1;CD40LG;TC2N;FGFBP2;DE...
# 37  CPNE8;MS4A7;ASGR1;FAM198B;RIN2;SCIMP;KYNU;CYFI...
# 38  TCN1;DEFA4;BPI;MPO;HP;MMP8;CTSG;CEACAM8;LTF;AR...
# 39  PTPRCAP;CD6;SLC38A1;CD2;CD28;MAL;SIT1;SIRPG;IC...
#
#                                                 Title            Category
# 0                 immune activation - generic cluster              immune
# 1                          enriched in monocytes (II)              immune
# 2                                          Interferon               DC.M3
# 3                                        Inflammation               DC.M3
# 4                                          Interferon               DC.M5
# 5                                              T cell               DC.M4
# 6                                             T cells               DC.M4
# 7                                        Inflammation               DC.M4
# 8                             enriched in T cells (I)              immune
# 9                               T cell activation (I)              immune
# 10                           enriched in NK cells (I)              immune
# 11                     TLR and inflammatory signaling              immune
# 12                         Monocyte surface signature              immune
# 13                                         Interferon               DC.M1
# 14                            antiviral IFN signature              immune
# 15                       cell cycle and transcription  biological process
# 16         enriched in activated dendritic cells (II)              immune
# 17  regulation of antigen presentation and immune ...              immune
# 18                                             B cell               DC.M4
# 19                                         Cell Cycle               DC.M4
# 20                                  Cytotoxic/NK Cell               DC.M3
# 21                                       Inflammation               DC.M4
# 22                                         Cell Death               DC.M6
# 23                         enriched in monocytes (IV)              immune
# 24                        enriched in neutrophils (I)              immune
# 25                            T cell activation (III)              immune
# 26                            enriched in B cells (I)              immune
# 27                         type I interferon response              immune
# 28                          activated dendritic cells              immune
# 29                             T cell differentiation              immune
# 30                             T cell activation (II)              immune
# 31            enriched in myeloid cells and monocytes              immune
# 32  viral sensing & immunity; IRF2 targets network...              immune
# 33                       T cell differentiation (Th2)              immune
# 34                          innate antiviral response              immune
# 35                          receptors, cell migration  molecular function
# 36                           enriched in T cells (II)              immune
# 37                                          Monocytes               DC.M4
# 38                                        Neutrophils               DC.M5
# 39                           T cell surface signature              immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.3333333333333333
# Number of Nodes = 1038
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value  Overlap  \
# 0    LI.M11.0  1.820896e-61      3.914927e-59   89/189
# 1    LI.M37.0  1.867487e-56      2.007548e-54  112/347
# 2     DC.M3.4  1.749103e-55      1.253524e-53    48/53
# 3    DC.M5.12  3.546270e-45      1.906120e-43    45/59
# 4     DC.M4.1  1.334772e-40      5.739518e-39    42/58
# 5    DC.M4.15  6.463769e-38      2.316184e-36    35/42
# 6     DC.M3.2  2.029383e-31      6.233104e-30   53/138
# 7     LI.M7.0  9.750812e-30      2.620531e-28    36/62
# 8     DC.M4.2  2.274829e-29      5.434315e-28    32/48
# 9     LI.M7.1  1.371500e-25      2.948725e-24    30/50
# 10    LI.M4.0  8.054232e-23      1.574236e-21   70/335
# 11     LI.M75  1.109293e-21      1.987483e-20    19/22
# 12     LI.M16  2.048720e-21      3.388267e-20    26/46
# 13    DC.M1.2  2.779127e-20      4.267946e-19    20/27
# 14    LI.M7.2  6.261137e-18      8.974296e-17    24/49
# 15      LI.S4  1.174285e-17      1.577946e-16    32/94
# 16   DC.M4.10  1.484687e-16      1.877692e-15    19/32
# 17   DC.M6.13  9.053534e-16      1.081394e-14    22/48
# 18    LI.M165  2.941040e-14      3.328019e-13    18/35
# 19    LI.M5.0  6.573215e-14      7.066207e-13    26/81
# 20    LI.M127  1.370552e-13      1.339403e-12    11/12
# 21     LI.M67  1.370552e-13      1.339403e-12    11/12
# 22    DC.M4.6  2.250747e-13      2.103959e-12   30/113
# 23    LI.M7.4  2.531603e-13      2.267894e-12    12/15
# 24  LI.M111.1  2.326707e-12      2.000968e-11    10/11
# 25    LI.M150  1.327496e-11      1.023536e-10    10/12
# 26    LI.M7.3  1.332977e-11      1.023536e-10    15/31
# 27     LI.M14  1.327496e-11      1.023536e-10    10/12
# 28    DC.M3.6  1.586530e-11      1.176221e-10    18/47
# 29  LI.M118.0  7.399947e-11      5.303295e-10    19/57
# 30     LI.M81  1.172060e-10      8.128801e-10    15/35
# 31     LI.M18  2.048003e-10      1.376002e-09     9/11
# 32    DC.M4.7  5.454288e-10      3.553551e-09   24/100
# 33   LI.M47.0  1.460231e-09      9.233813e-09    17/53
# 34    LI.M117  2.553639e-09      1.568664e-08    11/21
# 35  LI.M111.0  3.042271e-09      1.816912e-08    10/17
# 36   LI.M37.1  8.767878e-09      5.094848e-08    16/52
# 37   DC.M4.14  9.194925e-09      5.202392e-08    17/59
# 38   LI.M37.2  1.307036e-08      7.205453e-08    10/19
# 39      LI.M3  1.462227e-08      7.859469e-08    15/47
#
#                                                 Genes  \
# 0   FES;TIMP2;CYP1B1;AQP9;TLR2;TLR8;TYMP;MAFB;CSTA...
# 1   AQP9;FCGR3A;HNRNPLL;BPI;DEFA1;STX11;ANXA3;CIIT...
# 2   UBE2L6;LGALS3BP;LAP3;IRF7;CARD17;OAS2;IDO1;SAM...
# 3   TDRD7;ETV7;LHFPL2;ZNFX1;ACTA2;TRAFD1;SP100;ASP...
# 4   CCR7;LEF1;STMN3;TNFRSF25;BACH2;LRRN3;DOCK9;TBC...
# 5   PLEKHA1;PRKCH;ZNF256;LBH;SH2D1A;PLCG1;OCIAD2;C...
# 6   PHTF1;NAMPT;QPCT;OSCAR;TIMP2;SULT1B1;AQP9;GNG1...
# 7   LEF1;PRKCH;SH2D1A;GZMM;IL7R;GNLY;CD3E;CD6;ETS1...
# 8   LMNB1;PGLYRP1;LRG1;MAPK14;KREMEN1;SERPINA1;SIP...
# 9   CCR7;PRKCH;LEF1;RHOH;IL7R;CD5;CD3E;THEMIS;CD3G...
# 10  IGSF6;LMNB1;PGLYRP1;FES;MYOF;NCF1;NOD2;TIMP2;A...
# 11  C1QB;OAS3;IRF7;DDX60;SERPING1;HERC5;ANXA3;DDX5...
# 12  FCGR1A;FES;P2RY13;AQP9;TLR2;TLR8;HSPA6;TLR7;AP...
# 13  IFI44;ISG15;BATF2;TRIM6;RTP4;LAMP3;OAS3;SERPIN...
# 14  PRKCH;STAT4;FCGR3B;CLIC3;GZMM;GNLY;S1PR5;IL2RB...
# 15  CCR2;ASGR1;MARCO;P2RY13;TLR2;PYCARD;HCAR3;LTBR...
# 16  TSPAN13;COBLL1;AFF3;CD19;SPIB;VPREB3;BLNK;FCRL...
# 17  RAB20;EIF4E3;NLRC4;NCF1;FES;DRAM1;CSTA;HSPA6;S...
# 18  PRRG4;CSF2RB;DSE;LAMP3;DOCK4;SERPING1;IFIH1;HE...
# 19  CCR7;MAPK14;CARD11;TLR2;PLCG1;FYN;CD3E;THEMIS;...
# 20  PLSCR1;DDX60;IFIH1;IRF7;STAT1;HERC5;IFIT1;RSAD...
# 21  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;CD...
# 22  SELL;CSRNP1;RIT1;AKIRIN2;MLKL;ENTPD1;P2RY13;ME...
# 23  LEF1;LCK;ETS1;RASGRP1;THEMIS;KLF12;ATP8B2;PRKC...
# 24  ZBP1;TAP1;BST2;PSMB10;PSMB8;DDX58;IFIT2;CXCL10...
# 25  PLSCR1;OAS3;IRF7;SP100;OASL;EIF2AK2;OAS1;IFIT1...
# 26  PTPRCAP;LCK;SP140;CXCR3;STAT4;ITK;SIRPG;ZAP70;...
# 27  TXK;RASGRP1;CD28;ITK;SH2D1A;MAL;LRRN3;TCF7;BCL...
# 28  NCALD;GPR68;TSEN54;CD160;PLEKHF1;FGFBP2;AUTS2;...
# 29  LY96;MARC1;DYSF;HCAR3;PTGS2;STEAP4;LTBR;F5;BCL...
# 30  CLEC5A;EGF;F5;BCL6;CD14;ITGB3;CCR2;ITGA2B;PRAM...
# 31  PRKCH;ETS1;ABLIM1;ITK;SIRPG;SH2D1A;PRKCQ;BCL2;...
# 32  CCND2;TRAF5;ZNF529;MTAP;FYN;ASF1A;ZBTB9;SUPV3L...
# 33  TSPAN13;AFF3;SPIB;CD19;PLEKHG1;VPREB3;FCRLA;BA...
# 34  LEF1;CD6;CXCR3;CD300A;CD40LG;ZAP70;PRKCQ;BCL2;...
# 35  ZBP1;TAP1;CXCL16;BST2;FES;PSMB8;TLR7;TNFSF13B;...
# 36  FCGR3A;G0S2;FCGR2A;KCNJ15;HCAR3;STEAP4;LRG1;FC...
# 37  CYFIP1;CPNE8;MS4A7;VCAN;SLC46A2;CYBB;GPBAR1;AS...
# 38  MARCH1;LPCAT2;ELOVL4;UNC93B1;SGK1;MGST1;SORT1;...
# 39  TLR5;FOXO1;S100A12;GATA3;BCL6;ADAP2;NOD2;TIMP2...
#
#                                                 Title            Category
# 0                          enriched in monocytes (II)              immune
# 1                 immune activation - generic cluster              immune
# 2                                          Interferon               DC.M3
# 3                                          Interferon               DC.M5
# 4                                              T cell               DC.M4
# 5                                             T cells               DC.M4
# 6                                        Inflammation               DC.M3
# 7                             enriched in T cells (I)              immune
# 8                                        Inflammation               DC.M4
# 9                               T cell activation (I)              immune
# 10                       cell cycle and transcription  biological process
# 11                            antiviral IFN signature              immune
# 12                     TLR and inflammatory signaling              immune
# 13                                         Interferon               DC.M1
# 14                           enriched in NK cells (I)              immune
# 15                         Monocyte surface signature              immune
# 16                                             B cell               DC.M4
# 17                                         Cell Death               DC.M6
# 18         enriched in activated dendritic cells (II)              immune
# 19  regulation of antigen presentation and immune ...              immune
# 20                         type I interferon response              immune
# 21                          activated dendritic cells              immune
# 22                                       Inflammation               DC.M4
# 23                            T cell activation (III)              immune
# 24  viral sensing & immunity; IRF2 targets network...              immune
# 25                          innate antiviral response              immune
# 26                             T cell activation (II)              immune
# 27                             T cell differentiation              immune
# 28                                  Cytotoxic/NK Cell               DC.M3
# 29                         enriched in monocytes (IV)              immune
# 30            enriched in myeloid cells and monocytes              immune
# 31             T cell differentiation via ITK and PKC              immune
# 32                                         Cell Cycle               DC.M4
# 33                            enriched in B cells (I)              immune
# 34                                 cell adhesion (GO)  molecular function
# 35  viral sensing & immunity; IRF2 targets network...              immune
# 36                        enriched in neutrophils (I)              immune
# 37                                          Monocytes               DC.M4
# 38                              endoplasmic reticulum            location
# 39                  regulation of signal transduction           signaling
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.4
# Number of Nodes = 726
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  8.921283e-61      1.739650e-58   47/53
# 1    LI.M11.0  8.507388e-47      8.294703e-45  67/189
# 2    LI.M37.0  1.000834e-45      6.505420e-44  86/347
# 3     DC.M4.1  8.213285e-42      4.003976e-40   39/58
# 4    DC.M5.12  2.337465e-41      9.116114e-40   39/59
# 5    DC.M4.15  3.615761e-30      1.175122e-28   28/42
# 6     DC.M4.2  2.420059e-29      6.741592e-28   29/48
# 7     DC.M3.2  1.481892e-25      3.612113e-24  41/138
# 8      LI.M75  1.498052e-22      3.245779e-21   18/22
# 9     DC.M1.2  1.465248e-21      2.857235e-20   19/27
# 10    LI.M7.0  8.813769e-20      1.562441e-18   25/62
# 11     LI.M16  1.494818e-19      2.429079e-18   22/46
# 12    LI.M7.1  1.455699e-18      2.183548e-17   22/50
# 13    LI.M4.0  2.167532e-17      3.019062e-16  51/335
# 14    LI.M127  2.666056e-15      3.465873e-14   11/12
# 15    LI.M165  3.500087e-14      4.265731e-13   16/35
# 16   DC.M6.13  5.892126e-14      6.758615e-13   18/48
# 17      LI.S4  7.213882e-14      7.815039e-13   24/94
# 18     LI.M67  3.765111e-13      3.864193e-12   10/12
# 19    LI.M7.2  1.311400e-12      1.278615e-11   17/49
# 20  LI.M111.1  8.333536e-12      7.738284e-11    9/11
# 21     LI.M14  3.220461e-11      2.730391e-10    9/12
# 22    LI.M150  3.220461e-11      2.730391e-10    9/12
# 23  LI.M111.0  9.324292e-11      7.575987e-10   10/17
# 24    LI.M7.4  6.607151e-10      4.955363e-09    9/15
# 25    LI.M109  6.607151e-10      4.955363e-09    9/15
# 26   DC.M4.10  9.656514e-10      6.974149e-09   12/32
# 27    DC.M3.6  1.287731e-09      8.968130e-09   14/47
# 28  LI.M118.0  2.250614e-09      1.513344e-08   15/57
# 29     LI.M81  3.211867e-09      2.087713e-08   12/35
# 30    LI.M223  4.670676e-09      2.938006e-08    8/13
# 31    LI.M5.0  8.268016e-09      5.038322e-08   17/81
# 32    LI.M117  3.156565e-08      1.865243e-07    9/21
# 33     LI.M18  3.286826e-08      1.885092e-07    7/11
# 34      LI.M3  1.320404e-07      6.958886e-07   12/47
# 35    LI.M7.3  1.308608e-07      6.958886e-07   10/31
# 36    LI.M4.3  1.308608e-07      6.958886e-07   10/31
# 37    DC.M4.6  2.662631e-07      1.366350e-06  18/113
# 38      LI.S0  4.096290e-07      2.048145e-06    9/27
# 39     LI.M68  5.544329e-07      2.702860e-06    6/10
#
#                                                 Genes  \
# 0   UBE2L6;LGALS3BP;LAP3;IRF7;CARD17;OAS2;IDO1;SAM...
# 1   IGSF6;MS4A7;QPCT;MYOF;FES;NCF1;FCGR1A;NOD2;ASG...
# 2   AQP9;FCGR3A;BPI;DEFA1;STX11;ANXA3;APOBR;FCAR;F...
# 3   CCR7;LEF1;STMN3;TNFRSF25;BACH2;LRRN3;DOCK9;TBC...
# 4   TDRD7;ETV7;LHFPL2;ZNFX1;ACTA2;TRAFD1;ASPRV1;TY...
# 5   PLEKHA1;PRKCH;ZNF256;LBH;SH2D1A;OCIAD2;CD5;CD6...
# 6   LMNB1;PGLYRP1;LRG1;MAPK14;KREMEN1;SIPA1L2;CLEC...
# 7   PHTF1;QPCT;OSCAR;SULT1B1;AQP9;GNG10;TLR8;ACSL1...
# 8   C1QB;OAS3;IRF7;DDX60;SERPING1;HERC5;ANXA3;DDX5...
# 9   IFI44;ISG15;BATF2;RTP4;XAF1;LAMP3;OAS3;SERPING...
# 10  LEF1;PRKCH;SH2D1A;IL7R;CD3E;CD6;ETS1;KLRB1;CD3...
# 11  FCGR1A;FES;P2RY13;AQP9;TLR2;TLR8;HSPA6;TLR7;AP...
# 12  CCR7;PRKCH;LEF1;RHOH;IL7R;CD5;CD3E;THEMIS;CD3G...
# 13  IGSF6;LMNB1;PGLYRP1;FES;MYOF;NCF1;NOD2;ASGR1;F...
# 14  PLSCR1;DDX60;IFIH1;IRF7;STAT1;HERC5;IFIT1;RSAD...
# 15  PRRG4;DSE;LAMP3;DOCK4;SERPING1;IFIH1;HERC5;IFI...
# 16  RAB20;VPS9D1;EIF4E3;NLRC4;HK3;NCF1;FES;CSTA;HS...
# 17  CCR2;ASGR1;MARCO;P2RY13;TLR2;HCAR3;LTBR;AGTRAP...
# 18  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;CD...
# 19  PRKCH;PTGDR;STAT4;PLEKHF1;IL18RAP;FGFBP2;ITK;T...
# 20  ZBP1;TAP1;BST2;PSMB8;DDX58;IFIT2;CXCL10;TNFSF1...
# 21  TXK;RASGRP1;CD28;ITK;SH2D1A;MAL;LRRN3;BCL11B;S...
# 22  PLSCR1;OAS3;IRF7;OASL;EIF2AK2;OAS1;IFIT1;RSAD2...
# 23  ZBP1;TAP1;CXCL16;BST2;FES;PSMB8;TLR7;TNFSF13B;...
# 24  LEF1;ETS1;RASGRP1;THEMIS;KLF12;ATP8B2;RORA;CD9...
# 25   CCR7;LEF1;GATA3;CCR2;S1PR1;BCL2;LRRK2;C3AR1;CCR1
# 26  COBLL1;CD19;SPIB;VPREB3;FCRLA;BANK1;CD79B;BLK;...
# 27  NCALD;GPR68;TSEN54;CD160;PLEKHF1;FGFBP2;AUTS2;...
# 28  LY96;DYSF;HCAR3;STEAP4;LTBR;F5;BCL6;NAIP;DOK3;...
# 29  F5;BCL6;CD14;ITGB3;CCR2;ITGA2B;TLR7;PROS1;FCER...
# 30  SLC38A1;LBH;PLEKHF1;TC2N;CD40LG;FGFBP2;DENND2D...
# 31  CCR7;TLR5;LY96;CD19;THEMIS;FCGR1B;IRAK3;ITK;MA...
# 32  LEF1;CD6;CXCR3;CD300A;CD40LG;BCL2;CD96;NELL2;S...
# 33           PRKCH;ETS1;ABLIM1;ITK;SH2D1A;BCL2;SPOCK2
# 34  TLR5;FOXO1;S100A12;GATA3;BCL6;ADAP2;NOD2;IL1RN...
# 35  PTPRCAP;SP140;CXCR3;STAT4;ITK;ICOS;CD3G;CD247;...
# 36  IGSF6;TLR5;MYOF;GPBAR1;SECTM1;CD14;ASGR1;MARCO...
# 37  GRN;SELL;AKIRIN2;MLKL;RAB24;ENTPD1;SAT1;P2RY13...
# 38  PTPRCAP;CD6;SLC38A1;CD28;MAL;ICOS;LRRN3;CD3G;CD3E
# 39               ISG15;IRF7;IFIH1;DDX58;CXCL10;TRIM25
#
#                                                 Title            Category
# 0                                          Interferon               DC.M3
# 1                          enriched in monocytes (II)              immune
# 2                 immune activation - generic cluster              immune
# 3                                              T cell               DC.M4
# 4                                          Interferon               DC.M5
# 5                                             T cells               DC.M4
# 6                                        Inflammation               DC.M4
# 7                                        Inflammation               DC.M3
# 8                             antiviral IFN signature              immune
# 9                                          Interferon               DC.M1
# 10                            enriched in T cells (I)              immune
# 11                     TLR and inflammatory signaling              immune
# 12                              T cell activation (I)              immune
# 13                       cell cycle and transcription  biological process
# 14                         type I interferon response              immune
# 15         enriched in activated dendritic cells (II)              immune
# 16                                         Cell Death               DC.M6
# 17                         Monocyte surface signature              immune
# 18                          activated dendritic cells              immune
# 19                           enriched in NK cells (I)              immune
# 20  viral sensing & immunity; IRF2 targets network...              immune
# 21                             T cell differentiation              immune
# 22                          innate antiviral response              immune
# 23  viral sensing & immunity; IRF2 targets network...              immune
# 24                            T cell activation (III)              immune
# 25                          receptors, cell migration  molecular function
# 26                                             B cell               DC.M4
# 27                                  Cytotoxic/NK Cell               DC.M3
# 28                         enriched in monocytes (IV)              immune
# 29            enriched in myeloid cells and monocytes              immune
# 30                           enriched in T cells (II)              immune
# 31  regulation of antigen presentation and immune ...              immune
# 32                                 cell adhesion (GO)  molecular function
# 33             T cell differentiation via ITK and PKC              immune
# 34                  regulation of signal transduction           signaling
# 35                             T cell activation (II)              immune
# 36   myeloid cell enriched receptors and transporters              immune
# 37                                       Inflammation               DC.M4
# 38                           T cell surface signature              immune
# 39                      RIG-1 like receptor signaling              immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.4666666666666667
# Number of Nodes = 502
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  7.115513e-55      1.188291e-52   41/53
# 1    DC.M5.12  1.119517e-38      9.347964e-37   34/59
# 2    LI.M11.0  1.276332e-33      7.104914e-32  48/189
# 3    LI.M37.0  5.242041e-29      2.188552e-27  57/347
# 4    DC.M4.15  1.681557e-27      5.616400e-26   24/42
# 5     DC.M4.1  4.719658e-26      1.313638e-24   26/58
# 6      LI.M75  1.860553e-25      4.438748e-24   18/22
# 7     DC.M1.2  1.302908e-24      2.719820e-23   19/27
# 8     DC.M3.2  1.936864e-21      3.593959e-20  32/138
# 9     DC.M4.2  1.529926e-19      2.554977e-18   20/48
# 10    LI.M7.0  3.104006e-18      4.712445e-17   21/62
# 11    LI.M127  4.500670e-17      6.263433e-16   11/12
# 12    LI.M7.1  9.273213e-14      1.106162e-12   16/50
# 13    LI.M165  9.151150e-14      1.106162e-12   14/35
# 14    LI.M4.0  1.810018e-13      2.015153e-12  37/335
# 15  LI.M111.1  3.009540e-13      3.141208e-12    9/11
# 16    LI.M150  1.175762e-12      1.090846e-11    9/12
# 17     LI.M67  1.175762e-12      1.090846e-11    9/12
# 18     LI.M16  7.251589e-12      6.373765e-11   14/46
# 19   DC.M6.13  1.389248e-11      1.160022e-10   14/48
# 20      LI.S4  3.960994e-11      3.149933e-10   18/94
# 21     LI.M14  9.965010e-11      7.564349e-10    8/12
# 22  LI.M111.0  1.154805e-10      8.384887e-10    9/17
# 23    LI.M5.0  2.765137e-09      1.924074e-08   15/81
# 24    LI.M4.3  4.002605e-09      2.673740e-08   10/31
# 25     LI.M81  1.506911e-08      9.679006e-08   10/35
# 26    LI.M7.4  4.549855e-08      2.620089e-07    7/15
# 27    LI.M109  4.549855e-08      2.620089e-07    7/15
# 28    LI.M7.2  4.517064e-08      2.620089e-07   11/49
# 29     LI.M68  6.257588e-08      3.483391e-07    6/10
# 30     LI.M18  1.345975e-07      7.024307e-07    6/11
# 31     LI.M13  1.345975e-07      7.024307e-07    6/11
# 32  LI.M118.0  2.364564e-07      1.196613e-06   11/57
# 33      LI.S0  3.152220e-07      1.548296e-06    8/27
# 34   DC.M4.10  1.329810e-06      6.345094e-06    8/32
# 35   LI.M61.0  1.990894e-06      9.235538e-06    7/24
# 36  LI.M112.0  3.150008e-06      1.406480e-05    6/17
# 37      LI.M3  3.200374e-06      1.406480e-05    9/47
# 38   LI.M37.1  7.687261e-06      3.291724e-05    9/52
# 39     LI.M56  8.483867e-06      3.542014e-05    5/12
#
#                                                 Genes  \
# 0   UBE2L6;LAP3;IRF7;CARD17;OAS2;IDO1;SAMD9L;PML;P...
# 1   TDRD7;ETV7;LHFPL2;ZNFX1;ACTA2;TRAFD1;ASPRV1;TY...
# 2   IGSF6;MS4A7;MYOF;FCGR1A;NOD2;ASGR1;AQP9;TYMP;T...
# 3   PRRG4;MS4A7;OSCAR;NLRC4;ENTPD1;LRG1;SH2D1A;AQP...
# 4   PLEKHA1;PRKCH;ZNF256;SH2D1A;OCIAD2;CD5;CD6;THE...
# 5   CCR7;LEF1;STMN3;TNFRSF25;LRRN3;TBC1D4;IL7R;SPO...
# 6   C1QB;OAS3;IRF7;DDX60;SERPING1;HERC5;ANXA3;DDX5...
# 7   IFI44;ISG15;BATF2;RTP4;XAF1;LAMP3;OAS3;SERPING...
# 8   PHTF1;OSCAR;SULT1B1;AQP9;TLR8;ACSL1;SLC2A3;ZNF...
# 9   TLR5;LMNB1;LIMK2;SOCS3;CYSTM1;CR1;S100A12;SLC2...
# 10  LEF1;PRKCH;SH2D1A;IL7R;CD3E;CD6;ETS1;KLRB1;CD3...
# 11  PLSCR1;DDX60;IFIH1;IRF7;STAT1;HERC5;IFIT1;RSAD...
# 12  CCR7;CD27;PRKCH;LEF1;TXK;CD7;ITPR3;THEMIS;RASG...
# 13  PRRG4;LAMP3;SERPING1;IFIH1;HERC5;IFIT2;IFIT1;T...
# 14  IGSF6;LMNB1;MYOF;FCGR1A;NOD2;ASGR1;TYMP;TLR2;T...
# 15  ZBP1;TAP1;BST2;PSMB8;DDX58;IFIT2;CXCL10;TNFSF1...
# 16  PLSCR1;OAS3;IRF7;OASL;EIF2AK2;OAS1;IFIT1;RSAD2...
# 17  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;RS...
# 18  LY96;BST1;TLR5;KCNJ15;DYSF;HSPA6;FCGR1A;FCGR1B...
# 19  RAB20;VPS9D1;EIF4E3;NLRC4;HK3;CSTA;HSPA6;STK3;...
# 20  TLR5;DYSF;HCAR3;STEAP4;LTBR;FCGR1B;AGTRAP;FCER...
# 21       TXK;RASGRP1;CD28;ITK;SH2D1A;MAL;LRRN3;SPOCK2
# 22  ZBP1;TAP1;CXCL16;BST2;PSMB8;TLR7;TNFSF13B;KYNU...
# 23  CCR7;TLR5;LY96;CD19;THEMIS;FCGR1B;ITK;MAPK14;T...
# 24  IGSF6;TLR5;MYOF;GPBAR1;SECTM1;CD14;ASGR1;MARCO...
# 25  CD14;ITGB3;ITGA2B;CCR2;TLR7;PROS1;FCER1G;SELP;...
# 26          LEF1;ETS1;RASGRP1;THEMIS;KLF12;CD96;NELL2
# 27              CCR7;LEF1;CCR2;S1PR1;LRRK2;C3AR1;CCR1
# 28  PRKCH;PTGDR;ITK;KLRF1;CLIC3;KLRB1;GIMAP7;CD96;...
# 29               ISG15;IRF7;IFIH1;DDX58;CXCL10;TRIM25
# 30                PRKCH;ETS1;ABLIM1;ITK;SH2D1A;SPOCK2
# 31                   ZBP1;IRF7;DDX58;AIM2;CXCL10;IL1B
# 32  LY96;DYSF;HCAR3;STEAP4;LTBR;NAIP;SMARCD3;VNN1;...
# 33       PTPRCAP;CD6;SLC38A1;CD28;MAL;LRRN3;CD3G;CD3E
# 34     COBLL1;CD19;SPIB;FCRLA;BANK1;BLK;OSBPL10;CXCR5
# 35             PVRIG;CD7;KLRF1;KLRB1;CD96;CD247;IL2RB
# 36                    CR1;C1QB;SERPING1;C1QC;C3AR1;C2
# 37  TLR5;S100A12;ADAP2;NOD2;IL1RN;TLR2;CCR1;HPSE;CD3E
# 38  KCNJ15;HCAR3;STEAP4;LRG1;SLC22A4;CREB5;FFAR2;M...
# 39                     HSPA6;CD14;DUSP3;CACNA2D3;IL1B
#
#                                                 Title            Category
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                          enriched in monocytes (II)              immune
# 3                 immune activation - generic cluster              immune
# 4                                             T cells               DC.M4
# 5                                              T cell               DC.M4
# 6                             antiviral IFN signature              immune
# 7                                          Interferon               DC.M1
# 8                                        Inflammation               DC.M3
# 9                                        Inflammation               DC.M4
# 10                            enriched in T cells (I)              immune
# 11                         type I interferon response              immune
# 12                              T cell activation (I)              immune
# 13         enriched in activated dendritic cells (II)              immune
# 14                       cell cycle and transcription  biological process
# 15  viral sensing & immunity; IRF2 targets network...              immune
# 16                          innate antiviral response              immune
# 17                          activated dendritic cells              immune
# 18                     TLR and inflammatory signaling              immune
# 19                                         Cell Death               DC.M6
# 20                         Monocyte surface signature              immune
# 21                             T cell differentiation              immune
# 22  viral sensing & immunity; IRF2 targets network...              immune
# 23  regulation of antigen presentation and immune ...              immune
# 24   myeloid cell enriched receptors and transporters              immune
# 25            enriched in myeloid cells and monocytes              immune
# 26                            T cell activation (III)              immune
# 27                          receptors, cell migration  molecular function
# 28                           enriched in NK cells (I)              immune
# 29                      RIG-1 like receptor signaling              immune
# 30             T cell differentiation via ITK and PKC              immune
# 31         innate activation by cytosolic DNA sensing              immune
# 32                         enriched in monocytes (IV)              immune
# 33                           T cell surface signature              immune
# 34                                             B cell               DC.M4
# 35                          enriched in NK cells (II)              immune
# 36                          complement activation (I)              immune
# 37                  regulation of signal transduction           signaling
# 38                        enriched in neutrophils (I)              immune
# 39                      suppression of MAPK signaling           signaling
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.5333333333333333
# Number of Nodes = 342
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  4.075691e-53      6.154294e-51   37/53
# 1    DC.M5.12  7.556971e-32      5.705513e-30   27/59
# 2      LI.M75  5.595363e-24      2.366028e-22   16/22
# 3     DC.M4.1  6.267623e-24      2.366028e-22   22/58
# 4    DC.M4.15  1.266917e-22      3.826089e-21   19/42
# 5     DC.M1.2  9.014004e-22      2.268524e-20   16/27
# 6    LI.M37.0  3.410349e-19      7.356610e-18  38/347
# 7    LI.M11.0  6.668830e-19      1.258742e-17  29/189
# 8     LI.M127  1.960507e-16      3.289295e-15   10/12
# 9   LI.M111.1  9.339562e-15      1.410274e-13    9/11
# 10    LI.M7.0  1.069893e-14      1.468671e-13   16/62
# 11    DC.M4.2  7.755402e-14      9.758881e-13   14/48
# 12     LI.M67  4.643129e-12      5.007946e-11    8/12
# 13    LI.M150  4.643129e-12      5.007946e-11    8/12
# 14    DC.M3.2  6.067190e-12      6.107638e-11  19/138
# 15    LI.M165  1.518313e-11      1.432908e-10   11/35
# 16    LI.M7.1  6.122445e-11      5.438172e-10   12/50
# 17  LI.M111.0  2.108060e-10      1.768428e-09    8/17
# 18   DC.M6.13  6.675012e-10      5.304878e-09   11/48
# 19    LI.M4.0  2.129574e-09      1.607829e-08  25/335
# 20     LI.M68  6.352654e-09      4.567861e-08    6/10
# 21     LI.M16  7.037802e-09      4.830492e-08   10/46
# 22      LI.S4  1.313079e-08      8.620647e-08   13/94
# 23     LI.M13  1.376462e-08      8.660239e-08    6/11
# 24    LI.M5.0  2.165927e-08      1.308220e-07   12/81
# 25     LI.M14  2.711329e-08      1.574657e-07    6/12
# 26    LI.M117  1.388672e-06      7.766277e-06    6/21
# 27    LI.M7.2  2.369294e-06      1.277726e-05    8/49
# 28   LI.M61.0  3.291145e-06      1.713665e-05    6/24
# 29    LI.M109  4.701927e-06      2.290294e-05    5/15
# 30    LI.M7.4  4.701927e-06      2.290294e-05    5/15
# 31  LI.M118.0  7.662303e-06      3.615649e-05    8/57
# 32    LI.M4.3  1.619159e-05      7.408879e-05    6/31
# 33      LI.M3  1.923526e-05      8.542717e-05    7/47
# 34     LI.M18  3.054458e-05      1.317780e-04    4/11
# 35   LI.M37.1  3.788966e-05      1.589261e-04    7/52
# 36     LI.M56  4.516865e-05      1.843369e-04    4/12
# 37      LI.S0  1.058703e-04      4.206953e-04    5/27
# 38    DC.M3.6  1.854480e-04      7.180166e-04    6/47
# 39     LI.M64  2.022653e-04      7.300682e-04    4/17
#
#                                                 Genes  \
# 0   UBE2L6;LAP3;IRF7;CARD17;SAMD9L;PML;PARP14;TIMM...
# 1   ETV7;LHFPL2;ACTA2;TRAFD1;ASPRV1;TYMP;RBCK1;CAS...
# 2   C1QB;OAS3;IRF7;DDX60;SERPING1;HERC5;ANXA3;DDX5...
# 3   CCR7;LEF1;STMN3;TNFRSF25;LRRN3;IL7R;SPOCK2;GPR...
# 4   CD27;PRKCH;CD6;ZNF256;CD7;GPR18;TC2N;GZMK;KLF1...
# 5   IFI44;ISG15;BATF2;RTP4;XAF1;LAMP3;OAS3;SERPING...
# 6   PRRG4;OSCAR;NLRC4;LRG1;BANK1;ELANE;CLEC4D;CAMP...
# 7   MYOF;FCGR1A;NOD2;ASGR1;TYMP;TLR2;KYNU;HPSE;MAF...
# 8   PLSCR1;DDX60;IFIH1;IRF7;STAT1;HERC5;RSAD2;PARP...
# 9   ZBP1;TAP1;BST2;PSMB8;DDX58;IFIT2;CXCL10;TNFSF1...
# 10  CD27;LEF1;CD6;PRKCH;CD7;ETS1;GZMK;MAL;CD28;ITK...
# 11  TLR5;LMNB1;LIMK2;S100A12;SLC2A14;LRG1;MAPK14;O...
# 12  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;RSAD2
# 13      PLSCR1;OAS3;IRF7;OASL;EIF2AK2;OAS1;RSAD2;TAP1
# 14  PHTF1;PFKFB3;BST1;ZNF438;KCNJ15;B4GALT5;DYSF;O...
# 15  PRRG4;LAMP3;SERPING1;IFIH1;HERC5;IFIT2;TNFAIP6...
# 16  CCR7;CD27;PRKCH;LEF1;TXK;CD7;CD28;ITK;CD3G;CD2...
# 17      ZBP1;TAP1;BST2;PSMB8;TLR7;TNFSF13B;KYNU;IFI35
# 18  RAB20;VPS9D1;EIF4E3;NLRC4;HK3;STK3;STX11;MCTP1...
# 19  LMNB1;MYOF;FCGR1A;NOD2;ASGR1;TYMP;TLR2;KYNU;HP...
# 20               ISG15;IRF7;IFIH1;DDX58;CXCL10;TRIM25
# 21  LY96;BST1;TLR5;KCNJ15;DYSF;FCGR1A;FCGR1B;TLR7;...
# 22  TLR5;DYSF;HCAR3;LTBR;FCGR1B;AGTRAP;FCER1A;CCR2...
# 23                   ZBP1;IRF7;DDX58;AIM2;CXCL10;IL1B
# 24  CCR7;TLR5;LY96;CD19;FCGR1B;ITK;MAPK14;TLR7;CD3...
# 25                      TXK;MAL;CD28;ITK;LRRN3;SPOCK2
# 26                   LEF1;CD6;CXCR3;CD96;NELL2;SPOCK2
# 27       PRKCH;ITK;KLRF1;CLIC3;KLRB1;CD96;ARL4C;CD247
# 28                   PVRIG;CD7;KLRF1;KLRB1;CD96;CD247
# 29                         CCR7;LEF1;CCR2;S1PR1;LRRK2
# 30                         LEF1;ETS1;KLF12;CD96;NELL2
# 31   LY96;DYSF;HCAR3;LTBR;NAIP;SMARCD3;LRRK2;TNFSF13B
# 32                  TLR5;GPBAR1;MYOF;CD14;ASGR1;MARCO
# 33            TLR5;S100A12;ADAP2;NOD2;IL1RN;TLR2;HPSE
# 34                              SPOCK2;PRKCH;ITK;ETS1
# 35        KCNJ15;HCAR3;LRG1;SLC22A4;CREB5;FFAR2;MSRB1
# 36                           CACNA2D3;CD14;IL1B;DUSP3
# 37                            CD6;CD28;MAL;LRRN3;CD3G
# 38               TSEN54;ABCB1;KLRF1;CLIC3;PRSS23;NCR3
# 39                              SOD2;IL1B;IL1RN;DRAM1
#
#                                                 Title            Category
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                             antiviral IFN signature              immune
# 3                                              T cell               DC.M4
# 4                                             T cells               DC.M4
# 5                                          Interferon               DC.M1
# 6                 immune activation - generic cluster              immune
# 7                          enriched in monocytes (II)              immune
# 8                          type I interferon response              immune
# 9   viral sensing & immunity; IRF2 targets network...              immune
# 10                            enriched in T cells (I)              immune
# 11                                       Inflammation               DC.M4
# 12                          activated dendritic cells              immune
# 13                          innate antiviral response              immune
# 14                                       Inflammation               DC.M3
# 15         enriched in activated dendritic cells (II)              immune
# 16                              T cell activation (I)              immune
# 17  viral sensing & immunity; IRF2 targets network...              immune
# 18                                         Cell Death               DC.M6
# 19                       cell cycle and transcription  biological process
# 20                      RIG-1 like receptor signaling              immune
# 21                     TLR and inflammatory signaling              immune
# 22                         Monocyte surface signature              immune
# 23         innate activation by cytosolic DNA sensing              immune
# 24  regulation of antigen presentation and immune ...              immune
# 25                             T cell differentiation              immune
# 26                                 cell adhesion (GO)  molecular function
# 27                           enriched in NK cells (I)              immune
# 28                          enriched in NK cells (II)              immune
# 29                          receptors, cell migration  molecular function
# 30                            T cell activation (III)              immune
# 31                         enriched in monocytes (IV)              immune
# 32   myeloid cell enriched receptors and transporters              immune
# 33                  regulation of signal transduction           signaling
# 34             T cell differentiation via ITK and PKC              immune
# 35                        enriched in neutrophils (I)              immune
# 36                      suppression of MAPK signaling           signaling
# 37                           T cell surface signature              immune
# 38                                  Cytotoxic/NK Cell               DC.M3
# 39    enriched in activated dendritic cells/monocytes              immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6
# Number of Nodes = 227
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  4.881980e-51      6.053655e-49   33/53
# 1    DC.M5.12  2.669516e-24      1.655100e-22   20/59
# 2      LI.M75  3.582759e-18      1.480874e-16   12/22
# 3     DC.M4.1  5.018192e-18      1.555640e-16   16/58
# 4     LI.M127  8.851514e-16      2.195176e-14    9/12
# 5     DC.M1.2  5.978736e-15      1.235606e-13   11/27
# 6    LI.M37.0  1.110735e-14      1.721639e-13  27/347
# 7    LI.M11.0  1.070957e-14      1.721639e-13  21/189
# 8    DC.M4.15  4.968145e-14      6.845000e-13   12/42
# 9   LI.M111.1  5.770973e-14      7.156007e-13    8/11
# 10     LI.M67  1.713589e-13      1.931682e-12    8/12
# 11    LI.M7.0  7.870285e-12      7.368667e-11   12/62
# 12  LI.M111.0  7.994175e-12      7.368667e-11    8/17
# 13    DC.M4.2  8.319463e-12      7.368667e-11   11/48
# 14    DC.M3.2  1.119977e-09      9.258479e-09  14/138
# 15    LI.M150  2.339094e-09      1.812798e-08    6/12
# 16     LI.M16  3.117680e-09      2.274073e-08    9/46
# 17    LI.M165  6.433853e-09      4.432210e-08    8/35
# 18   DC.M6.13  9.028351e-08      5.892187e-07    8/48
# 19     LI.M13  1.004288e-07      6.226586e-07    5/11
# 20    LI.M7.1  1.258472e-07      7.430975e-07    8/50
# 21    LI.M5.0  5.143277e-07      2.898938e-06    9/81
# 22    LI.M4.0  6.014413e-07      3.242553e-06  17/335
# 23    LI.M7.4  6.278224e-07      3.243749e-06    5/15
# 24    LI.M117  4.012852e-06      1.990375e-05    5/21
# 25  LI.M118.0  4.970853e-06      2.370714e-05    7/57
# 26      LI.S4  1.664185e-05      7.642924e-05    8/94
# 27    LI.M109  2.422007e-05      1.072603e-04    4/15
# 28   LI.M61.0  1.733042e-04      7.410247e-04    4/24
# 29     LI.M44  1.886237e-04      7.544948e-04    3/10
# 30     LI.M68  1.886237e-04      7.544948e-04    3/10
# 31     LI.M18  2.570778e-04      9.961764e-04    3/11
#
#                                                 Genes  \
# 0   UBE2L6;LAP3;IRF7;CARD17;SAMD9L;PML;PARP14;TIMM...
# 1   TAP1;ETV7;LHFPL2;BST2;CHMP5;GBP2;ACTA2;SRBD1;T...
# 2   C1QB;SERPING1;DDX60;IRF7;FCER1A;IFIH1;ANXA3;DD...
# 3   CCR7;ID3;LEF1;STMN3;TMEM204;CD28;FAM102A;EPHX2...
# 4   PLSCR1;DDX60;IFIH1;IRF7;STAT1;RSAD2;PARP9;TAP1...
# 5   IFI44;BATF2;RTP4;XAF1;SERPING1;OASL;OAS1;RSAD2...
# 6   PRRG4;OSCAR;NLRC4;BANK1;CLEC4D;HCAR3;STX11;ANX...
# 7   MYOF;FCGR1A;NOD2;TYMP;KYNU;HPSE;SORT1;PLAUR;TL...
# 8   CD27;CD6;TC2N;GZMK;KLF12;ITK;S1PR1;SKAP1;CD96;...
# 9     ZBP1;TAP1;BST2;PSMB8;DDX58;IFIT2;TNFSF13B;CASP1
# 10  PLSCR1;SERPING1;IRF7;IFIH1;C1QC;DDX60;DDX58;RSAD2
# 11  CD27;LEF1;CD6;ETS1;GZMK;CD28;ITK;KLRB1;CD96;CD...
# 12      ZBP1;TAP1;BST2;PSMB8;TLR7;TNFSF13B;KYNU;IFI35
# 13  TLR5;LMNB1;LIMK2;MAPK14;OSM;ANXA3;KREMEN1;SIPA...
# 14  PHTF1;PFKFB3;BST1;ZNF438;KCNJ15;B4GALT5;DYSF;O...
# 15                   PLSCR1;IRF7;OASL;OAS1;RSAD2;TAP1
# 16  LY96;BST1;TLR5;KCNJ15;DYSF;FCGR1A;FCGR1B;TLR7;...
# 17  PRRG4;SERPING1;IFIH1;IFIT2;TNFAIP6;RSAD2;PARP9...
# 18      VPS9D1;NLRC4;HK3;STK3;STX11;MCTP1;PLAUR;DRAM1
# 19                          ZBP1;IRF7;DDX58;AIM2;IL1B
# 20             CCR7;CD27;LEF1;CD28;ITK;CD247;IL7R;CD5
# 21   CCR7;TLR5;LY96;CD19;FCGR1B;ITK;MAPK14;TLR7;CD247
# 22  LMNB1;DMXL2;LMO2;CYBB;MYOF;FCGR1A;FCGR1B;NOD2;...
# 23                         LEF1;ETS1;KLF12;CD96;NELL2
# 24                         LEF1;CD6;CD96;NELL2;SPOCK2
# 25        LY96;DYSF;HCAR3;LTBR;SMARCD3;LRRK2;TNFSF13B
# 26     TLR5;DYSF;HCAR3;LTBR;FCGR1B;FCER1A;MARCO;MCTP1
# 27                              CCR7;LEF1;LRRK2;S1PR1
# 28                             KLRB1;PVRIG;CD96;CD247
# 29                                  IFI30;MAPK14;IL7R
# 30                                   DDX58;IRF7;IFIH1
# 31                                    SPOCK2;ITK;ETS1
#
#                                                 Title            Category
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                             antiviral IFN signature              immune
# 3                                              T cell               DC.M4
# 4                          type I interferon response              immune
# 5                                          Interferon               DC.M1
# 6                 immune activation - generic cluster              immune
# 7                          enriched in monocytes (II)              immune
# 8                                             T cells               DC.M4
# 9   viral sensing & immunity; IRF2 targets network...              immune
# 10                          activated dendritic cells              immune
# 11                            enriched in T cells (I)              immune
# 12  viral sensing & immunity; IRF2 targets network...              immune
# 13                                       Inflammation               DC.M4
# 14                                       Inflammation               DC.M3
# 15                          innate antiviral response              immune
# 16                     TLR and inflammatory signaling              immune
# 17         enriched in activated dendritic cells (II)              immune
# 18                                         Cell Death               DC.M6
# 19         innate activation by cytosolic DNA sensing              immune
# 20                              T cell activation (I)              immune
# 21  regulation of antigen presentation and immune ...              immune
# 22                       cell cycle and transcription  biological process
# 23                            T cell activation (III)              immune
# 24                                 cell adhesion (GO)  molecular function
# 25                         enriched in monocytes (IV)              immune
# 26                         Monocyte surface signature              immune
# 27                          receptors, cell migration  molecular function
# 28                          enriched in NK cells (II)              immune
# 29                 T cell signaling and costimulation              immune
# 30                      RIG-1 like receptor signaling              immune
# 31             T cell differentiation via ITK and PKC              immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6666666666666666
# Number of Nodes = 141
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  4.435005e-40      4.435005e-38   25/53
# 1    DC.M5.12  3.466803e-16      1.733401e-14   13/59
# 2     LI.M127  8.068521e-13      2.689507e-11    7/12
# 3      LI.M75  2.167810e-12      5.419524e-11    8/22
# 4    LI.M37.0  1.151906e-11      2.303812e-10  19/347
# 5     DC.M4.1  1.384044e-11      2.306741e-10   10/58
# 6      LI.M16  4.517370e-11      6.453386e-10    9/46
# 7      LI.M67  1.319746e-10      1.634988e-09    6/12
# 8     LI.M165  1.471489e-10      1.634988e-09    8/35
# 9    DC.M4.15  7.064758e-10      7.064758e-09    8/42
# 10    DC.M1.2  8.246482e-10      7.496802e-09    7/27
# 11  LI.M111.1  9.243314e-09      7.702762e-08    5/11
# 12   LI.M11.0  1.651042e-07      1.270032e-06  11/189
# 13  LI.M118.0  2.040438e-07      1.457456e-06    7/57
# 14    LI.M7.0  3.680367e-07      2.453578e-06    7/62
# 15    DC.M3.2  8.840539e-07      5.525337e-06   9/138
# 16   DC.M6.13  1.407900e-06      7.821666e-06    6/48
# 17    DC.M4.2  1.407900e-06      7.821666e-06    6/48
# 18  LI.M111.0  6.362630e-06      3.348753e-05    4/17
# 19    LI.M5.0  3.047852e-05      1.523926e-04    6/81
# 20     LI.M18  6.279524e-05      2.854329e-04    3/11
# 21     LI.M13  6.279524e-05      2.854329e-04    3/11
# 22    LI.M150  8.327298e-05      3.620565e-04    3/12
# 23     LI.M65  1.362895e-04      5.451581e-04    3/14
# 24   LI.M86.1  1.362895e-04      5.451581e-04    3/14
# 25    LI.M7.4  1.694391e-04      6.275521e-04    3/15
# 26    LI.M109  1.694391e-04      6.275521e-04    3/15
# 27    LI.M4.0  2.003700e-04      7.156070e-04  10/335
#
#                                                 Genes  \
# 0   UBE2L6;LAP3;SAMD9L;PARP14;TIMM10;PLSCR1;TNFSF1...
# 1   TAP1;LHFPL2;CHMP5;GBP2;ACTA2;SRBD1;TRAFD1;TAP2...
# 2           PLSCR1;DDX60;IFIH1;STAT1;RSAD2;PARP9;TAP1
# 3    C1QB;SERPING1;DDX60;IFIH1;ANXA3;DDX58;RSAD2;IL1B
# 4   TLR5;BST1;DYSF;KCNJ15;OSCAR;PRRG4;HP;NLRC4;HCA...
# 5   CCR7;ID3;TMEM204;DHRS3;IL7R;NELL2;EPHA4;SPOCK2...
# 6   LY96;BST1;TLR5;KCNJ15;DYSF;FCGR1A;FCGR1B;TLR7;...
# 7             PLSCR1;SERPING1;DDX60;IFIH1;DDX58;RSAD2
# 8   PRRG4;SERPING1;IFIH1;IFIT2;TNFAIP6;RSAD2;PARP9...
# 9           CD6;GZMK;KLF12;ITK;S1PR1;SKAP1;OCIAD2;CD5
# 10        BATF2;RTP4;SERPING1;RSAD2;XAF1;IFITM3;IFIT3
# 11                    TAP1;IFIT2;DDX58;TNFSF13B;CASP1
# 12  TLR5;BST1;MYOF;FCGR1A;FCGR1B;NOD2;SORT1;TYMP;P...
# 13        LY96;DYSF;HCAR3;LTBR;SMARCD3;LRRK2;TNFSF13B
# 14                 CD6;ETS1;GZMK;ITK;KLRB1;IL7R;NELL2
# 15  PHTF1;LY96;BST1;ZNF438;KCNJ15;OSCAR;DYSF;SLC22...
# 16                VPS9D1;NLRC4;STK3;STX11;PLAUR;DRAM1
# 17               TLR5;LMNB1;LIMK2;ANXA3;SIPA1L2;CASP5
# 18                           TNFSF13B;TAP1;TLR7;IFI35
# 19                     CCR7;TLR5;LY96;FCGR1B;ITK;TLR7
# 20                                    SPOCK2;ITK;ETS1
# 21                                    DDX58;AIM2;IL1B
# 22                                  TAP1;PLSCR1;RSAD2
# 23                                      CCR7;ITK;IL7R
# 24                                  IL1B;TNFAIP6;GCH1
# 25                                   NELL2;KLF12;ETS1
# 26                                   CCR7;LRRK2;S1PR1
# 27  LMNB1;MYOF;FCGR1A;FCGR1B;NOD2;SORT1;TYMP;PLAUR...
#
#                                                 Title            Category
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                          type I interferon response              immune
# 3                             antiviral IFN signature              immune
# 4                 immune activation - generic cluster              immune
# 5                                              T cell               DC.M4
# 6                      TLR and inflammatory signaling              immune
# 7                           activated dendritic cells              immune
# 8          enriched in activated dendritic cells (II)              immune
# 9                                             T cells               DC.M4
# 10                                         Interferon               DC.M1
# 11  viral sensing & immunity; IRF2 targets network...              immune
# 12                         enriched in monocytes (II)              immune
# 13                         enriched in monocytes (IV)              immune
# 14                            enriched in T cells (I)              immune
# 15                                       Inflammation               DC.M3
# 16                                         Cell Death               DC.M6
# 17                                       Inflammation               DC.M4
# 18  viral sensing & immunity; IRF2 targets network...              immune
# 19  regulation of antigen presentation and immune ...              immune
# 20             T cell differentiation via ITK and PKC              immune
# 21         innate activation by cytosolic DNA sensing              immune
# 22                          innate antiviral response              immune
# 23                              IL2, IL7, TCR network              immune
# 24  proinflammatory dendritic cell, myeloid cell r...              immune
# 25                            T cell activation (III)              immune
# 26                          receptors, cell migration  molecular function
# 27                       cell cycle and transcription  biological process
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.7333333333333333
# Number of Nodes = 81
# ---------------------------------------------
# gene enrichment for nodes in this network:
#          ID       P-value  Adjusted P-value Overlap  \
# 0   DC.M3.4  2.331869e-28      1.935451e-26   17/53
# 1   DC.M1.2  1.352900e-09      5.614534e-08    6/27
# 2    LI.M16  4.014745e-08      1.110746e-06    6/46
# 3   DC.M4.1  1.665893e-07      3.456728e-06    6/58
# 4  DC.M5.12  5.140949e-06      8.533976e-05    5/59
# 5   LI.M165  1.439131e-05      1.950034e-04    4/35
# 6  LI.M37.0  1.644607e-05      1.950034e-04   9/347
# 7  DC.M6.13  5.128189e-05      5.320496e-04    4/48
# 8   LI.M117  9.333157e-05      8.607245e-04    3/21
# 9    LI.M75  1.077371e-04      8.942175e-04    3/22
#
#                                                Genes  \
# 0  UBE2L6;WARS;GBP5;FBXO6;LAP3;CEACAM1;APOL6;TNFS...
# 1              BATF2;RTP4;SERPING1;XAF1;IFITM3;IFIT3
# 2                 TLR5;BST1;KCNJ15;FCGR1B;TLR7;KCNJ2
# 3                 CCR7;DHRS3;IL7R;NELL2;EPHA4;SPOCK2
# 4                       LHFPL2;GBP2;SRBD1;ACTA2;TYMP
# 5                         IFIT2;PARP9;SERPING1;IFIT3
# 6  TLR5;BST1;KCNJ15;HCAR3;SMCO4;STX11;TLR7;LRRK2;...
# 7                            STK3;VPS9D1;STX11;DRAM1
# 8                                   SPOCK2;CD6;NELL2
# 9                                 C1QB;SERPING1;IL1B
#
#                                         Title            Category
# 0                                  Interferon               DC.M3
# 1                                  Interferon               DC.M1
# 2              TLR and inflammatory signaling              immune
# 3                                      T cell               DC.M4
# 4                                  Interferon               DC.M5
# 5  enriched in activated dendritic cells (II)              immune
# 6         immune activation - generic cluster              immune
# 7                                  Cell Death               DC.M6
# 8                          cell adhesion (GO)  molecular function
# 9                     antiviral IFN signature              immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.8
# Number of Nodes = 38
# ---------------------------------------------
# gene enrichment for nodes in this network:
#         ID       P-value  Adjusted P-value Overlap  \
# 0  DC.M3.4  7.514747e-16      4.959733e-14    9/53
# 1   LI.M16  3.110499e-08      1.026465e-06    5/46
# 2  DC.M1.2  2.075103e-05      3.423921e-04    3/27
# 3  LI.M5.0  2.009256e-05      3.423921e-04    4/81
#
#                                                Genes  \
# 0  GBP5;FBXO6;LAP3;TNFSF10;GBP4;STAT1;AIM2;SAMD9L...
# 1                      TLR5;KCNJ15;FCGR1B;TLR7;KCNJ2
# 2                               SERPING1;XAF1;IFITM3
# 3                              CCR7;TLR5;FCGR1B;TLR7
#
#                                                Title Category
# 0                                         Interferon    DC.M3
# 1                     TLR and inflammatory signaling   immune
# 2                                         Interferon    DC.M1
# 3  regulation of antigen presentation and immune ...   immune
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.8666666666666667
# Number of Nodes = 9
# ---------------------------------------------
# gene enrichment for nodes in this network:
#         ID   P-value  Adjusted P-value Overlap             Genes       Title  \
# 0  DC.M3.4  0.000002          0.000022    3/53  GBP5;AIM2;SAMD9L  Interferon
#
#   Category
# 0    DC.M3
# ---------------------------------------------
