# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #### choose correct comparison groups

# %%
comparison_X = 'ATB_v_HC'

# %% [markdown]
# import packages

# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import MaxNLocator
from matplotlib.gridspec import GridSpec
import matplotlib.pylab as pl
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches

import fastcluster
from scipy.cluster.hierarchy import dendrogram
import scipy.cluster.hierarchy as hier

import networkx as nx
import networkx.algorithms.community as nxcom
import community
from collections import Counter
import pickle
from collections import defaultdict

import gseapy as gp
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### set parameters for plotting

# %%
plt.style.use('ggplot')
plt.rcParams['lines.linewidth']=1.0
plt.rcParams['axes.facecolor']='1.0'
plt.rcParams['xtick.color']='black'
plt.rcParams['axes.grid']=False
plt.rcParams['axes.edgecolor']='black'
plt.rcParams['grid.color']= '1.0'
plt.rcParams.update({'font.size': 14})

# %% [markdown]
# #### specify directory paths

# %%
# use these paths for O2 computing cluster

#specify directory for Data
Data_files_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/'

#specify directory for pickling objects
pickled_objects_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/Pickled Files/'

#specify directory for CSV files
CSV_files_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/CSV Files/'

#specify directory for Gene Set Files
Gene_Set_dir = '/n/data1/hms/dbmi/farhat/Roger/gatesMRI/Projects/Biomarkers/Data/Gene Set Files/CSV files/'

# %% [markdown]
# # [1] Load Data

# %% [markdown]
# ### Network

# %%
G = nx.read_gpickle(pickled_objects_dir + f'Network Files/networks/{comparison_X}.pkl')

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 3005
# Number of edges: 672127
# Average degree: 447.3391

# %%
num_nodes_overall_network = int(len(G.nodes()))

# %% [markdown]
# ### Weighted Degrees for Nodes (genes)

# %%
weighted_deg_series = pd.read_pickle(pickled_objects_dir + f'Network Files/weighted degree series/{comparison_X}.pkl')

# %%
np.shape(weighted_deg_series)
# Out:
# (3005,)

# %% [markdown]
# ### Mean $log_2(Fold Change)$ for Nodes (genes)

# %%
mean_logFC_series = pd.read_pickle(pickled_objects_dir + f'Network Files/mean logFC network nodes series/{comparison_X}.pkl')

# %%
np.shape(mean_logFC_series)
# Out:
# (3005,)

# %% [markdown]
# ### Compile into DataFrame

# %%
G_deg_logFC_df = pd.DataFrame(index = mean_logFC_series.index)
G_deg_logFC_df['mean_log2FC'] = mean_logFC_series.values
G_deg_logFC_df['weighted_degree'] = weighted_deg_series[mean_logFC_series.index].values

# %%
G_deg_logFC_df.head()
# Out:
#           mean_log2FC  weighted_degree
# SERPING1     2.805312       572.733333
# ANKRD22      2.713292       604.800000
# BATF2        2.319556       583.066667
# P2RY14       2.241647       511.666667
# FCGR1B       2.127004       572.733333

# %% [markdown]
# # [2] Get sub-network constructed from retaining only nodes with $mean(logFC) \ge 0.5$ & detect communities

# %% [markdown]
# ## [2.1] Get most heavily weighted edges that pass optimal threshold & construct sub-graph

# %%
len(G_deg_logFC_df.mean_log2FC[abs(G_deg_logFC_df.mean_log2FC) >= 0.5].index)
# Out:
# 372

# %%
#get the nodes in the network that pass the logFC threshold
nodes_high_abs_logFC_subset = list(G_deg_logFC_df.mean_log2FC[abs(G_deg_logFC_df.mean_log2FC) >= 0.5].index)

#get the SUBGRAPH induced by the most these nodes (correspond to genes with >> |logFC|)
S = G.subgraph(nodes_high_abs_logFC_subset)

# %%
print(nx.info(S))
# Out:
# Name:
# Type: Graph
# Number of nodes: 372
# Number of edges: 62697
# Average degree: 337.0806

# %% [markdown]
# Use **Spring Layout** to set the positions of the nodes

# %%
pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 4.5)

# %%
fig , ax = plt.subplots()

nx.draw_networkx(
    S, 
    pos = pos, 
    ax = ax,
    node_size = 45, 
    node_color = 'xkcd:black',
    linewidths = 0.0,
    edge_color = "0.9",
    width=0.25,
    alpha = 0.75, 
    with_labels = False)

fig = plt.gcf()
fig.set_size_inches(7.5, 7.5)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### *Function* to retrieve node colors based of node values (i.e. weighted degree, logFC for gene)

# %%
def get_node_colors(node_values):
    
    '''
    This function takes a list of values for each node and color map, 
    normalizes the list of values from 0.0-1.0 and assigns each node 
    a color from a color map based on normalized values. Returns a 
    list of colors for nodes.
    '''
    
    #load mpl colormap and normalize to data
    color_scheme = plt.get_cmap('afmhot_r')
    norm = mpl.colors.Normalize(vmin = min(node_values), vmax = max(node_values)) #get the normalization
    color_scheme_norm = mpl.cm.ScalarMappable(norm = norm, cmap = color_scheme) #normalize the color map to the min/max values of the node values
    
    #get color for each node from color map
    color_map = []
    for node_value in node_values:
        color_map.append(color_scheme_norm.to_rgba(node_value))
        
    return [color_map, norm, color_scheme]

# %% [markdown]
# #### *Function* to visualize network by weighted degree & logFC based on gene values

# %%
def visualize_network_color_by_weighted_deg_and_logFC(G, pos):
    
    #weighted degree for nodes in this network
    node_weighted_deg_values = G_deg_logFC_df.weighted_degree[list(G.nodes)] 
    
    #logFC for nodes in this network
    node_logFC_values = G_deg_logFC_df.mean_log2FC[list(G.nodes)] 
    
    fig = plt.figure(constrained_layout=True)

    gs = GridSpec(2, 2, figure=fig, height_ratios = [13,1])

    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    ax3 = fig.add_subplot(gs[1, 0])
    ax4 = fig.add_subplot(gs[1, 1])
    
    #color nodes by weighted deg 
    node_colors , color_bar_norm , color_scheme = get_node_colors(node_weighted_deg_values)
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax1,
        node_size = 40, 
        node_color = node_colors,
        linewidths = 0.2, #width of the node outlines
        edge_color = "0.83",
        width=0.1,
        alpha = 1.0, 
        with_labels = False)
    ax1.collections[0].set_edgecolor("black") #color of the node outlines
    cb1 = mpl.colorbar.ColorbarBase(ax3, cmap = color_scheme, norm = color_bar_norm, orientation='horizontal')
    cb1.set_label('Weighted Degree', fontsize = 14, color = 'k', weight = 'bold')
    
    #color nodes by logFC
    node_colors , color_bar_norm , color_scheme = get_node_colors(node_logFC_values)
    nx.draw_networkx(
        G, 
        pos = pos, 
        ax = ax2,
        node_size = 40, 
        node_color = node_colors,
        linewidths = 0.2,
        edge_color = "0.83",
        width=0.1,
        alpha = 1.0, 
        with_labels = False)
    ax2.collections[0].set_edgecolor("black") #color of the node outlines
    cb2 = mpl.colorbar.ColorbarBase(ax4, cmap = color_scheme, norm = color_bar_norm, orientation='horizontal')
    cb2.set_label('Mean logFC', fontsize = 14, color = 'k', weight = 'bold')

    ################### Plot
    fig = plt.gcf()
    fig.set_size_inches(17.25, 9.0)
    fig.tight_layout()

    #file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
    #plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

    plt.show()

# %%
visualize_network_color_by_weighted_deg_and_logFC(S, pos)

# %% [markdown]
# ## [2.2] Run gene-enrichment analysis on genes within subnetwork

# %% [markdown]
# ### Load and prepare gene sets

# %% [markdown]
# DataFrame for the Gene Sets (excel files from Wen-Han)

# %%
GeneSets_df = pd.read_csv(f'{Gene_Set_dir}GeneModule.csv')

#subset to the IMMUNE modules
GeneSets_IMMUNE_df = GeneSets_df.loc[0:297, :]

#subset to the REACTOME modules
GeneSets_REACTOME_df = GeneSets_df.loc[993:1666, :]

# %%
GeneSets_IMMUNE_df.head()
# Out:
#         ID                                    Title            Category   B
# 0    LI.M0                       targets of FOSL1/2          TF targets  12
# 1  LI.M1.0   integrin cell surface interactions (I)  molecular function  29
# 2  LI.M1.1  integrin cell surface interactions (II)  molecular function  12
# 3  LI.M2.0                 extracellular matrix (I)            location  30
# 4  LI.M2.1                extracellular matrix (II)            location  45

# %%
np.shape(GeneSets_IMMUNE_df)
# Out:
# (298, 4)

# %%
GeneSets_REACTOME_df.head()
# Out:
#          ID                                              Title  \
# 993  M19193         Reactome glycogen breakdown glycogenolysis
# 994   M8229                               Reactome translation
# 995  M10654                     Reactome pyrimidine catabolism
# 996    M486  Reactome rna pol iii transcription initiation ...
# 997    M489  Reactome inhibition of the proteolytic activit...
#
#            Category    B
# 993  C2:CP:REACTOME   18
# 994  C2:CP:REACTOME  222
# 995  C2:CP:REACTOME   12
# 996  C2:CP:REACTOME   23
# 997  C2:CP:REACTOME   24

# %%
np.shape(GeneSets_REACTOME_df)
# Out:
# (674, 4)

# %% [markdown]
# DataFrame for the genes that belong to each Gene Set

# %%
GeneSet_GeneLists_df = pd.read_csv(f'{Gene_Set_dir}GeneModule_Genelist.csv')
GeneSet_GeneLists_df.set_index('ID', drop = True, inplace = True)

# %%
GeneSet_GeneLists_df.head()
# Out:
#        Gene
# ID
# LI.M0  CCL2
# LI.M0   DCN
# LI.M0   LIF
# LI.M0  PLAU
# LI.M0   IL6

# %%
np.shape(GeneSet_GeneLists_df)
# Out:
# (84042, 1)

# %% [markdown]
# #### Convert gene sets to a dictionary
# - keys: gene sets
# - values: list of genes belonging to each set

# %%
#Immune-specific gene sets
gene_set_IMMUNE_dict = {}
for gene_set_i in GeneSets_IMMUNE_df.ID:
    
    gene_list_for_set_i = list(GeneSet_GeneLists_df[GeneSet_GeneLists_df.index == gene_set_i].Gene)
    gene_set_IMMUNE_dict[gene_set_i] = gene_list_for_set_i

#Reactome gene sets
gene_set_REACTOME_dict = {}
for gene_set_i in GeneSets_REACTOME_df.ID:
    
    gene_list_for_set_i = list(GeneSet_GeneLists_df[GeneSet_GeneLists_df.index == gene_set_i].Gene)
    gene_set_REACTOME_dict[gene_set_i] = gene_list_for_set_i

# %%
len(gene_set_IMMUNE_dict.keys()) #number of gene sets
# Out:
# 298

# %%
len(gene_set_REACTOME_dict.keys()) #number of gene sets
# Out:
# 674

# %% [markdown]
# #### *Function* to run gene set enrichment

# %%
def run_enrichr_on_list_of_genes(gene_list, gene_set_category):
    
    #specify which gene sets we'll probe for enrichment
    if gene_set_category == 'IMMUNE':
        gene_set_dict = gene_set_IMMUNE_dict
    elif gene_set_category == 'REACTOME':
        gene_set_dict = gene_set_REACTOME_dict
    
    #run enrichr
    enr = gp.enrichr(gene_list = gene_list,  
        gene_sets = gene_set_dict,
        background = 'hsapiens_gene_ensembl',
        organism = 'Human',
        description = f'community pathway enrichment',
        outdir = f'{Data_files_dir}/enrichr gene set analyses bucket',
        no_plot = True)

    #filter & sort enrichr results df
    enrichr_results_df = enr.results
    enrichr_results_df = enrichr_results_df.loc[: , ['Term', 'P-value', 'Adjusted P-value', 'Overlap', 'Genes']] #subset to necessary columns
    enrichr_results_df.rename(columns = {'Term':'ID'}, inplace = True) #rename column for merging with Gene Set df
    enrichr_results_df = enrichr_results_df[enrichr_results_df.loc[: , 'Adjusted P-value'] <= 0.001] #keep hits with lowest adj. p-vals
    enrichr_results_df.sort_values(by = 'Adjusted P-value', ascending = True , inplace = True) #sort by lowest p-val
    enrichr_results_df.reset_index(inplace = True, drop = True) #reset index
    enrichr_results_df = enrichr_results_df.merge(GeneSets_df.loc[: , ['ID','Title','Category']], how = 'left', on = 'ID') #get details for gene sets
    
    #average the (mean logFC) for each gene detected as part of the gene set and append as another column
    avg_meanlogFC = [mean_logFC_series[enrichr_results_df.Genes[pathway_i].split(';')].mean() for pathway_i in enrichr_results_df.index]
    enrichr_results_df.loc[: , 'logFC'] = avg_meanlogFC
    
    return enrichr_results_df

# %% [markdown]
# ### Run gene set enrichment on genes in subnetwork

# %% [markdown]
# Pathway enrichment with **Immune** modules

# %%
run_enrichr_on_list_of_genes(list(S.nodes), 'IMMUNE')
# Out:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  1.933581e-60      2.823028e-58   41/53
# 1     DC.M1.2  4.089322e-27      2.985205e-25   19/27
# 2    LI.M37.0  5.317418e-26      1.552686e-24  47/347
# 3     DC.M4.1  3.191900e-26      1.552686e-24   24/58
# 4    DC.M5.12  5.286039e-26      1.552686e-24   24/59
# 5      LI.M75  2.623444e-21      6.383713e-20   15/22
# 6    LI.M11.0  6.121860e-20      1.276845e-18  31/189
# 7     LI.M127  1.612054e-18      2.941998e-17   11/12
# 8    DC.M4.15  3.428827e-17      5.562320e-16   16/42
# 9     LI.M165  1.480548e-15      2.161600e-14   14/35
# 10     LI.M67  7.870711e-14      9.576032e-13    9/12
# 11    LI.M150  7.870711e-14      9.576032e-13    9/12
# 12  LI.M111.1  3.088177e-12      3.468260e-11    8/11
# 13   DC.M5.15  6.555364e-12      6.836308e-11   10/23
# 14     LI.M16  5.547178e-11      5.399253e-10   12/46
# 15    DC.M4.2  9.588950e-11      8.749916e-10   12/48
# 16    LI.M7.0  2.324823e-09      1.996612e-08   12/62
# 17     LI.M68  1.050089e-08      8.517390e-08    6/10
# 18     LI.M40  8.164055e-08      6.264278e-07    6/13
# 19    DC.M3.2  8.581202e-08      6.264278e-07  15/138
# 20    LI.M4.0  2.053512e-07      1.427680e-06  23/335
# 21   DC.M6.13  3.222531e-07      2.138589e-06    9/48
# 22    LI.M7.1  4.651178e-07      2.952487e-06    9/50
# 23  LI.M111.0  5.510313e-07      3.352107e-06    6/17
# 24     LI.M13  1.162130e-06      6.786841e-06    5/11
# 25  LI.M118.0  1.480610e-06      8.314192e-06    9/57
# 26    LI.M117  2.261266e-06      1.179089e-05    6/21
# 27      LI.S4  2.212097e-06      1.179089e-05   11/94
# 28    LI.M5.0  3.931296e-06      1.979204e-05   10/81
# 29    LI.M109  7.081460e-06      3.335139e-05    5/15
# 30    LI.M7.4  7.081460e-06      3.335139e-05    5/15
# 31  LI.M112.0  1.412907e-05      6.446389e-05    5/17
# 32    LI.M4.3  2.601104e-05      1.144136e-04    6/31
# 33     LI.M44  2.742792e-05      1.144136e-04    4/10
# 34    LI.M113  2.742792e-05      1.144136e-04    4/10
# 35     LI.M14  6.267526e-05      2.541830e-04    4/12
# 36     LI.S11  7.440063e-05      2.935809e-04    6/37
# 37   LI.M61.0  8.671164e-05      3.331553e-04    5/24
# 38   DC.M4.14  1.461977e-04      5.473042e-04    7/59
#
#                                                 Genes  \
# 0   GBP5;EIF2AK2;MT2A;CARD17;AIM2;IFITM1;LGALS3BP;...
# 1   OASL;XAF1;OAS2;IFIT3;ISG15;HERC5;OAS1;RTP4;CXC...
# 2   CYFIP1;CACNA2D3;CD7;SLC26A8;DYSF;NLRC4;CAMP;MA...
# 3   NELL2;BACH2;SPOCK2;GPR183;KLHL3;EPHA4;TXK;HPCA...
# 4   SRBD1;TCN2;TYMP;CASP1;TRIM21;PSMB9;GBP2;GADD45...
# 5   ANXA3;PML;HERC5;C1QB;OAS1;CXCL10;IFIH1;RSAD2;I...
# 6   CYFIP1;CACNA2D3;ADAP2;TYMP;FCGR1B;FGL2;RNASE2;...
# 7   STAT1;HERC5;IFIH1;RSAD2;TAP1;PLSCR1;IFITM1;IRF...
# 8   S1PR1;CD6;ARL4C;ZNF831;TC2N;CD7;ZNF256;CD96;CD...
# 9   TNFAIP6;IFI27;IFIT2;HERC5;IFIH1;PRRG4;ATF3;RSA...
# 10  IFIH1;C1QC;RSAD2;PLSCR1;C2;IRF7;DDX60;SERPING1...
# 11  OASL;EIF2AK2;OAS1;RSAD2;TAP1;PLSCR1;IFIT1;IRF7...
# 12   BST2;IFIT2;CXCL10;TAP1;ZBP1;CASP1;TNFSF13B;DDX58
# 13  CEACAM6;MMP8;CEACAM8;HP;DEFA4;CAMP;OLR1;LTF;EL...
# 14  TLR8;FCGR1A;KCNJ15;LY96;KCNJ2;DYSF;LILRA6;FCGR...
# 15  SIPA1L2;LIMK2;ANXA3;MAPK14;S100A12;LMNB1;SLPI;...
# 16  ETS1;NELL2;CD6;IL7R;LEF1;CD7;CD96;ITK;KLRB1;CD...
# 17               ISG15;CXCL10;IFIH1;IRF7;TRIM25;DDX58
# 18                      C1QA;LY96;C1QB;C1QC;OLR1;TLR8
# 19  ZNF438;MSRB1;KCNJ15;LY96;BST1;SULT1B1;SLC26A8;...
# 20  CEACAM8;LMNB1;TYMP;FCGR1B;FGL2;S100A12;LMO2;MN...
# 21  STK3;DRAM1;CLEC12A;STX11;VPS9D1;NLRC4;RAB20;MN...
# 22          CCR7;IL7R;LEF1;CD7;TXK;CD5;ITK;CD247;CD27
# 23                 BST2;TAP1;ZBP1;TLR7;TNFSF13B;IFI35
# 24                        CXCL10;AIM2;ZBP1;IRF7;DDX58
# 25  LY96;SMARCD3;TNFSF13B;DYSF;MARC1;VNN1;NAIP;DPY...
# 26                   NELL2;CD6;SPOCK2;LEF1;CD96;CXCR3
# 27  MARCO;CLEC12A;ASGR1;MCTP1;AGTRAP;CCR2;DYSF;FCG...
# 28  CCR7;CD19;MAPK14;LY96;CD247;FCGR1B;ITK;MNDA;TL...
# 29                         S1PR1;CCR7;LEF1;CCR2;LRRK2
# 30                         NELL2;ETS1;LEF1;CD96;KLF12
# 31                         C1QA;C1QB;C1QC;C2;SERPING1
# 32                  MYOF;ASGR1;GPBAR1;TLR8;MARCO;TLR5
# 33                            IL23A;IL7R;IFI30;MAPK14
# 34                          TLR8;SORT1;FAM198B;LPCAT2
# 35                               LRRN3;SPOCK2;TXK;ITK
# 36            IFI6;TMEM140;IFI27;PRRG4;CD274;TNFSF13B
# 37                         CD7;CD96;KLRB1;CD247;PVRIG
# 38         CYFIP1;FAM198B;FZD2;ASGR1;GPBAR1;CYBB;CD36
#
#                                                 Title            Category  \
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M1
# 2                 immune activation - generic cluster              immune
# 3                                              T cell               DC.M4
# 4                                          Interferon               DC.M5
# 5                             antiviral IFN signature              immune
# 6                          enriched in monocytes (II)              immune
# 7                          type I interferon response              immune
# 8                                             T cells               DC.M4
# 9          enriched in activated dendritic cells (II)              immune
# 10                          activated dendritic cells              immune
# 11                          innate antiviral response              immune
# 12  viral sensing & immunity; IRF2 targets network...              immune
# 13                                        Neutrophils               DC.M5
# 14                     TLR and inflammatory signaling              immune
# 15                                       Inflammation               DC.M4
# 16                            enriched in T cells (I)              immune
# 17                      RIG-1 like receptor signaling              immune
# 18              complement and other receptors in DCs              immune
# 19                                       Inflammation               DC.M3
# 20                       cell cycle and transcription  biological process
# 21                                         Cell Death               DC.M6
# 22                              T cell activation (I)              immune
# 23  viral sensing & immunity; IRF2 targets network...              immune
# 24         innate activation by cytosolic DNA sensing              immune
# 25                         enriched in monocytes (IV)              immune
# 26                                 cell adhesion (GO)  molecular function
# 27                         Monocyte surface signature              immune
# 28  regulation of antigen presentation and immune ...              immune
# 29                          receptors, cell migration  molecular function
# 30                            T cell activation (III)              immune
# 31                          complement activation (I)              immune
# 32   myeloid cell enriched receptors and transporters              immune
# 33                 T cell signaling and costimulation              immune
# 34                                 golgi membrane (I)            location
# 35                             T cell differentiation              immune
# 36   Activated (LPS) dendritic cell surface signature              immune
# 37                          enriched in NK cells (II)              immune
# 38                                          Monocytes               DC.M4
#
#        logFC
# 0   0.987039
# 1   1.190130
# 2   0.634590
# 3  -0.833810
# 4   0.711818
# 5   1.087366
# 6   0.713188
# 7   0.910252
# 8  -0.599919
# 9   1.077035
# 10  1.166409
# 11  0.863285
# 12  0.775062
# 13  0.574337
# 14  0.990161
# 15  0.859876
# 16 -0.692751
# 17  0.792091
# 18  0.804881
# 19  0.711365
# 20  0.792591
# 21  0.683978
# 22 -0.716859
# 23  0.748877
# 24  0.941108
# 25  0.764113
# 26 -0.806442
# 27  0.818665
# 28  0.332200
# 29 -0.240964
# 30 -0.749914
# 31  1.534473
# 32  0.758664
# 33 -0.031499
# 34  0.696940
# 35 -0.803379
# 36  0.804111
# 37 -0.614369
# 38  0.600054

# %% [markdown]
# Pathway enrichment with **Reactome** modules

# %%
run_enrichr_on_list_of_genes(list(S.nodes), 'REACTOME')
# Out:
#        ID       P-value  Adjusted P-value Overlap  \
# 0   M1045  5.746342e-27      1.723903e-24  76/933
# 1    M983  1.488919e-24      2.233379e-22  33/159
# 2   M1060  8.153435e-21      8.153435e-19  37/270
# 3    M973  1.813580e-16      1.360185e-14   18/64
# 4   M1036  5.248722e-15      3.149233e-13  31/279
# 5    M965  5.196278e-14      2.598139e-12   16/63
# 6  M19752  2.268174e-06      9.720745e-05    7/32
# 7    M550  5.218711e-06      1.957017e-04    9/66
# 8    M985  2.601104e-05      8.670346e-04    6/31
#
#                                                Genes  \
# 0  GBP5;EIF2AK2;MT2A;C4BPA;ISG15;OAS1;PIK3AP1;AIM...
# 1  GBP5;EIF2AK2;MT2A;ISG15;OAS1;IFITM1;FCGR1B;GBP...
# 2  GBP5;EIF2AK2;MT2A;ISG15;OAS1;IFITM1;FCGR1B;GBP...
# 3  OASL;STAT2;IFI6;IFI27;OAS2;XAF1;IFIT2;ISG15;ST...
# 4  ISG15;C4BPA;C1QC;AIM2;NLRC4;CASP1;DDX58;DEFA1B...
# 5  OASL;GBP5;MT2A;OAS2;PML;STAT1;OAS1;JAK2;IRF7;F...
# 6                   PROS1;C1QA;C4BPA;C1QB;C1QC;C2;C5
# 7  EIF2AK2;STAT1;ISG15;HERC5;UBE2L6;IFIT1;FLNB;TR...
# 8              ISG15;HERC5;IFIH1;UBE2L6;TRIM25;DDX58
#
#                                                Title        Category     logFC
# 0                             Reactome immune system  C2:CP:REACTOME  0.729931
# 1                      Reactome interferon signaling  C2:CP:REACTOME  0.940852
# 2       Reactome cytokine signaling in immune system  C2:CP:REACTOME  0.831985
# 3           Reactome interferon alpha beta signaling  C2:CP:REACTOME  0.893786
# 4                      Reactome innate immune system  C2:CP:REACTOME  0.822585
# 5                Reactome interferon gamma signaling  C2:CP:REACTOME  1.113092
# 6                        Reactome complement cascade  C2:CP:REACTOME  1.008820
# 7  Reactome antiviral mechanism by ifn stimulated...  C2:CP:REACTOME  0.597439
# 8  Reactome negative regulators of rig i mda5 sig...  C2:CP:REACTOME  0.797765

# %% [markdown]
# ## [3] Calculate *num edges*, *mean edge weight*, *num nodes* & *mean weighted degree*  for subgraphs induced by highest weighted edges

# %% [markdown]
# ### Edges Weights for Node Pairs (gene pairs)

# %%
edge_weight_dict = nx.get_edge_attributes(G, 'weight') #keys: node pairs; values: edge weights
edge_weight_array = np.array(list(edge_weight_dict.values())) #array of edge weights in graph

# %%
len(edge_weight_array)
# Out:
# 672127

# %%
edge_weight_array.mean()
# Out:
# 0.2537207006017215

# %% [markdown]
# ### Distribution of Edge Weights in original Network

# %%
def prettify_plot(ax):
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.grid(False)
    ax.tick_params(labelcolor = 'k')
    ax.tick_params(axis='y', which='major', labelsize=12 , labelcolor = 'k')
    ax.tick_params(axis='x', which='major', labelsize=12 , labelcolor = 'k')

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(1, 1, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])

#EDGE WEIGHTS
ax1.hist(edge_weight_array , bins = len(set(edge_weight_array)), color = 'black' , rwidth = 0.95 , edgecolor='white', linewidth=0.0, align='left')

ax1.set_ylabel('Number of Edges', fontsize = 12, color = 'k')
ax1.set_xlabel('Edge Weight' , fontsize = 12, color = 'k')

prettify_plot(ax1)
#ax1.set_yscale('log')
    
################### Plot ###################
fig = plt.gcf()
fig.set_size_inches(9, 5.5)
fig.tight_layout()

#file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
#plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()

# %%
edge_weight_thresholds = np.sort(np.array(list(set(edge_weight_array))))
edge_weight_thresholds
# Out:
# array([0.2       , 0.26666667, 0.33333333, 0.4       , 0.46666667,
#        0.53333333, 0.6       , 0.66666667, 0.73333333, 0.8       ,
#        0.86666667])

# %%
def get_characteristics_of_subgraph(edge_weight_thresh):
    
    '''
    (1) This function returns the mean (edge weight) & (weighted degree) of the subgraph induced by the edges 
    that pass the edge weight threshold in the larger network.
    
    (2) Function returns the (# Edges) and (# Nodes) for these different subgraphs.
    '''
    
    #get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
    edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
    edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

    #get the SUBGRAPH induced by the most heavily weighted edges
    S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))

    #Get a series of the WEIGHTED DEGREE for each node in the subgraph 
    node_list = [node_deg[0] for node_deg in list(S.degree(weight = 'weight'))]
    degree_list = [node_deg[1] for node_deg in list(S.degree(weight = 'weight'))]
    subgraph_weighted_degree_series = pd.Series(degree_list , index = node_list).sort_values(ascending = False)
    
    return [float(len(edge_weight_array_subset)), edge_weight_array_subset.mean(), float(len(node_list)), subgraph_weighted_degree_series.mean()]

# %% [markdown]
# #### Iterate through subnetworks of various sizes for different *edge weight thresholds* in original network

# %%
num_edges_for_subnetworks_list = []
mean_edge_weight_for_subnetworks_list = []
num_nodes_for_subnetworks_list = []
mean_weighted_deg_for_subnetworks_list = []

for edge_weight_thresh in edge_weight_thresholds:
    
    subgraph_num_edges , subgraph_mean_edge_weight , subgraph_num_nodes , subgraph_mean_weighted_deg = get_characteristics_of_subgraph(edge_weight_thresh)
    
    num_edges_for_subnetworks_list.append(subgraph_num_edges)
    mean_edge_weight_for_subnetworks_list.append(subgraph_mean_edge_weight)
    num_nodes_for_subnetworks_list.append(subgraph_num_nodes)
    mean_weighted_deg_for_subnetworks_list.append(subgraph_mean_weighted_deg)
    
    print(edge_weight_thresh)
    
#convert to arrays
num_edges_for_subnetworks = np.array(num_edges_for_subnetworks_list)
mean_edge_weight_for_subnetworks = np.array(mean_edge_weight_for_subnetworks_list)
num_nodes_for_subnetworks = np.array(num_nodes_for_subnetworks_list)
mean_weighted_deg_for_subnetworks = np.array(mean_weighted_deg_for_subnetworks_list)
# Out:
# 0.2
# 0.26666666666666666
# 0.3333333333333333
# 0.4
# 0.4666666666666667
# 0.5333333333333333
# 0.6
# 0.6666666666666666
# 0.7333333333333333
# 0.8
# 0.8666666666666667

# %% [markdown]
# #### Plot various characteristics of subgraphs induced by highest weighted edges

# %%
fig = plt.figure(constrained_layout=True)

gs = GridSpec(2, 2, figure=fig)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])

#NUMBER OF EDGES
ax1.scatter(edge_weight_thresholds, num_edges_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax1.plot(edge_weight_thresholds, num_edges_for_subnetworks , color = 'black' , linewidth=1.0)

ax1.set_ylabel('Number of Edges in Subgraph', fontsize = 12, color = 'k')
ax1.set_title('# of Edges', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax1)

#EDGE WEIGHT
ax2.scatter(edge_weight_thresholds, mean_edge_weight_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax2.plot(edge_weight_thresholds, mean_edge_weight_for_subnetworks , color = 'black' , linewidth=1.0)

ax2.set_ylabel('Mean Edge Weight in Subgraph', fontsize = 12, color = 'k')
ax2.set_title('Mean Edge Weight', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax2)

#NUMBER OF NODES

#targeting sub-networks with around ~50-500 nodes
ax3.axhline(y = 500, linewidth = 1.0, color = 'green', linestyle = '--')
ax3.axhline(y = 50, linewidth = 1.0, color = 'green', linestyle = '--')

ax3.scatter(edge_weight_thresholds, num_nodes_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax3.plot(edge_weight_thresholds, num_nodes_for_subnetworks , color = 'black' , linewidth=1.0)

ax3.set_ylabel('Number of Nodes in Subgraph', fontsize = 12, color = 'k')
ax3.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')
ax3.set_title('# of Nodes', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax3)
    
#WEIGHTED DEGREE
ax4.scatter(edge_weight_thresholds, mean_weighted_deg_for_subnetworks , color = 'black' , linewidth=0.75 , edgecolor = 'white' , s = 40 , alpha = 1.0)
ax4.plot(edge_weight_thresholds, mean_weighted_deg_for_subnetworks , color = 'black' , linewidth=1.0)

ax4.set_ylabel('Mean Weighted Degree in Subgraph', fontsize = 12, color = 'k')
ax4.set_xlabel('Edge Weight Threshold used to construct Subgraph' , fontsize = 12, color = 'k')
ax4.set_title('Mean Weighted Degree', fontsize = 12, color = 'k' , weight = 'bold')

prettify_plot(ax4)
    
################### Plot ###################
fig = plt.gcf()
fig.set_size_inches(12, 10)
fig.tight_layout()

#file_name = '/n/data1/hms/dbmi/farhat/Roger/homoplasy_project/Figures/lab_meeting_12_12_19/pairwise_SNP_distance/distribution_of_pairwise_SNP_distances.png'
#plt.savefig(file_name, bbox_inches='tight', dpi = 300 , transparent = True)

plt.show()

# %% [markdown]
# How does the **edge weight threshold** affect the **number of nodes** in the subnetwork?

# %%
for edge_weight_thresh_i, num_nodes_subnetwork_i in zip(edge_weight_thresholds, num_nodes_for_subnetworks):
    print(f'Edge Weight Threshold = {edge_weight_thresh_i} , Number of Nodes in Subnetwork = {num_nodes_subnetwork_i}')
# Out:
# Edge Weight Threshold = 0.2 , Number of Nodes in Subnetwork = 3005.0
# Edge Weight Threshold = 0.26666666666666666 , Number of Nodes in Subnetwork = 1580.0
# Edge Weight Threshold = 0.3333333333333333 , Number of Nodes in Subnetwork = 1038.0
# Edge Weight Threshold = 0.4 , Number of Nodes in Subnetwork = 726.0
# Edge Weight Threshold = 0.4666666666666667 , Number of Nodes in Subnetwork = 502.0
# Edge Weight Threshold = 0.5333333333333333 , Number of Nodes in Subnetwork = 342.0
# Edge Weight Threshold = 0.6 , Number of Nodes in Subnetwork = 227.0
# Edge Weight Threshold = 0.6666666666666666 , Number of Nodes in Subnetwork = 141.0
# Edge Weight Threshold = 0.7333333333333333 , Number of Nodes in Subnetwork = 81.0
# Edge Weight Threshold = 0.8 , Number of Nodes in Subnetwork = 38.0
# Edge Weight Threshold = 0.8666666666666667 , Number of Nodes in Subnetwork = 9.0

# %% [markdown]
# We're aiming to run enrichment analysis on **~50-500 nodes** so we have to adjust the edge-weight thresholds for this.

# %%
print(edge_weight_thresholds[4:-1])
# Out:
# [0.46666667 0.53333333 0.6        0.66666667 0.73333333 0.8       ]

# %%
edge_weight_thresholds = edge_weight_thresholds[4:-1]

# %% [markdown]
# ## [4] Iterate through subnetworks constructed from most heavily weighted edges and preform gene enrichment analysis

# %% [markdown]
# ### *Function* to plot subnetworks (after thresholding edge weights) & perform gene enrichment on nodes

# %%
def subgraph_visualize_and_gene_enrichment(edge_weight_thresh, gene_set_category):
    
    '''
    (1) This function returns visualizes the sub-network generated by 
    retaining only the edge weights above the input edge weight threshold.
        (1.1) colors nodes by weighted degree
        (1.2) colors nodes by mean logFC
        
    (2) This function also returns a dataframe from the gene enrichment 
    analysis run on the nodes of the subnetwork.
    '''
    
    #get the EDGE WEIGHTS for edges in the network that pass the edge weight threshold
    edge_weight_dict_subset = {key:value for key, value in edge_weight_dict.items() if value >= edge_weight_thresh}
    edge_weight_array_subset = np.array(list(edge_weight_dict_subset.values()))

    #get the SUBGRAPH induced by the most heavily weighted edges
    S = G.edge_subgraph(list(edge_weight_dict_subset.keys()))
    
    #print some stats
    print('')
    print('')
    print('')
    print('')
    print(f'Edge Weight Threshold = {edge_weight_thresh}')
    print(f'Number of Nodes = {len(S.nodes)}')
    print('---------------------------------------------')
    
    #visualize subgraph
    pos = nx.spring_layout(S , weight = 'weight' , iterations = 350 , k = 1.75)
    visualize_network_color_by_weighted_deg_and_logFC(S, pos)
    
    #gene set enrichment
    gene_enrichr_df = run_enrichr_on_list_of_genes(list(S.nodes), gene_set_category)
    print(f'gene enrichment for nodes in this network: ')
    display(gene_enrichr_df.head(n=40)) #return the top 40 hits if there are > 40
    print('---------------------------------------------')
    
    ## return gene_enrichr_df

# %% [markdown]
# ### Iterate through subnetworks of various sizes for different *edge weight thresholds* in original network

# %% [markdown]
# We're going to start with the smallest **edge weight threshold** and iterate down from there (increase edge weight threshold but decrease # of nodes) to preform gene enrichment

# %% [markdown]
# ## [4.1] *Immune* Gene Sets

# %% [markdown]
# ################################################################################################################################################################################################

# %%
for edge_weight_thresh in edge_weight_thresholds:
    
    subgraph_visualize_and_gene_enrichment(edge_weight_thresh, 'IMMUNE')
# Out:
# Edge Weight Threshold = 0.4666666666666667
# Number of Nodes = 502
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  7.115513e-55      1.188291e-52   41/53
# 1    DC.M5.12  1.119517e-38      9.347964e-37   34/59
# 2    LI.M11.0  1.276332e-33      7.104914e-32  48/189
# 3    LI.M37.0  5.242041e-29      2.188552e-27  57/347
# 4    DC.M4.15  1.681557e-27      5.616400e-26   24/42
# 5     DC.M4.1  4.719658e-26      1.313638e-24   26/58
# 6      LI.M75  1.860553e-25      4.438748e-24   18/22
# 7     DC.M1.2  1.302908e-24      2.719820e-23   19/27
# 8     DC.M3.2  1.936864e-21      3.593959e-20  32/138
# 9     DC.M4.2  1.529926e-19      2.554977e-18   20/48
# 10    LI.M7.0  3.104006e-18      4.712445e-17   21/62
# 11    LI.M127  4.500670e-17      6.263433e-16   11/12
# 12    LI.M7.1  9.273213e-14      1.106162e-12   16/50
# 13    LI.M165  9.151150e-14      1.106162e-12   14/35
# 14    LI.M4.0  1.810018e-13      2.015153e-12  37/335
# 15  LI.M111.1  3.009540e-13      3.141208e-12    9/11
# 16    LI.M150  1.175762e-12      1.090846e-11    9/12
# 17     LI.M67  1.175762e-12      1.090846e-11    9/12
# 18     LI.M16  7.251589e-12      6.373765e-11   14/46
# 19   DC.M6.13  1.389248e-11      1.160022e-10   14/48
# 20      LI.S4  3.960994e-11      3.149933e-10   18/94
# 21     LI.M14  9.965010e-11      7.564349e-10    8/12
# 22  LI.M111.0  1.154805e-10      8.384887e-10    9/17
# 23    LI.M5.0  2.765137e-09      1.924074e-08   15/81
# 24    LI.M4.3  4.002605e-09      2.673740e-08   10/31
# 25     LI.M81  1.506911e-08      9.679006e-08   10/35
# 26    LI.M7.4  4.549855e-08      2.620089e-07    7/15
# 27    LI.M109  4.549855e-08      2.620089e-07    7/15
# 28    LI.M7.2  4.517064e-08      2.620089e-07   11/49
# 29     LI.M68  6.257588e-08      3.483391e-07    6/10
# 30     LI.M18  1.345975e-07      7.024307e-07    6/11
# 31     LI.M13  1.345975e-07      7.024307e-07    6/11
# 32  LI.M118.0  2.364564e-07      1.196613e-06   11/57
# 33      LI.S0  3.152220e-07      1.548296e-06    8/27
# 34   DC.M4.10  1.329810e-06      6.345094e-06    8/32
# 35   LI.M61.0  1.990894e-06      9.235538e-06    7/24
# 36  LI.M112.0  3.150008e-06      1.406480e-05    6/17
# 37      LI.M3  3.200374e-06      1.406480e-05    9/47
# 38   LI.M37.1  7.687261e-06      3.291724e-05    9/52
# 39     LI.M56  8.483867e-06      3.542014e-05    5/12
#
#                                                 Genes  \
# 0   GBP5;EIF2AK2;MT2A;CARD17;AIM2;IFITM1;GBP1;PARP...
# 1   SRBD1;DHRS9;TDRD7;TCN2;TYMP;CASP1;TRIM21;PSMB9...
# 2   CYFIP1;CACNA2D3;FCER1G;RBM47;ADAP2;SECTM1;FCGR...
# 3   CYFIP1;CACNA2D3;SLC22A4;CD7;SLC26A8;SH2D1A;NLR...
# 4   ZNF831;TC2N;CD7;SH2D1A;ZNF256;CD27;CD6;THEMIS;...
# 5   NELL2;SPOCK2;GPR183;KLHL3;EPHA4;CD28;MAL;TXK;H...
# 6   BCL3;ANXA3;FCER1A;PML;HERC5;C1QB;OAS1;CXCL10;I...
# 7   OASL;XAF1;OAS2;IFIT3;ISG15;HERC5;OAS1;RTP4;CXC...
# 8   SULT1B1;SLC22A4;SLC26A8;DYSF;SOD2;STEAP4;PLXNC...
# 9   OSM;LIMK2;SIPA1L2;SLC2A14;ANXA3;MAPK14;SOCS3;L...
# 10  ETS1;NELL2;GIMAP7;PTPRCAP;CD7;SH2D1A;CD27;CD6;...
# 11  STAT1;HERC5;IFIH1;RSAD2;TAP1;PLSCR1;IFITM1;IRF...
# 12  RASGRP1;CCR7;CD3E;IL7R;CD28;LEF1;THEMIS;CD7;TX...
# 13  TNFAIP6;IFI27;IFIT2;HERC5;IFIH1;PRRG4;ATF3;RSA...
# 14  CEACAM8;FCER1G;LMNB1;RBM47;SECTM1;FCGR1B;TYMP;...
# 15  BST2;IFIT2;CXCL10;TAP1;ZBP1;PSMB8;CASP1;TNFSF1...
# 16  OASL;EIF2AK2;OAS1;RSAD2;TAP1;PLSCR1;IFIT1;IRF7...
# 17  IFIH1;C1QC;RSAD2;PLSCR1;C2;IRF7;DDX60;SERPING1...
# 18  HSPA6;TLR8;FCGR1A;KCNJ15;LY96;TLR4;KCNJ2;DYSF;...
# 19  HSPA6;BCL3;EIF4E3;STK3;CSTA;DRAM1;FCER1G;STX11...
# 20  SIRPB1;CCR1;MARCO;FCER1A;HCAR3;TLR4;AGTRAP;TLR...
# 21       RASGRP1;CD28;SPOCK2;MAL;TXK;SH2D1A;ITK;LRRN3
# 22  CXCL16;BST2;KYNU;TAP1;ZBP1;PSMB8;TLR7;TNFSF13B...
# 23  CCR7;CD3E;CD19;MAPK14;FCER1G;TLR4;THEMIS;LY96;...
# 24  MYOF;CCR1;IGSF6;ASGR1;CD14;SECTM1;GPBAR1;TLR8;...
# 25  PROS1;FCER1G;TLR4;LIN7A;CD14;CCR2;ITGB3;SELP;T...
# 26          RASGRP1;NELL2;ETS1;LEF1;THEMIS;CD96;KLF12
# 27              C3AR1;CCR7;CCR1;S1PR1;LEF1;CCR2;LRRK2
# 28  ARL4C;GIMAP7;PTGDR;CLIC3;PRKCH;IL2RB;CD96;ITK;...
# 29               ISG15;CXCL10;IFIH1;IRF7;TRIM25;DDX58
# 30                ETS1;SPOCK2;PRKCH;SH2D1A;ABLIM1;ITK
# 31                   CXCL10;AIM2;ZBP1;IRF7;IL1B;DDX58
# 32  LY96;HCAR3;SMARCD3;DYSF;STEAP4;LTBR;ACSL1;VNN1...
# 33       CD6;CD3E;PTPRCAP;CD28;MAL;SLC38A1;CD3G;LRRN3
# 34     OSBPL10;SPIB;CD19;BANK1;CXCR5;FCRLA;BLK;COBLL1
# 35             CD7;IL2RB;CD96;KLRF1;KLRB1;CD247;PVRIG
# 36                    C3AR1;C1QB;C1QC;C2;SERPING1;CR1
# 37  CCR1;CD3E;S100A12;HPSE;ADAP2;TLR2;NOD2;IL1RN;TLR5
# 38  FFAR2;MSRB1;KCNJ15;HCAR3;SLC22A4;LRG1;LIN7A;ST...
# 39                     HSPA6;CACNA2D3;DUSP3;CD14;IL1B
#
#                                                 Title            Category  \
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                          enriched in monocytes (II)              immune
# 3                 immune activation - generic cluster              immune
# 4                                             T cells               DC.M4
# 5                                              T cell               DC.M4
# 6                             antiviral IFN signature              immune
# 7                                          Interferon               DC.M1
# 8                                        Inflammation               DC.M3
# 9                                        Inflammation               DC.M4
# 10                            enriched in T cells (I)              immune
# 11                         type I interferon response              immune
# 12                              T cell activation (I)              immune
# 13         enriched in activated dendritic cells (II)              immune
# 14                       cell cycle and transcription  biological process
# 15  viral sensing & immunity; IRF2 targets network...              immune
# 16                          innate antiviral response              immune
# 17                          activated dendritic cells              immune
# 18                     TLR and inflammatory signaling              immune
# 19                                         Cell Death               DC.M6
# 20                         Monocyte surface signature              immune
# 21                             T cell differentiation              immune
# 22  viral sensing & immunity; IRF2 targets network...              immune
# 23  regulation of antigen presentation and immune ...              immune
# 24   myeloid cell enriched receptors and transporters              immune
# 25            enriched in myeloid cells and monocytes              immune
# 26                            T cell activation (III)              immune
# 27                          receptors, cell migration  molecular function
# 28                           enriched in NK cells (I)              immune
# 29                      RIG-1 like receptor signaling              immune
# 30             T cell differentiation via ITK and PKC              immune
# 31         innate activation by cytosolic DNA sensing              immune
# 32                         enriched in monocytes (IV)              immune
# 33                           T cell surface signature              immune
# 34                                             B cell               DC.M4
# 35                          enriched in NK cells (II)              immune
# 36                          complement activation (I)              immune
# 37                  regulation of signal transduction           signaling
# 38                        enriched in neutrophils (I)              immune
# 39                      suppression of MAPK signaling           signaling
#
#        logFC
# 0   0.960681
# 1   0.585968
# 2   0.586283
# 3   0.490869
# 4  -0.524134
# 5  -0.776418
# 6   0.910279
# 7   1.190130
# 8   0.513885
# 9   0.603263
# 10 -0.557615
# 11  0.910252
# 12 -0.585209
# 13  1.057776
# 14  0.633442
# 15  0.738843
# 16  0.863285
# 17  1.166409
# 18  0.864099
# 19  0.549999
# 20  0.592457
# 21 -0.611144
# 22  0.589455
# 23  0.205356
# 24  0.622513
# 25  0.555729
# 26 -0.639535
# 27 -0.080953
# 28 -0.459323
# 29  0.792091
# 30 -0.526720
# 31  0.849823
# 32  0.635492
# 33 -0.532680
# 34 -0.572831
# 35 -0.537299
# 36  1.218878
# 37  0.467285
# 38  0.502206
# 39  0.320892
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.5333333333333333
# Number of Nodes = 342
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  4.075691e-53      6.154294e-51   37/53
# 1    DC.M5.12  7.556971e-32      5.705513e-30   27/59
# 2      LI.M75  5.595363e-24      2.366028e-22   16/22
# 3     DC.M4.1  6.267623e-24      2.366028e-22   22/58
# 4    DC.M4.15  1.266917e-22      3.826089e-21   19/42
# 5     DC.M1.2  9.014004e-22      2.268524e-20   16/27
# 6    LI.M37.0  3.410349e-19      7.356610e-18  38/347
# 7    LI.M11.0  6.668830e-19      1.258742e-17  29/189
# 8     LI.M127  1.960507e-16      3.289295e-15   10/12
# 9   LI.M111.1  9.339562e-15      1.410274e-13    9/11
# 10    LI.M7.0  1.069893e-14      1.468671e-13   16/62
# 11    DC.M4.2  7.755402e-14      9.758881e-13   14/48
# 12     LI.M67  4.643129e-12      5.007946e-11    8/12
# 13    LI.M150  4.643129e-12      5.007946e-11    8/12
# 14    DC.M3.2  6.067190e-12      6.107638e-11  19/138
# 15    LI.M165  1.518313e-11      1.432908e-10   11/35
# 16    LI.M7.1  6.122445e-11      5.438172e-10   12/50
# 17  LI.M111.0  2.108060e-10      1.768428e-09    8/17
# 18   DC.M6.13  6.675012e-10      5.304878e-09   11/48
# 19    LI.M4.0  2.129574e-09      1.607829e-08  25/335
# 20     LI.M68  6.352654e-09      4.567861e-08    6/10
# 21     LI.M16  7.037802e-09      4.830492e-08   10/46
# 22      LI.S4  1.313079e-08      8.620647e-08   13/94
# 23     LI.M13  1.376462e-08      8.660239e-08    6/11
# 24    LI.M5.0  2.165927e-08      1.308220e-07   12/81
# 25     LI.M14  2.711329e-08      1.574657e-07    6/12
# 26    LI.M117  1.388672e-06      7.766277e-06    6/21
# 27    LI.M7.2  2.369294e-06      1.277726e-05    8/49
# 28   LI.M61.0  3.291145e-06      1.713665e-05    6/24
# 29    LI.M109  4.701927e-06      2.290294e-05    5/15
# 30    LI.M7.4  4.701927e-06      2.290294e-05    5/15
# 31  LI.M118.0  7.662303e-06      3.615649e-05    8/57
# 32    LI.M4.3  1.619159e-05      7.408879e-05    6/31
# 33      LI.M3  1.923526e-05      8.542717e-05    7/47
# 34     LI.M18  3.054458e-05      1.317780e-04    4/11
# 35   LI.M37.1  3.788966e-05      1.589261e-04    7/52
# 36     LI.M56  4.516865e-05      1.843369e-04    4/12
# 37      LI.S0  1.058703e-04      4.206953e-04    5/27
# 38    DC.M3.6  1.854480e-04      7.180166e-04    6/47
# 39     LI.M64  2.022653e-04      7.300682e-04    4/17
#
#                                                 Genes  \
# 0   GBP5;EIF2AK2;CARD17;AIM2;IFITM1;GBP1;PARP9;TNF...
# 1   SRBD1;TYMP;CASP1;TRIM21;PSMB9;GBP2;GADD45B;TAP...
# 2   ANXA3;FCER1A;PML;HERC5;C1QB;OAS1;CXCL10;IFIH1;...
# 3   NELL2;SPOCK2;GPR183;KLHL3;EPHA4;CD28;MAL;TXK;H...
# 4   S1PR1;CD6;ARL4C;ZNF831;TC2N;GPR18;CD7;ZNF256;P...
# 5   OASL;XAF1;IFIT3;ISG15;HERC5;OAS1;RTP4;CXCL10;R...
# 6   CACNA2D3;SLC22A4;CD7;SLC26A8;DYSF;ADAP2;NLRC4;...
# 7   CACNA2D3;FCER1G;ADAP2;DMXL2;FCGR1B;TYMP;FGL2;K...
# 8   STAT1;HERC5;IFIH1;RSAD2;TAP1;PLSCR1;IFITM1;IRF...
# 9   BST2;IFIT2;CXCL10;TAP1;ZBP1;PSMB8;CASP1;TNFSF1...
# 10  ETS1;NELL2;CD6;IL7R;CD28;LEF1;CD7;MAL;PRKCH;CD...
# 11  OSM;LIMK2;SIPA1L2;SLC2A14;ANXA3;MAPK14;LRG1;S1...
# 12  IFIH1;C1QC;RSAD2;PLSCR1;IRF7;DDX60;SERPING1;DDX58
# 13      OASL;EIF2AK2;OAS1;RSAD2;TAP1;PLSCR1;IRF7;OAS3
# 14  ZNF438;MSRB1;B4GALT5;OSCAR;KCNJ15;LY96;BST1;SL...
# 15  TNFAIP6;IFIT2;HERC5;IFIH1;PRRG4;ATF3;RSAD2;LAM...
# 16  CCR7;IL7R;CD28;LEF1;CD7;TXK;PRKCH;CD5;ITK;CD24...
# 17      BST2;KYNU;TAP1;ZBP1;PSMB8;TLR7;TNFSF13B;IFI35
# 18  EIF4E3;STK3;DRAM1;FCER1G;STX11;VPS9D1;NLRC4;PL...
# 19  FCER1G;LMNB1;DMXL2;FCGR1B;TYMP;FGL2;IL1RN;KYNU...
# 20               ISG15;CXCL10;IFIH1;IRF7;TRIM25;DDX58
# 21  FCGR1A;KCNJ15;LY96;KCNJ2;DYSF;TLR2;FCGR1B;BST1...
# 22  MARCO;FCER1A;HCAR3;ASGR1;AGTRAP;TLR5;CCR2;DYSF...
# 23                   CXCL10;AIM2;ZBP1;IRF7;IL1B;DDX58
# 24  CCR7;CD19;MAPK14;FCER1G;LY96;CD3G;TLR2;FCGR1B;...
# 25                      CD28;SPOCK2;MAL;TXK;ITK;LRRN3
# 26                   NELL2;CD6;SPOCK2;LEF1;CD96;CXCR3
# 27       ARL4C;CLIC3;PRKCH;CD96;ITK;KLRF1;KLRB1;CD247
# 28                   CD7;CD96;KLRF1;KLRB1;CD247;PVRIG
# 29                         S1PR1;CCR7;LEF1;CCR2;LRRK2
# 30                         NELL2;ETS1;LEF1;CD96;KLF12
# 31   LY96;HCAR3;SMARCD3;DYSF;LTBR;NAIP;TNFSF13B;LRRK2
# 32                  MYOF;ASGR1;CD14;GPBAR1;MARCO;TLR5
# 33            S100A12;HPSE;ADAP2;TLR2;NOD2;IL1RN;TLR5
# 34                              ETS1;SPOCK2;ITK;PRKCH
# 35        FFAR2;MSRB1;KCNJ15;HCAR3;SLC22A4;LRG1;CREB5
# 36                           DUSP3;CD14;IL1B;CACNA2D3
# 37                            CD6;CD28;MAL;CD3G;LRRN3
# 38               NCR3;PRSS23;CLIC3;TSEN54;ABCB1;KLRF1
# 39                              IL1RN;SOD2;IL1B;DRAM1
#
#                                                 Title            Category  \
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                             antiviral IFN signature              immune
# 3                                              T cell               DC.M4
# 4                                             T cells               DC.M4
# 5                                          Interferon               DC.M1
# 6                 immune activation - generic cluster              immune
# 7                          enriched in monocytes (II)              immune
# 8                          type I interferon response              immune
# 9   viral sensing & immunity; IRF2 targets network...              immune
# 10                            enriched in T cells (I)              immune
# 11                                       Inflammation               DC.M4
# 12                          activated dendritic cells              immune
# 13                          innate antiviral response              immune
# 14                                       Inflammation               DC.M3
# 15         enriched in activated dendritic cells (II)              immune
# 16                              T cell activation (I)              immune
# 17  viral sensing & immunity; IRF2 targets network...              immune
# 18                                         Cell Death               DC.M6
# 19                       cell cycle and transcription  biological process
# 20                      RIG-1 like receptor signaling              immune
# 21                     TLR and inflammatory signaling              immune
# 22                         Monocyte surface signature              immune
# 23         innate activation by cytosolic DNA sensing              immune
# 24  regulation of antigen presentation and immune ...              immune
# 25                             T cell differentiation              immune
# 26                                 cell adhesion (GO)  molecular function
# 27                           enriched in NK cells (I)              immune
# 28                          enriched in NK cells (II)              immune
# 29                          receptors, cell migration  molecular function
# 30                            T cell activation (III)              immune
# 31                         enriched in monocytes (IV)              immune
# 32   myeloid cell enriched receptors and transporters              immune
# 33                  regulation of signal transduction           signaling
# 34             T cell differentiation via ITK and PKC              immune
# 35                        enriched in neutrophils (I)              immune
# 36                      suppression of MAPK signaling           signaling
# 37                           T cell surface signature              immune
# 38                                  Cytotoxic/NK Cell               DC.M3
# 39    enriched in activated dendritic cells/monocytes              immune
#
#        logFC
# 0   1.009305
# 1   0.639072
# 2   0.982280
# 3  -0.842409
# 4  -0.565993
# 5   1.296355
# 6   0.548095
# 7   0.666786
# 8   0.935580
# 9   0.738843
# 10 -0.628138
# 11  0.698339
# 12  1.231202
# 13  0.889074
# 14  0.598097
# 15  1.155651
# 16 -0.642611
# 17  0.659994
# 18  0.618704
# 19  0.699864
# 20  0.792091
# 21  1.038182
# 22  0.639690
# 23  0.849823
# 24  0.279970
# 25 -0.698128
# 26 -0.806442
# 27 -0.517426
# 28 -0.548087
# 29 -0.240964
# 30 -0.749914
# 31  0.715704
# 32  0.730406
# 33  0.602329
# 34 -0.608646
# 35  0.530562
# 36  0.296205
# 37 -0.602450
# 38 -0.462135
# 39  0.355115
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6
# Number of Nodes = 227
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  4.881980e-51      6.053655e-49   33/53
# 1    DC.M5.12  2.669516e-24      1.655100e-22   20/59
# 2      LI.M75  3.582759e-18      1.480874e-16   12/22
# 3     DC.M4.1  5.018192e-18      1.555640e-16   16/58
# 4     LI.M127  8.851514e-16      2.195176e-14    9/12
# 5     DC.M1.2  5.978736e-15      1.235606e-13   11/27
# 6    LI.M37.0  1.110735e-14      1.721639e-13  27/347
# 7    LI.M11.0  1.070957e-14      1.721639e-13  21/189
# 8    DC.M4.15  4.968145e-14      6.845000e-13   12/42
# 9   LI.M111.1  5.770973e-14      7.156007e-13    8/11
# 10     LI.M67  1.713589e-13      1.931682e-12    8/12
# 11    LI.M7.0  7.870285e-12      7.368667e-11   12/62
# 12  LI.M111.0  7.994175e-12      7.368667e-11    8/17
# 13    DC.M4.2  8.319463e-12      7.368667e-11   11/48
# 14    DC.M3.2  1.119977e-09      9.258479e-09  14/138
# 15    LI.M150  2.339094e-09      1.812798e-08    6/12
# 16     LI.M16  3.117680e-09      2.274073e-08    9/46
# 17    LI.M165  6.433853e-09      4.432210e-08    8/35
# 18   DC.M6.13  9.028351e-08      5.892187e-07    8/48
# 19     LI.M13  1.004288e-07      6.226586e-07    5/11
# 20    LI.M7.1  1.258472e-07      7.430975e-07    8/50
# 21    LI.M5.0  5.143277e-07      2.898938e-06    9/81
# 22    LI.M4.0  6.014413e-07      3.242553e-06  17/335
# 23    LI.M7.4  6.278224e-07      3.243749e-06    5/15
# 24    LI.M117  4.012852e-06      1.990375e-05    5/21
# 25  LI.M118.0  4.970853e-06      2.370714e-05    7/57
# 26      LI.S4  1.664185e-05      7.642924e-05    8/94
# 27    LI.M109  2.422007e-05      1.072603e-04    4/15
# 28   LI.M61.0  1.733042e-04      7.410247e-04    4/24
# 29     LI.M44  1.886237e-04      7.544948e-04    3/10
# 30     LI.M68  1.886237e-04      7.544948e-04    3/10
# 31     LI.M18  2.570778e-04      9.961764e-04    3/11
#
#                                                 Genes  \
# 0   GBP5;CARD17;AIM2;IFITM1;GBP1;PARP9;TNFSF10;DDX...
# 1   ETV7;BST2;IFI16;SRBD1;PARP10;ACTA2;TAP1;PSMB9;...
# 2   ANXA3;FCER1A;PML;C1QB;OAS1;IFIH1;RSAD2;IRF7;DD...
# 3   NELL2;CCR7;IL7R;SPOCK2;CD28;DHRS3;GPR183;LEF1;...
# 4   STAT1;IFIH1;RSAD2;TAP1;PLSCR1;IFITM1;IRF7;DDX6...
# 5   OASL;XAF1;OAS1;RTP4;RSAD2;IFI44L;SERPING1;BATF...
# 6   SLC22A4;SLC26A8;DYSF;ADAP2;NLRC4;ROPN1L;MCTP1;...
# 7   ADAP2;DMXL2;FCGR1B;TYMP;FGL2;KYNU;LMO2;TLR5;PL...
# 8   S1PR1;CD6;TC2N;SKAP1;CD96;CD5;ITK;OCIAD2;KLF12...
# 9     BST2;IFIT2;TAP1;ZBP1;PSMB8;CASP1;TNFSF13B;DDX58
# 10  IFIH1;C1QC;RSAD2;PLSCR1;IRF7;DDX60;SERPING1;DDX58
# 11  ETS1;NELL2;CD6;IL7R;CD28;LEF1;CD96;ITK;KLRB1;C...
# 12      BST2;KYNU;TAP1;ZBP1;PSMB8;TLR7;TNFSF13B;IFI35
# 13  OSM;LIMK2;SIPA1L2;SLC2A14;ANXA3;MAPK14;LMNB1;K...
# 14  ZNF438;B4GALT5;OSCAR;KCNJ15;LY96;SLC22A4;SLC26...
# 15                   OASL;OAS1;RSAD2;TAP1;PLSCR1;IRF7
# 16  FCGR1A;KCNJ15;LY96;KCNJ2;DYSF;FCGR1B;BST1;TLR7...
# 17  TNFAIP6;IFIT2;IFIH1;PRRG4;RSAD2;SERPING1;PARP9...
# 18      STK3;DRAM1;STX11;VPS9D1;NLRC4;PLAUR;HK3;MCTP1
# 19                          AIM2;ZBP1;IRF7;IL1B;DDX58
# 20             CCR7;IL7R;CD28;LEF1;CD5;ITK;CD247;CD27
# 21   CCR7;CD19;MAPK14;LY96;FCGR1B;ITK;CD247;TLR7;TLR5
# 22  STAB1;MYOF;SORT1;CYBB;KYNU;LMO2;HPSE;LMNB1;PLA...
# 23                         NELL2;ETS1;LEF1;CD96;KLF12
# 24                         NELL2;CD6;SPOCK2;LEF1;CD96
# 25        LY96;HCAR3;SMARCD3;DYSF;LTBR;TNFSF13B;LRRK2
# 26     FCER1A;HCAR3;TLR5;DYSF;FCGR1B;LTBR;MARCO;MCTP1
# 27                              LEF1;S1PR1;CCR7;LRRK2
# 28                             KLRB1;CD247;CD96;PVRIG
# 29                                  IL7R;IFI30;MAPK14
# 30                                   IRF7;IFIH1;DDX58
# 31                                    ETS1;SPOCK2;ITK
#
#                                                 Title            Category  \
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                             antiviral IFN signature              immune
# 3                                              T cell               DC.M4
# 4                          type I interferon response              immune
# 5                                          Interferon               DC.M1
# 6                 immune activation - generic cluster              immune
# 7                          enriched in monocytes (II)              immune
# 8                                             T cells               DC.M4
# 9   viral sensing & immunity; IRF2 targets network...              immune
# 10                          activated dendritic cells              immune
# 11                            enriched in T cells (I)              immune
# 12  viral sensing & immunity; IRF2 targets network...              immune
# 13                                       Inflammation               DC.M4
# 14                                       Inflammation               DC.M3
# 15                          innate antiviral response              immune
# 16                     TLR and inflammatory signaling              immune
# 17         enriched in activated dendritic cells (II)              immune
# 18                                         Cell Death               DC.M6
# 19         innate activation by cytosolic DNA sensing              immune
# 20                              T cell activation (I)              immune
# 21  regulation of antigen presentation and immune ...              immune
# 22                       cell cycle and transcription  biological process
# 23                            T cell activation (III)              immune
# 24                                 cell adhesion (GO)  molecular function
# 25                         enriched in monocytes (IV)              immune
# 26                         Monocyte surface signature              immune
# 27                          receptors, cell migration  molecular function
# 28                          enriched in NK cells (II)              immune
# 29                 T cell signaling and costimulation              immune
# 30                      RIG-1 like receptor signaling              immune
# 31             T cell differentiation via ITK and PKC              immune
#
#        logFC
# 0   1.044983
# 1   0.694949
# 2   1.025110
# 3  -0.887565
# 4   0.954381
# 5   1.487243
# 6   0.713972
# 7   0.778576
# 8  -0.584301
# 9   0.692782
# 10  1.231202
# 11 -0.685099
# 12  0.659994
# 13  0.812549
# 14  0.662446
# 15  0.959007
# 16  1.104388
# 17  1.274367
# 18  0.661770
# 19  0.798322
# 20 -0.693410
# 21  0.310037
# 22  0.811681
# 23 -0.749914
# 24 -0.803369
# 25  0.717179
# 26  0.733394
# 27 -0.452267
# 28 -0.620593
# 29  0.131616
# 30  0.729172
# 31 -0.669851
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6666666666666666
# Number of Nodes = 141
# ---------------------------------------------
# gene enrichment for nodes in this network:
#            ID       P-value  Adjusted P-value Overlap  \
# 0     DC.M3.4  4.435005e-40      4.435005e-38   25/53
# 1    DC.M5.12  3.466803e-16      1.733401e-14   13/59
# 2     LI.M127  8.068521e-13      2.689507e-11    7/12
# 3      LI.M75  2.167810e-12      5.419524e-11    8/22
# 4    LI.M37.0  1.151906e-11      2.303812e-10  19/347
# 5     DC.M4.1  1.384044e-11      2.306741e-10   10/58
# 6      LI.M16  4.517370e-11      6.453386e-10    9/46
# 7      LI.M67  1.319746e-10      1.634988e-09    6/12
# 8     LI.M165  1.471489e-10      1.634988e-09    8/35
# 9    DC.M4.15  7.064758e-10      7.064758e-09    8/42
# 10    DC.M1.2  8.246482e-10      7.496802e-09    7/27
# 11  LI.M111.1  9.243314e-09      7.702762e-08    5/11
# 12   LI.M11.0  1.651042e-07      1.270032e-06  11/189
# 13  LI.M118.0  2.040438e-07      1.457456e-06    7/57
# 14    LI.M7.0  3.680367e-07      2.453578e-06    7/62
# 15    DC.M3.2  8.840539e-07      5.525337e-06   9/138
# 16   DC.M6.13  1.407900e-06      7.821666e-06    6/48
# 17    DC.M4.2  1.407900e-06      7.821666e-06    6/48
# 18  LI.M111.0  6.362630e-06      3.348753e-05    4/17
# 19    LI.M5.0  3.047852e-05      1.523926e-04    6/81
# 20     LI.M18  6.279524e-05      2.854329e-04    3/11
# 21     LI.M13  6.279524e-05      2.854329e-04    3/11
# 22    LI.M150  8.327298e-05      3.620565e-04    3/12
# 23     LI.M65  1.362895e-04      5.451581e-04    3/14
# 24   LI.M86.1  1.362895e-04      5.451581e-04    3/14
# 25    LI.M7.4  1.694391e-04      6.275521e-04    3/15
# 26    LI.M109  1.694391e-04      6.275521e-04    3/15
# 27    LI.M4.0  2.003700e-04      7.156070e-04  10/335
#
#                                                 Genes  \
# 0   GBP5;AIM2;GBP1;PARP9;TNFSF10;DDX58;IFIT2;FBXO6...
# 1   IFI16;SRBD1;ACTA2;TAP1;PSMB9;TYMP;DYNLT1;TRAFD...
# 2           STAT1;IFIH1;RSAD2;TAP1;PLSCR1;DDX60;PARP9
# 3    ANXA3;C1QB;IFIH1;RSAD2;DDX60;SERPING1;IL1B;DDX58
# 4   TNFAIP6;ANXA3;OSCAR;SMCO4;KCNJ15;HP;LY96;HCAR3...
# 5   NELL2;CCR7;IL7R;SPOCK2;DHRS3;GPR183;PASK;TMEM2...
# 6   FCGR1A;KCNJ15;LY96;KCNJ2;DYSF;FCGR1B;BST1;TLR7...
# 7             IFIH1;RSAD2;PLSCR1;DDX60;SERPING1;DDX58
# 8   TNFAIP6;IFIT2;IFIH1;PRRG4;RSAD2;SERPING1;PARP9...
# 9           S1PR1;CD6;SKAP1;CD5;ITK;OCIAD2;KLF12;GZMK
# 10        XAF1;RTP4;RSAD2;SERPING1;BATF2;IFIT3;IFITM3
# 11                    IFIT2;TAP1;CASP1;TNFSF13B;DDX58
# 12  MYOF;SORT1;HPSE;PLAUR;TYMP;FCGR1B;NOD2;BST1;EP...
# 13        LY96;HCAR3;SMARCD3;DYSF;LTBR;TNFSF13B;LRRK2
# 14                 ETS1;NELL2;CD6;IL7R;ITK;KLRB1;GZMK
# 15  ZNF438;OSCAR;KCNJ15;LY96;SLC22A4;SLC26A8;DYSF;...
# 16                STK3;DRAM1;STX11;VPS9D1;NLRC4;PLAUR
# 17               SIPA1L2;LIMK2;ANXA3;LMNB1;CASP5;TLR5
# 18                           TLR7;TNFSF13B;TAP1;IFI35
# 19                     CCR7;LY96;FCGR1B;ITK;TLR7;TLR5
# 20                                    ETS1;SPOCK2;ITK
# 21                                    IL1B;DDX58;AIM2
# 22                                  PLSCR1;RSAD2;TAP1
# 23                                      IL7R;CCR7;ITK
# 24                                  TNFAIP6;GCH1;IL1B
# 25                                   KLF12;NELL2;ETS1
# 26                                   S1PR1;CCR7;LRRK2
# 27  MYOF;SORT1;LMNB1;HPSE;PLAUR;TYMP;FCGR1B;NOD2;E...
#
#                                                 Title            Category  \
# 0                                          Interferon               DC.M3
# 1                                          Interferon               DC.M5
# 2                          type I interferon response              immune
# 3                             antiviral IFN signature              immune
# 4                 immune activation - generic cluster              immune
# 5                                              T cell               DC.M4
# 6                      TLR and inflammatory signaling              immune
# 7                           activated dendritic cells              immune
# 8          enriched in activated dendritic cells (II)              immune
# 9                                             T cells               DC.M4
# 10                                         Interferon               DC.M1
# 11  viral sensing & immunity; IRF2 targets network...              immune
# 12                         enriched in monocytes (II)              immune
# 13                         enriched in monocytes (IV)              immune
# 14                            enriched in T cells (I)              immune
# 15                                       Inflammation               DC.M3
# 16                                         Cell Death               DC.M6
# 17                                       Inflammation               DC.M4
# 18  viral sensing & immunity; IRF2 targets network...              immune
# 19  regulation of antigen presentation and immune ...              immune
# 20             T cell differentiation via ITK and PKC              immune
# 21         innate activation by cytosolic DNA sensing              immune
# 22                          innate antiviral response              immune
# 23                              IL2, IL7, TCR network              immune
# 24  proinflammatory dendritic cell, myeloid cell r...              immune
# 25                            T cell activation (III)              immune
# 26                          receptors, cell migration  molecular function
# 27                       cell cycle and transcription  biological process
#
#        logFC
# 0   1.090688
# 1   0.719344
# 2   1.048049
# 3   1.289749
# 4   0.855092
# 5  -1.022678
# 6   1.104388
# 7   1.345405
# 8   1.274367
# 9  -0.610583
# 10  1.761520
# 11  0.800885
# 12  1.011940
# 13  0.717179
# 14 -0.768613
# 15  0.767579
# 16  0.686032
# 17  0.939208
# 18  0.851131
# 19  0.528822
# 20 -0.669851
# 21  0.951834
# 22  1.162391
# 23 -0.853888
# 24  0.667335
# 25 -0.835898
# 26 -0.362592
# 27  1.027817
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.7333333333333333
# Number of Nodes = 81
# ---------------------------------------------
# gene enrichment for nodes in this network:
#          ID       P-value  Adjusted P-value Overlap  \
# 0   DC.M3.4  2.331869e-28      1.935451e-26   17/53
# 1   DC.M1.2  1.352900e-09      5.614534e-08    6/27
# 2    LI.M16  4.014745e-08      1.110746e-06    6/46
# 3   DC.M4.1  1.665893e-07      3.456728e-06    6/58
# 4  DC.M5.12  5.140949e-06      8.533976e-05    5/59
# 5   LI.M165  1.439131e-05      1.950034e-04    4/35
# 6  LI.M37.0  1.644607e-05      1.950034e-04   9/347
# 7  DC.M6.13  5.128189e-05      5.320496e-04    4/48
# 8   LI.M117  9.333157e-05      8.607245e-04    3/21
# 9    LI.M75  1.077371e-04      8.942175e-04    3/22
#
#                                                Genes  \
# 0  GBP5;SCO2;IFIT2;STAT1;FBXO6;UBE2L6;WARS;AIM2;C...
# 1              XAF1;RTP4;SERPING1;BATF2;IFIT3;IFITM3
# 2                 KCNJ15;KCNJ2;FCGR1B;BST1;TLR7;TLR5
# 3                 NELL2;CCR7;IL7R;DHRS3;SPOCK2;EPHA4
# 4                       SRBD1;ACTA2;TYMP;LHFPL2;GBP2
# 5                         PARP9;IFIT3;SERPING1;IFIT2
# 6  KCNJ15;HCAR3;STX11;CEACAM1;BST1;SMCO4;TLR7;TLR...
# 7                            VPS9D1;STK3;STX11;DRAM1
# 8                                   NELL2;CD6;SPOCK2
# 9                                 C1QB;SERPING1;IL1B
#
#                                         Title            Category     logFC
# 0                                  Interferon               DC.M3  1.204854
# 1                                  Interferon               DC.M1  1.790892
# 2              TLR and inflammatory signaling              immune  1.064768
# 3                                      T cell               DC.M4 -1.021795
# 4                                  Interferon               DC.M5  0.826639
# 5  enriched in activated dendritic cells (II)              immune  1.510122
# 6         immune activation - generic cluster              immune  0.839493
# 7                                  Cell Death               DC.M6  0.716461
# 8                          cell adhesion (GO)  molecular function -0.924989
# 9                     antiviral IFN signature              immune  1.715861
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.8
# Number of Nodes = 38
# ---------------------------------------------
# gene enrichment for nodes in this network:
#         ID       P-value  Adjusted P-value Overlap  \
# 0  DC.M3.4  7.514747e-16      4.959733e-14    9/53
# 1   LI.M16  3.110499e-08      1.026465e-06    5/46
# 2  DC.M1.2  2.075103e-05      3.423921e-04    3/27
# 3  LI.M5.0  2.009256e-05      3.423921e-04    4/81
#
#                                                Genes  \
# 0  GBP5;STAT1;FBXO6;AIM2;GBP4;LAP3;PARP9;TNFSF10;...
# 1                      KCNJ15;KCNJ2;FCGR1B;TLR7;TLR5
# 2                               XAF1;SERPING1;IFITM3
# 3                              CCR7;TLR7;FCGR1B;TLR5
#
#                                                Title Category     logFC
# 0                                         Interferon    DC.M3  1.296864
# 1                     TLR and inflammatory signaling   immune  1.135627
# 2                                         Interferon    DC.M1  1.855994
# 3  regulation of antigen presentation and immune ...   immune  0.721589
# ---------------------------------------------

# %% [markdown]
# ## [4.2] *Reactome* Gene Sets

# %% [markdown]
# ################################################################################################################################################################################################

# %%
for edge_weight_thresh in edge_weight_thresholds:
    
    subgraph_visualize_and_gene_enrichment(edge_weight_thresh, 'REACTOME')
# Out:
# Edge Weight Threshold = 0.4666666666666667
# Number of Nodes = 502
# ---------------------------------------------
# gene enrichment for nodes in this network:
#       ID       P-value  Adjusted P-value Overlap  \
# 0  M1045  1.035250e-26      3.768310e-24  89/933
# 1   M983  1.142576e-24      2.079489e-22  37/159
# 2  M1060  1.535617e-21      1.863216e-19  43/270
# 3   M973  6.599387e-18      6.005442e-16   21/64
# 4   M965  2.422617e-14      1.763665e-12   18/63
# 5  M1036  1.492614e-11      9.055193e-10  31/279
# 6   M550  8.327070e-06      4.330076e-04   10/66
#
#                                                Genes  \
# 0  ISG15;OAS1;PSME2;GBP1;FCGR1B;DDX58;TAP2;S100A1...
# 1  GBP5;EIF2AK2;MT2A;ISG15;OAS1;IFITM1;FCGR1B;GBP...
# 2  GBP5;EIF2AK2;MT2A;ISG15;OAS1;IFITM1;IL2RB;FCGR...
# 3  ISG15;OAS1;IFITM1;IRF1;GBP2;IFIT2;IFITM2;OAS3;...
# 4  OASL;GBP5;SOCS3;MT2A;OAS2;PML;STAT1;OAS1;ICAM1...
# 5  ISG15;C1QC;AIM2;NLRC4;IRF1;CASP1;DDX58;P2RX7;M...
# 6  EIF4E3;EIF2AK2;STAT1;ISG15;HERC5;UBE2L6;IFIT1;...
#
#                                                Title        Category     logFC
# 0                             Reactome immune system  C2:CP:REACTOME  0.606302
# 1                      Reactome interferon signaling  C2:CP:REACTOME  0.854428
# 2       Reactome cytokine signaling in immune system  C2:CP:REACTOME  0.750174
# 3           Reactome interferon alpha beta signaling  C2:CP:REACTOME  0.820953
# 4                Reactome interferon gamma signaling  C2:CP:REACTOME  0.981419
# 5                      Reactome innate immune system  C2:CP:REACTOME  0.774587
# 6  Reactome antiviral mechanism by ifn stimulated...  C2:CP:REACTOME  0.577590
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.5333333333333333
# Number of Nodes = 342
# ---------------------------------------------
# gene enrichment for nodes in this network:
#       ID       P-value  Adjusted P-value Overlap  \
# 0  M1045  1.083249e-25      3.368905e-23  71/933
# 1   M983  1.545173e-24      2.402744e-22  32/159
# 2  M1060  4.421529e-22      4.583652e-20  37/270
# 3   M973  9.098070e-16      7.073749e-14   17/64
# 4   M965  2.694739e-13      1.676128e-11   15/63
# 5  M1036  4.520071e-11      2.342904e-09  25/279
# 6   M550  2.633602e-06      1.170072e-04    9/66
# 7  M1002  6.186413e-06      2.404968e-04    9/73
# 8   M985  1.619159e-05      5.595094e-04    6/31
#
#                                                Genes  \
# 0  GBP5;EIF2AK2;ISG15;OAS1;PSME2;AIM2;C1QC;NLRC4;...
# 1  GBP5;EIF2AK2;ISG15;OAS1;IFITM1;FCGR1B;GBP1;IRF...
# 2  GBP5;EIF2AK2;ISG15;OAS1;IFITM1;FCGR1B;GBP1;IRF...
# 3  OASL;STAT2;XAF1;IFIT3;IFIT2;ISG15;STAT1;OAS1;I...
# 4  OASL;GBP5;PML;STAT1;OAS1;ICAM1;JAK2;IRF7;FCGR1...
# 5  ISG15;C1QC;AIM2;NLRC4;IRF1;CASP1;DDX58;MAPK14;...
# 6  EIF4E3;EIF2AK2;STAT1;ISG15;HERC5;UBE2L6;FLNB;T...
# 7  ISG15;HERC5;IFIH1;S100A12;UBE2L6;TRIM25;IRF7;I...
# 8              ISG15;HERC5;IFIH1;UBE2L6;TRIM25;DDX58
#
#                                                Title        Category     logFC
# 0                             Reactome immune system  C2:CP:REACTOME  0.670772
# 1                      Reactome interferon signaling  C2:CP:REACTOME  0.885833
# 2       Reactome cytokine signaling in immune system  C2:CP:REACTOME  0.796293
# 3           Reactome interferon alpha beta signaling  C2:CP:REACTOME  0.854634
# 4                Reactome interferon gamma signaling  C2:CP:REACTOME  1.076761
# 5                      Reactome innate immune system  C2:CP:REACTOME  0.830920
# 6  Reactome antiviral mechanism by ifn stimulated...  C2:CP:REACTOME  0.568771
# 7  Reactome rig i mda5 mediated induction of ifn ...  C2:CP:REACTOME  0.711143
# 8  Reactome negative regulators of rig i mda5 sig...  C2:CP:REACTOME  0.797765
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6
# Number of Nodes = 227
# ---------------------------------------------
# gene enrichment for nodes in this network:
#       ID       P-value  Adjusted P-value Overlap  \
# 0  M1045  2.285938e-24      5.577690e-22  56/933
# 1   M983  5.009387e-21      6.111452e-19  25/159
# 2  M1060  1.710787e-19      1.391440e-17  29/270
# 3   M973  8.345201e-16      5.090572e-14   15/64
# 4   M965  4.305815e-13      2.101238e-11   13/63
# 5  M1036  7.235926e-09      2.942610e-07  18/279
# 6   M518  3.387619e-06      1.180827e-04    8/76
# 7  M1058  7.688908e-06      2.345117e-04  20/539
# 8  M1066  1.053744e-05      2.856818e-04  13/251
#
#                                                Genes  \
# 0  GBP5;OAS1;PSME2;AIM2;C1QC;NLRC4;IFITM1;GBP1;FC...
# 1  GBP5;OAS1;IFITM1;FCGR1B;GBP1;IRF1;GBP2;DDX58;I...
# 2  GBP5;OAS1;IFITM1;GBP1;FCGR1B;IRF1;CASP1;GBP2;D...
# 3  OASL;STAT2;XAF1;IFIT3;IFIT2;STAT1;OAS1;IFITM1;...
# 4  OASL;GBP5;PML;STAT1;OAS1;JAK2;IRF7;FCGR1B;GBP1...
# 5  LY96;MAPK14;C1QB;IFIH1;DUSP3;IRF1;UBE2L6;AIM2;...
# 6     TAP1;PSME2;FCGR1B;PSMB8;CYBB;PSMB9;FCGR1A;TAP2
# 7  CYBB;FCGR1A;CD28;CD19;PIK3AP1;FBXO6;UBE2L6;PSM...
# 8  FBXO6;UBE2L6;TAP1;RBCK1;PSME2;FCGR1B;PSMB8;CYB...
#
#                                                Title        Category     logFC
# 0                             Reactome immune system  C2:CP:REACTOME  0.743360
# 1                      Reactome interferon signaling  C2:CP:REACTOME  0.964286
# 2       Reactome cytokine signaling in immune system  C2:CP:REACTOME  0.862892
# 3           Reactome interferon alpha beta signaling  C2:CP:REACTOME  0.850187
# 4                Reactome interferon gamma signaling  C2:CP:REACTOME  1.156876
# 5                      Reactome innate immune system  C2:CP:REACTOME  0.912256
# 6     Reactome antigen processing cross presentation  C2:CP:REACTOME  1.007171
# 7                    Reactome adaptive immune system  C2:CP:REACTOME  0.522075
# 8  Reactome class i mhc mediated antigen processi...  C2:CP:REACTOME  0.909793
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.6666666666666666
# Number of Nodes = 141
# ---------------------------------------------
# gene enrichment for nodes in this network:
#       ID       P-value  Adjusted P-value Overlap  \
# 0  M1045  1.238512e-16      2.489408e-14  36/933
# 1  M1060  8.542956e-16      8.585671e-14  21/270
# 2   M983  2.850172e-15      1.909615e-13  17/159
# 3   M965  8.725251e-10      4.056061e-08    9/63
# 4   M973  1.008970e-09      4.056061e-08    9/64
# 5  M1036  2.083628e-08      6.980152e-07  14/279
# 6   M518  2.116265e-05      6.076703e-04    6/76
#
#                                                Genes  \
# 0  GBP5;PSME2;AIM2;NLRC4;FCGR1B;GBP1;IRF1;CASP1;G...
# 1  GBP5;FCGR1B;GBP1;IRF1;CASP1;GBP2;DDX58;IFIT2;I...
# 2  STAT2;GBP5;XAF1;STAT1;IFIT2;UBE2L6;JAK2;FCGR1B...
# 3  GBP5;STAT1;JAK2;FCGR1B;GBP1;GBP4;IRF1;GBP2;FCGR1A
# 4  STAT2;XAF1;IFIT3;IFIT2;STAT1;IRF1;GBP2;IFITM3;...
# 5  LY96;C1QB;IFIH1;DUSP3;IRF1;UBE2L6;AIM2;NLRC4;N...
# 6                TAP1;PSME2;FCGR1B;PSMB9;FCGR1A;TAP2
#
#                                             Title        Category     logFC
# 0                          Reactome immune system  C2:CP:REACTOME  0.963740
# 1    Reactome cytokine signaling in immune system  C2:CP:REACTOME  1.005340
# 2                   Reactome interferon signaling  C2:CP:REACTOME  1.187966
# 3             Reactome interferon gamma signaling  C2:CP:REACTOME  1.321401
# 4        Reactome interferon alpha beta signaling  C2:CP:REACTOME  0.986245
# 5                   Reactome innate immune system  C2:CP:REACTOME  0.957767
# 6  Reactome antigen processing cross presentation  C2:CP:REACTOME  1.164185
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.7333333333333333
# Number of Nodes = 81
# ---------------------------------------------
# gene enrichment for nodes in this network:
#       ID       P-value  Adjusted P-value Overlap  \
# 0   M983  3.253067e-12      5.237438e-10  12/159
# 1  M1060  7.411353e-12      5.966139e-10  14/270
# 2  M1045  2.071788e-10      1.111860e-08  21/933
# 3   M965  8.838831e-09      3.557630e-07    7/63
# 4   M973  3.023894e-07      9.736940e-06    6/64
#
#                                                Genes  \
# 0  GBP5;XAF1;IFIT2;STAT1;UBE2L6;JAK2;GBP1;FCGR1B;...
# 1  GBP5;IL7R;XAF1;IFIT2;STAT1;UBE2L6;JAK2;GBP1;FC...
# 2  GBP5;AIM2;PSME2;FCGR1B;GBP1;GBP2;IFIT2;FBXO6;T...
# 3              GBP5;STAT1;JAK2;FCGR1B;GBP1;GBP4;GBP2
# 4                 XAF1;STAT1;IFIT2;GBP2;IFIT3;IFITM3
#
#                                           Title        Category     logFC
# 0                 Reactome interferon signaling  C2:CP:REACTOME  1.282218
# 1  Reactome cytokine signaling in immune system  C2:CP:REACTOME  1.068378
# 2                        Reactome immune system  C2:CP:REACTOME  1.118920
# 3           Reactome interferon gamma signaling  C2:CP:REACTOME  1.359134
# 4      Reactome interferon alpha beta signaling  C2:CP:REACTOME  1.141772
# ---------------------------------------------
#
#
#
#
# Edge Weight Threshold = 0.8
# Number of Nodes = 38
# ---------------------------------------------
# gene enrichment for nodes in this network:
#       ID       P-value  Adjusted P-value Overlap  \
# 0  M1045  1.081544e-10      4.542485e-09  15/933
# 1  M1060  9.274327e-11      4.542485e-09  10/270
# 2   M983  7.830289e-10      2.192481e-08   8/159
# 3   M965  2.612169e-09      5.485555e-08    6/63
# 4   M973  7.861851e-06      1.320791e-04    4/64
# 5   M874  6.005242e-05      8.407338e-04   4/107
#
#                                                Genes  \
# 0  GBP5;IL7R;XAF1;STAT1;FBXO6;DUSP3;JAK2;AIM2;FCG...
# 1  GBP5;IL7R;XAF1;STAT1;JAK2;FCGR1B;GBP4;IL1B;GBP...
# 2       GBP5;XAF1;STAT1;JAK2;FCGR1B;GBP4;GBP2;IFITM3
# 3                   GBP5;STAT1;JAK2;FCGR1B;GBP4;GBP2
# 4                             GBP2;XAF1;STAT1;IFITM3
# 5                               IL7R;JAK2;IL1B;STAT1
#
#                                           Title        Category     logFC
# 0                        Reactome immune system  C2:CP:REACTOME  1.070358
# 1  Reactome cytokine signaling in immune system  C2:CP:REACTOME  1.025236
# 2                 Reactome interferon signaling  C2:CP:REACTOME  1.335210
# 3           Reactome interferon gamma signaling  C2:CP:REACTOME  1.319835
# 4      Reactome interferon alpha beta signaling  C2:CP:REACTOME  1.171584
# 5                     Reactome signaling by ils  C2:CP:REACTOME  0.399063
# ---------------------------------------------
